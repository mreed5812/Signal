# %%
#!/usr/bin/env python
# coding: utf-8

import requests # type: ignore
import json
import pandas as pd
from sqlalchemy import create_engine
from sqlalchemy.dialects.postgresql import insert

from datetime import datetime

# ETL Pipeline for loading cryptocurrency data

# 1. API Call to Fetch Cryptocurrency Data
def fetch_crypto_data(api_key, url, parameters, headers):
    try:
        response = requests.get(url, headers=headers, params=parameters)
        response.raise_for_status()
        return response.json()
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data from API: {e}")
        return None

# 2. Process the Raw Data into a DataFrame
def process_crypto_data(raw_data):
    organized_data = []
    for item in raw_data.get('data', []):
        btc_info = {
            "id": item['id'],
            "name": item['name'],
            "symbol": item['symbol'],
            "cmc_rank": item['cmc_rank'],
            "price": item['quote']['USD']['price'],
            "volume_24h": item['quote']['USD']['volume_24h'],
            "market_cap": item['quote']['USD']['market_cap'],
            "market_cap_dominance": item['quote']['USD']['market_cap_dominance'],
            "circulating_supply": item['circulating_supply'],
            "max_supply": item['max_supply'],
            "percent_change_1h": item['quote']['USD']['percent_change_1h'],
            "percent_change_24h": item['quote']['USD']['percent_change_24h'],
            "percent_change_7d": item['quote']['USD']['percent_change_7d'],
            "last_updated": item['quote']['USD']['last_updated']
        }
        organized_data.append(btc_info)
    df = pd.DataFrame(organized_data)
    # Convert last_updated to datetime and add pulled_at
    df["last_updated"] = pd.to_datetime(df["last_updated"])
    df["pulled_at"] = datetime.now()
    return df

# 3. Validate and Truncate Data to Match Database Constraints
def validate_and_truncate(df):
    df["symbol"] = df["symbol"].str[:10]
    df["name"] = df["name"].str[:50]
    df["price"] = df["price"].clip(upper=10**12 - 1)
    df["volume_24h"] = df["volume_24h"].clip(upper=10**12 - 1)
    df["market_cap"] = df["market_cap"].clip(upper=10**12 - 1)
    df["market_cap_dominance"] = df["market_cap_dominance"].clip(upper=999.99)
    df["circulating_supply"] = df["circulating_supply"].clip(upper=10**12 - 1)
    df["max_supply"] = df["max_supply"].clip(upper=10**12 - 1)
    df["percent_change_1h"] = df["percent_change_1h"].clip(-9999.9999, 9999.9999)
    df["percent_change_24h"] = df["percent_change_24h"].clip(-9999.9999, 9999.9999)
    df["percent_change_7d"] = df["percent_change_7d"].clip(-9999.9999, 9999.9999)
    df = df.dropna(subset=["symbol", "last_updated"])
    return df

# 4. Upsert Data into the Database
from sqlalchemy import Table, MetaData
from sqlalchemy.dialects.postgresql import insert

def upsert_crypto_data(df, table_name, engine):
    """
    Upsert data into the database table, ensuring no duplicate records are inserted.
    Records are considered unique based on 'symbol' and 'last_updated'.
    """
    # Drop the 'id' column if it exists, as it should be auto-generated by the database
    if "id" in df.columns:
        df = df.drop(columns=["id"])

    # Convert 'last_updated' to UTC timezone to ensure consistency
    df["last_updated"] = pd.to_datetime(df["last_updated"]).dt.tz_convert("UTC")

    # Convert DataFrame to a list of dictionaries for bulk insert
    records = df.to_dict(orient="records")

    # Create a MetaData instance and reflect the table schema
    metadata = MetaData()
    metadata.reflect(bind=engine)
    table = Table(table_name, metadata, autoload_with=engine)  # Define the table object

    # Prepare the insert statement with ON CONFLICT logic
    stmt = insert(table).values(records)
    stmt = stmt.on_conflict_do_nothing(index_elements=["symbol", "last_updated"])

    # Execute the upsert operation
    with engine.connect() as connection:
        try:
            result = connection.execute(stmt)
            print(f"Upsert completed. {result.rowcount} new records inserted.")
        except Exception as e:
            print(f"Error during upsert: {e}")


# Main function to execute ETL pipeline
def main():
    # API Setup
    api_key = '42485936-1986-4342-9e0a-e854c8b0fe47'
    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
    parameters = {'start': '1', 'limit': '100', 'convert': 'USD'}
    headers = {'Accepts': 'application/json', 'X-CMC_PRO_API_KEY': api_key}

    # Database Configuration
    DB_USER = "postgres"
    DB_HOST = "localhost"
    DB_PORT = "5432"
    DB_NAME = "signal"
    table_name = "crypto_price_history"
    DATABASE_URL = f"postgresql+psycopg2://{DB_USER}@{DB_HOST}:{DB_PORT}/{DB_NAME}"
    engine = create_engine(DATABASE_URL)

    # Fetch, Process, Validate, and Load Data
    raw_data = fetch_crypto_data(api_key, url, parameters, headers)
    if raw_data:
        df = process_crypto_data(raw_data)
        df_cleaned = validate_and_truncate(df)
        upsert_crypto_data(df_cleaned, table_name, engine)

if __name__ == "__main__":
    main()
# Out:
# Upsert completed. 100 new records inserted.

# %%
raw_data = fetch_crypto_data(api_key, url, parameters, headers)
if raw_data:
    print(json.dumps(raw_data, indent=4))  # Print the raw data for debugging
# Out:
# {
#     "status": {
#         "timestamp": "2024-12-22T22:16:44.362Z",
#         "error_code": 0,
#         "error_message": null,
#         "elapsed": 21,
#         "credit_count": 1,
#         "notice": null,
#         "total_count": 10428
#     },
#     "data": [
#         {
#             "id": 1,
#             "name": "Bitcoin",
#             "symbol": "BTC",
#             "slug": "bitcoin",
#             "num_market_pairs": 11849,
#             "date_added": "2010-07-13T00:00:00.000Z",
#             "tags": [
#                 "mineable",
#                 "pow",
#                 "sha-256",
#                 "store-of-value",
#                 "state-channel",
#                 "coinbase-ventures-portfolio",
#                 "three-arrows-capital-portfolio",
#                 "polychain-capital-portfolio",
#                 "binance-labs-portfolio",
#                 "blockchain-capital-portfolio",
#                 "boostvc-portfolio",
#                 "cms-holdings-portfolio",
#                 "dcg-portfolio",
#                 "dragonfly-capital-portfolio",
#                 "electric-capital-portfolio",
#                 "fabric-ventures-portfolio",
#                 "framework-ventures-portfolio",
#                 "galaxy-digital-portfolio",
#                 "huobi-capital-portfolio",
#                 "alameda-research-portfolio",
#                 "a16z-portfolio",
#                 "1confirmation-portfolio",
#                 "winklevoss-capital-portfolio",
#                 "usv-portfolio",
#                 "placeholder-ventures-portfolio",
#                 "pantera-capital-portfolio",
#                 "multicoin-capital-portfolio",
#                 "paradigm-portfolio",
#                 "bitcoin-ecosystem",
#                 "ftx-bankruptcy-estate",
#                 "2017-2018-alt-season"
#             ],
#             "max_supply": 21000000,
#             "circulating_supply": 19799809,
#             "total_supply": 19799809,
#             "infinite_supply": false,
#             "platform": null,
#             "cmc_rank": 1,
#             "self_reported_circulating_supply": null,
#             "self_reported_market_cap": null,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-22T22:15:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 94544.62739488717,
#                     "volume_24h": 41966990011.13865,
#                     "volume_change_24h": -20.0442,
#                     "percent_change_1h": -0.93909682,
#                     "percent_change_24h": -2.15396813,
#                     "percent_change_7d": -8.16845413,
#                     "percent_change_30d": -4.60405694,
#                     "percent_change_60d": 42.25874759,
#                     "percent_change_90d": 49.42334639,
#                     "market_cap": 1871965564394.9336,
#                     "market_cap_dominance": 57.6457,
#                     "fully_diluted_market_cap": 1985437175292.63,
#                     "tvl": null,
#                     "last_updated": "2024-12-22T22:15:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 1027,
#             "name": "Ethereum",
#             "symbol": "ETH",
#             "slug": "ethereum",
#             "num_market_pairs": 9717,
#             "date_added": "2015-08-07T00:00:00.000Z",
#             "tags": [
#                 "pos",
#                 "smart-contracts",
#                 "ethereum-ecosystem",
#                 "coinbase-ventures-portfolio",
#                 "three-arrows-capital-portfolio",
#                 "polychain-capital-portfolio",
#                 "binance-labs-portfolio",
#                 "blockchain-capital-portfolio",
#                 "boostvc-portfolio",
#                 "cms-holdings-portfolio",
#                 "dcg-portfolio",
#                 "dragonfly-capital-portfolio",
#                 "electric-capital-portfolio",
#                 "fabric-ventures-portfolio",
#                 "framework-ventures-portfolio",
#                 "hashkey-capital-portfolio",
#                 "kenetic-capital-portfolio",
#                 "huobi-capital-portfolio",
#                 "alameda-research-portfolio",
#                 "a16z-portfolio",
#                 "1confirmation-portfolio",
#                 "winklevoss-capital-portfolio",
#                 "usv-portfolio",
#                 "placeholder-ventures-portfolio",
#                 "pantera-capital-portfolio",
#                 "multicoin-capital-portfolio",
#                 "paradigm-portfolio",
#                 "layer-1",
#                 "ftx-bankruptcy-estate"
#             ],
#             "max_supply": null,
#             "circulating_supply": 120455304.53520444,
#             "total_supply": 120455304.53520444,
#             "infinite_supply": true,
#             "platform": null,
#             "cmc_rank": 2,
#             "self_reported_circulating_supply": null,
#             "self_reported_market_cap": null,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-22T22:15:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 3249.985386054865,
#                     "volume_24h": 24379872367.16457,
#                     "volume_change_24h": -21.7334,
#                     "percent_change_1h": -1.41300637,
#                     "percent_change_24h": -1.51125125,
#                     "percent_change_7d": -15.9726012,
#                     "percent_change_30d": -1.81978354,
#                     "percent_change_60d": 29.61850915,
#                     "percent_change_90d": 22.61052017,
#                     "market_cap": 391477979412.20276,
#                     "market_cap_dominance": 12.0348,
#                     "fully_diluted_market_cap": 391477979412.2,
#                     "tvl": null,
#                     "last_updated": "2024-12-22T22:15:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 825,
#             "name": "Tether USDt",
#             "symbol": "USDT",
#             "slug": "tether",
#             "num_market_pairs": 109606,
#             "date_added": "2015-02-25T00:00:00.000Z",
#             "tags": [
#                 "stablecoin",
#                 "asset-backed-stablecoin",
#                 "avalanche-ecosystem",
#                 "solana-ecosystem",
#                 "arbitrum-ecosytem",
#                 "moonriver-ecosystem",
#                 "injective-ecosystem",
#                 "bnb-chain",
#                 "usd-stablecoin",
#                 "optimism-ecosystem",
#                 "fiat-stablecoin"
#             ],
#             "max_supply": null,
#             "circulating_supply": 139872815646.75348,
#             "total_supply": 143440125286.8632,
#             "platform": {
#                 "id": 1027,
#                 "name": "Ethereum",
#                 "symbol": "ETH",
#                 "slug": "ethereum",
#                 "token_address": "0xdac17f958d2ee523a2206206994597c13d831ec7"
#             },
#             "infinite_supply": true,
#             "cmc_rank": 3,
#             "self_reported_circulating_supply": null,
#             "self_reported_market_cap": null,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-22T22:15:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 0.9990902245933219,
#                     "volume_24h": 112397769912.9613,
#                     "volume_change_24h": -23.5041,
#                     "percent_change_1h": -0.00152767,
#                     "percent_change_24h": -0.03118456,
#                     "percent_change_7d": -0.06233858,
#                     "percent_change_30d": -0.20149675,
#                     "percent_change_60d": -0.00184596,
#                     "percent_change_90d": -0.08533623,
#                     "market_cap": 139745562799.01523,
#                     "market_cap_dominance": 4.3034,
#                     "fully_diluted_market_cap": 143309626988.55,
#                     "tvl": null,
#                     "last_updated": "2024-12-22T22:15:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 52,
#             "name": "XRP",
#             "symbol": "XRP",
#             "slug": "xrp",
#             "num_market_pairs": 1485,
#             "date_added": "2013-08-04T00:00:00.000Z",
#             "tags": [
#                 "medium-of-exchange",
#                 "enterprise-solutions",
#                 "arrington-xrp-capital-portfolio",
#                 "galaxy-digital-portfolio",
#                 "a16z-portfolio",
#                 "pantera-capital-portfolio",
#                 "ftx-bankruptcy-estate",
#                 "2017-2018-alt-season"
#             ],
#             "max_supply": 100000000000,
#             "circulating_supply": 57252380420,
#             "total_supply": 99986807248,
#             "infinite_supply": false,
#             "platform": null,
#             "cmc_rank": 4,
#             "self_reported_circulating_supply": null,
#             "self_reported_market_cap": null,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-22T22:15:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 2.180516426091264,
#                     "volume_24h": 11141164425.3883,
#                     "volume_change_24h": -26.7423,
#                     "percent_change_1h": -1.53981519,
#                     "percent_change_24h": -1.49332797,
#                     "percent_change_7d": -8.26500737,
#                     "percent_change_30d": 50.24265413,
#                     "percent_change_60d": 316.09916096,
#                     "percent_change_90d": 271.86370423,
#                     "market_cap": 124839755938.63586,
#                     "market_cap_dominance": 3.8443,
#                     "fully_diluted_market_cap": 218051642609.13,
#                     "tvl": null,
#                     "last_updated": "2024-12-22T22:15:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 1839,
#             "name": "BNB",
#             "symbol": "BNB",
#             "slug": "bnb",
#             "num_market_pairs": 2315,
#             "date_added": "2017-07-25T00:00:00.000Z",
#             "tags": [
#                 "marketplace",
#                 "centralized-exchange",
#                 "payments",
#                 "smart-contracts",
#                 "alameda-research-portfolio",
#                 "multicoin-capital-portfolio",
#                 "bnb-chain",
#                 "layer-1",
#                 "alleged-sec-securities",
#                 "celsius-bankruptcy-estate"
#             ],
#             "max_supply": null,
#             "circulating_supply": 144007650.31,
#             "total_supply": 144007650.31,
#             "infinite_supply": false,
#             "platform": null,
#             "cmc_rank": 5,
#             "self_reported_circulating_supply": null,
#             "self_reported_market_cap": null,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-22T22:15:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 643.2714753199804,
#                     "volume_24h": 1083528981.8725755,
#                     "volume_change_24h": -50.3732,
#                     "percent_change_1h": -1.18169105,
#                     "percent_change_24h": -1.89846627,
#                     "percent_change_7d": -9.29025381,
#                     "percent_change_30d": 2.4493923,
#                     "percent_change_60d": 10.4984088,
#                     "percent_change_90d": 5.63939126,
#                     "market_cap": 92636013672.27753,
#                     "market_cap_dominance": 2.8527,
#                     "fully_diluted_market_cap": 92636013672.28,
#                     "tvl": null,
#                     "last_updated": "2024-12-22T22:15:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 5426,
#             "name": "Solana",
#             "symbol": "SOL",
#             "slug": "solana",
#             "num_market_pairs": 813,
#             "date_added": "2020-04-10T00:00:00.000Z",
#             "tags": [
#                 "pos",
#                 "platform",
#                 "solana-ecosystem",
#                 "cms-holdings-portfolio",
#                 "kenetic-capital-portfolio",
#                 "alameda-research-portfolio",
#                 "multicoin-capital-portfolio",
#                 "okx-ventures-portfolio",
#                 "layer-1",
#                 "ftx-bankruptcy-estate",
#                 "alleged-sec-securities",
#                 "cmc-crypto-awards-2024"
#             ],
#             "max_supply": null,
#             "circulating_supply": 479343750.8276081,
#             "total_supply": 590646312.8516982,
#             "infinite_supply": true,
#             "platform": null,
#             "cmc_rank": 6,
#             "self_reported_circulating_supply": null,
#             "self_reported_market_cap": null,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-22T22:15:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 178.67259763343853,
#                     "volume_24h": 4025091723.843656,
#                     "volume_change_24h": -25.7626,
#                     "percent_change_1h": -1.54488797,
#                     "percent_change_24h": -0.68688344,
#                     "percent_change_7d": -17.78887544,
#                     "percent_change_30d": -30.45616585,
#                     "percent_change_60d": 4.4401919,
#                     "percent_change_90d": 23.92050365,
#                     "market_cap": 85645593119.72444,
#                     "market_cap_dominance": 2.6374,
#                     "fully_diluted_market_cap": 105532310999.83,
#                     "tvl": null,
#                     "last_updated": "2024-12-22T22:15:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 74,
#             "name": "Dogecoin",
#             "symbol": "DOGE",
#             "slug": "dogecoin",
#             "num_market_pairs": 1130,
#             "date_added": "2013-12-15T00:00:00.000Z",
#             "tags": [
#                 "mineable",
#                 "pow",
#                 "scrypt",
#                 "medium-of-exchange",
#                 "memes",
#                 "payments",
#                 "doggone-doggerel",
#                 "bnb-chain",
#                 "ftx-bankruptcy-estate"
#             ],
#             "max_supply": null,
#             "circulating_supply": 147311436383.70526,
#             "total_supply": 147311436383.70526,
#             "infinite_supply": true,
#             "platform": null,
#             "cmc_rank": 7,
#             "self_reported_circulating_supply": null,
#             "self_reported_market_cap": null,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-22T22:15:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 0.3090802937453228,
#                     "volume_24h": 4129184949.33668,
#                     "volume_change_24h": -40.6833,
#                     "percent_change_1h": -1.74430748,
#                     "percent_change_24h": -2.49714508,
#                     "percent_change_7d": -22.4596277,
#                     "percent_change_30d": -25.31109128,
#                     "percent_change_60d": 123.33734588,
#                     "percent_change_90d": 187.1421286,
#                     "market_cap": 45531062029.52106,
#                     "market_cap_dominance": 1.4021,
#                     "fully_diluted_market_cap": 45531062029.52,
#                     "tvl": null,
#                     "last_updated": "2024-12-22T22:15:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 3408,
#             "name": "USDC",
#             "symbol": "USDC",
#             "slug": "usd-coin",
#             "num_market_pairs": 24079,
#             "date_added": "2018-10-08T00:00:00.000Z",
#             "tags": [
#                 "medium-of-exchange",
#                 "stablecoin",
#                 "asset-backed-stablecoin",
#                 "coinbase-ventures-portfolio",
#                 "solana-ecosystem",
#                 "hedera-hashgraph-ecosystem",
#                 "arbitrum-ecosytem",
#                 "moonriver-ecosystem",
#                 "bnb-chain",
#                 "usd-stablecoin",
#                 "optimism-ecosystem",
#                 "base-ecosystem",
#                 "fiat-stablecoin"
#             ],
#             "max_supply": null,
#             "circulating_supply": 43003970143.34023,
#             "total_supply": 43003970143.34023,
#             "platform": {
#                 "id": 1027,
#                 "name": "Ethereum",
#                 "symbol": "ETH",
#                 "slug": "ethereum",
#                 "token_address": "0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48"
#             },
#             "infinite_supply": false,
#             "cmc_rank": 8,
#             "self_reported_circulating_supply": null,
#             "self_reported_market_cap": null,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-22T22:15:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 0.9999857706455006,
#                     "volume_24h": 5919502624.82281,
#                     "volume_change_24h": -20.729,
#                     "percent_change_1h": -0.00744301,
#                     "percent_change_24h": 0.00660661,
#                     "percent_change_7d": 0.01075962,
#                     "percent_change_30d": 0.01042659,
#                     "percent_change_60d": 0.00199052,
#                     "percent_change_90d": 0.0067444,
#                     "market_cap": 43003358224.60419,
#                     "market_cap_dominance": 1.3243,
#                     "fully_diluted_market_cap": 43003358224.6,
#                     "tvl": null,
#                     "last_updated": "2024-12-22T22:15:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 2010,
#             "name": "Cardano",
#             "symbol": "ADA",
#             "slug": "cardano",
#             "num_market_pairs": 1418,
#             "date_added": "2017-10-01T00:00:00.000Z",
#             "tags": [
#                 "dpos",
#                 "pos",
#                 "platform",
#                 "research",
#                 "smart-contracts",
#                 "staking",
#                 "cardano-ecosystem",
#                 "cardano",
#                 "layer-1",
#                 "alleged-sec-securities",
#                 "2017-2018-alt-season"
#             ],
#             "max_supply": 45000000000,
#             "circulating_supply": 35126169612.19378,
#             "total_supply": 44995107818.69111,
#             "infinite_supply": false,
#             "platform": null,
#             "cmc_rank": 9,
#             "self_reported_circulating_supply": null,
#             "self_reported_market_cap": null,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-22T22:15:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 0.8791622486556002,
#                     "volume_24h": 1094002666.107765,
#                     "volume_change_24h": -32.7969,
#                     "percent_change_1h": -1.56466992,
#                     "percent_change_24h": -1.94174565,
#                     "percent_change_7d": -16.9407615,
#                     "percent_change_30d": -12.88283348,
#                     "percent_change_60d": 151.51476528,
#                     "percent_change_90d": 142.92732734,
#                     "market_cap": 30881602262.914295,
#                     "market_cap_dominance": 0.951,
#                     "fully_diluted_market_cap": 39562301189.5,
#                     "tvl": null,
#                     "last_updated": "2024-12-22T22:15:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 1958,
#             "name": "TRON",
#             "symbol": "TRX",
#             "slug": "tron",
#             "num_market_pairs": 1087,
#             "date_added": "2017-09-13T00:00:00.000Z",
#             "tags": [
#                 "media",
#                 "payments",
#                 "tron-ecosystem",
#                 "layer-1",
#                 "dwf-labs-portfolio",
#                 "alleged-sec-securities",
#                 "2017-2018-alt-season"
#             ],
#             "max_supply": null,
#             "circulating_supply": 86216826067.02379,
#             "total_supply": 86216816756.21747,
#             "infinite_supply": true,
#             "platform": null,
#             "cmc_rank": 10,
#             "self_reported_circulating_supply": null,
#             "self_reported_market_cap": null,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-22T22:15:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 0.24300509243059834,
#                     "volume_24h": 1090794541.15559,
#                     "volume_change_24h": -14.9305,
#                     "percent_change_1h": -0.69782068,
#                     "percent_change_24h": -0.06891935,
#                     "percent_change_7d": -12.76059488,
#                     "percent_change_30d": 19.11590417,
#                     "percent_change_60d": 51.86727023,
#                     "percent_change_90d": 59.41621986,
#                     "market_cap": 20951127787.489937,
#                     "market_cap_dominance": 0.6452,
#                     "fully_diluted_market_cap": 20951125524.92,
#                     "tvl": null,
#                     "last_updated": "2024-12-22T22:15:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 5805,
#             "name": "Avalanche",
#             "symbol": "AVAX",
#             "slug": "avalanche",
#             "num_market_pairs": 828,
#             "date_added": "2020-07-13T00:00:00.000Z",
#             "tags": [
#                 "defi",
#                 "smart-contracts",
#                 "three-arrows-capital-portfolio",
#                 "polychain-capital-portfolio",
#                 "avalanche-ecosystem",
#                 "cms-holdings-portfolio",
#                 "dragonfly-capital-portfolio",
#                 "real-world-assets",
#                 "layer-1"
#             ],
#             "max_supply": 715748719,
#             "circulating_supply": 409831182.3712714,
#             "total_supply": 448167482.3712714,
#             "infinite_supply": false,
#             "platform": null,
#             "cmc_rank": 11,
#             "self_reported_circulating_supply": null,
#             "self_reported_market_cap": null,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-22T22:15:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 36.157846086804305,
#                     "volume_24h": 506240597.91359824,
#                     "volume_change_24h": -27.8702,
#                     "percent_change_1h": -1.48421669,
#                     "percent_change_24h": -2.68228791,
#                     "percent_change_7d": -25.32972714,
#                     "percent_change_30d": -12.89234017,
#                     "percent_change_60d": 35.63920919,
#                     "percent_change_90d": 32.48246665,
#                     "market_cap": 14818612813.753456,
#                     "market_cap_dominance": 0.4563,
#                     "fully_diluted_market_cap": 25879932018.43,
#                     "tvl": null,
#                     "last_updated": "2024-12-22T22:15:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 1975,
#             "name": "Chainlink",
#             "symbol": "LINK",
#             "slug": "chainlink",
#             "num_market_pairs": 1903,
#             "date_added": "2017-09-20T00:00:00.000Z",
#             "tags": [
#                 "platform",
#                 "defi",
#                 "oracles",
#                 "smart-contracts",
#                 "substrate",
#                 "polkadot",
#                 "avalanche-ecosystem",
#                 "solana-ecosystem",
#                 "framework-ventures-portfolio",
#                 "polygon-ecosystem",
#                 "fantom-ecosystem",
#                 "cardano-ecosystem",
#                 "web3",
#                 "near-protocol-ecosystem",
#                 "arbitrum-ecosytem",
#                 "cardano",
#                 "injective-ecosystem",
#                 "optimism-ecosystem",
#                 "real-world-assets",
#                 "celsius-bankruptcy-estate"
#             ],
#             "max_supply": null,
#             "circulating_supply": 638099970.4527867,
#             "total_supply": 1000000000,
#             "platform": {
#                 "id": 1027,
#                 "name": "Ethereum",
#                 "symbol": "ETH",
#                 "slug": "ethereum",
#                 "token_address": "0x514910771af9ca656af840dff83e8264ecf986ca"
#             },
#             "infinite_supply": false,
#             "cmc_rank": 12,
#             "self_reported_circulating_supply": null,
#             "self_reported_market_cap": null,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-22T22:15:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 21.932172157400313,
#                     "volume_24h": 751839305.9217045,
#                     "volume_change_24h": -43.1041,
#                     "percent_change_1h": -0.89885029,
#                     "percent_change_24h": -0.02863178,
#                     "percent_change_7d": -22.09391692,
#                     "percent_change_30d": 39.71125444,
#                     "percent_change_60d": 95.26677175,
#                     "percent_change_90d": 91.91779236,
#                     "market_cap": 13994918405.60257,
#                     "market_cap_dominance": 0.431,
#                     "fully_diluted_market_cap": 21932172157.4,
#                     "tvl": null,
#                     "last_updated": "2024-12-22T22:15:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 11419,
#             "name": "Toncoin",
#             "symbol": "TON",
#             "slug": "toncoin",
#             "num_market_pairs": 641,
#             "date_added": "2021-08-26T13:40:22.000Z",
#             "tags": [
#                 "pos",
#                 "layer-1",
#                 "ftx-bankruptcy-estate",
#                 "dwf-labs-portfolio",
#                 "toncoin-ecosystem"
#             ],
#             "max_supply": null,
#             "circulating_supply": 2551837843.451083,
#             "total_supply": 5118028218.493527,
#             "infinite_supply": true,
#             "platform": null,
#             "cmc_rank": 13,
#             "self_reported_circulating_supply": 3414166606,
#             "self_reported_market_cap": 18291427927.413715,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-22T22:15:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 5.357508885263145,
#                     "volume_24h": 219171034.13790005,
#                     "volume_change_24h": -21.9754,
#                     "percent_change_1h": -0.45579065,
#                     "percent_change_24h": 2.23517321,
#                     "percent_change_7d": -14.57172015,
#                     "percent_change_30d": -0.99645279,
#                     "percent_change_60d": 4.67467161,
#                     "percent_change_90d": -4.68389499,
#                     "market_cap": 13671493920.03992,
#                     "market_cap_dominance": 0.421,
#                     "fully_diluted_market_cap": 27419881655.61,
#                     "tvl": null,
#                     "last_updated": "2024-12-22T22:15:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 5994,
#             "name": "Shiba Inu",
#             "symbol": "SHIB",
#             "slug": "shiba-inu",
#             "num_market_pairs": 921,
#             "date_added": "2020-08-01T00:00:00.000Z",
#             "tags": [
#                 "memes",
#                 "ethereum-ecosystem",
#                 "doggone-doggerel"
#             ],
#             "max_supply": null,
#             "circulating_supply": 589255475176361.6,
#             "total_supply": 589508566398900.6,
#             "platform": {
#                 "id": 1027,
#                 "name": "Ethereum",
#                 "symbol": "ETH",
#                 "slug": "ethereum",
#                 "token_address": "0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce"
#             },
#             "infinite_supply": false,
#             "cmc_rank": 14,
#             "self_reported_circulating_supply": null,
#             "self_reported_market_cap": null,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-22T22:15:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 2.129444193263773e-05,
#                     "volume_24h": 630230490.7743242,
#                     "volume_change_24h": -41.7108,
#                     "percent_change_1h": -1.46130506,
#                     "percent_change_24h": -0.89366115,
#                     "percent_change_7d": -21.23143581,
#                     "percent_change_30d": -15.70337632,
#                     "percent_change_60d": 20.78624935,
#                     "percent_change_90d": 47.13432205,
#                     "market_cap": 12547866499.631886,
#                     "market_cap_dominance": 0.3864,
#                     "fully_diluted_market_cap": 12553255935.97,
#                     "tvl": null,
#                     "last_updated": "2024-12-22T22:15:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 20947,
#             "name": "Sui",
#             "symbol": "SUI",
#             "slug": "sui",
#             "num_market_pairs": 491,
#             "date_added": "2022-07-12T08:03:11.000Z",
#             "tags": [
#                 "binance-launchpool",
#                 "coinbase-ventures-portfolio",
#                 "binance-labs-portfolio",
#                 "electric-capital-portfolio",
#                 "a16z-portfolio",
#                 "sui-ecosystem",
#                 "layer-1",
#                 "move-vm"
#             ],
#             "max_supply": 10000000000,
#             "circulating_supply": 2927660018.558888,
#             "total_supply": 10000000000,
#             "infinite_supply": false,
#             "platform": null,
#             "cmc_rank": 15,
#             "self_reported_circulating_supply": null,
#             "self_reported_market_cap": null,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-22T22:15:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 4.266696317421098,
#                     "volume_24h": 2187820568.254646,
#                     "volume_change_24h": -24.1531,
#                     "percent_change_1h": -1.958982,
#                     "percent_change_24h": -0.96097128,
#                     "percent_change_7d": -7.95008289,
#                     "percent_change_30d": 22.34608239,
#                     "percent_change_60d": 116.607032,
#                     "percent_change_90d": 176.48524624,
#                     "market_cap": 12491436219.84619,
#                     "market_cap_dominance": 0.3847,
#                     "fully_diluted_market_cap": 42666963174.21,
#                     "tvl": null,
#                     "last_updated": "2024-12-22T22:15:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 512,
#             "name": "Stellar",
#             "symbol": "XLM",
#             "slug": "stellar",
#             "num_market_pairs": 651,
#             "date_added": "2014-08-05T00:00:00.000Z",
#             "tags": [
#                 "medium-of-exchange",
#                 "enterprise-solutions",
#                 "decentralized-exchange-dex-token",
#                 "smart-contracts",
#                 "hashkey-capital-portfolio",
#                 "2017-2018-alt-season"
#             ],
#             "max_supply": 50001806812,
#             "circulating_supply": 30227902434.296856,
#             "total_supply": 50001786911.162926,
#             "infinite_supply": false,
#             "platform": null,
#             "cmc_rank": 16,
#             "self_reported_circulating_supply": null,
#             "self_reported_market_cap": null,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-22T22:15:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 0.35349333129468247,
#                     "volume_24h": 430277148.5134861,
#                     "volume_change_24h": -27.0425,
#                     "percent_change_1h": -1.17993437,
#                     "percent_change_24h": 0.15882487,
#                     "percent_change_7d": -15.35363241,
#                     "percent_change_30d": 5.13609118,
#                     "percent_change_60d": 275.87231332,
#                     "percent_change_90d": 267.46716999,
#                     "market_cap": 10685361929.550238,
#                     "market_cap_dominance": 0.329,
#                     "fully_diluted_market_cap": 17675305260.73,
#                     "tvl": null,
#                     "last_updated": "2024-12-22T22:15:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 6636,
#             "name": "Polkadot",
#             "symbol": "DOT",
#             "slug": "polkadot-new",
#             "num_market_pairs": 855,
#             "date_added": "2020-08-19T00:00:00.000Z",
#             "tags": [
#                 "substrate",
#                 "polkadot",
#                 "polkadot-ecosystem",
#                 "three-arrows-capital-portfolio",
#                 "polychain-capital-portfolio",
#                 "arrington-xrp-capital-portfolio",
#                 "blockchain-capital-portfolio",
#                 "boostvc-portfolio",
#                 "cms-holdings-portfolio",
#                 "coinfund-portfolio",
#                 "fabric-ventures-portfolio",
#                 "fenbushi-capital-portfolio",
#                 "hashkey-capital-portfolio",
#                 "kenetic-capital-portfolio",
#                 "1confirmation-portfolio",
#                 "placeholder-ventures-portfolio",
#                 "pantera-capital-portfolio",
#                 "exnetwork-capital-portfolio",
#                 "web3",
#                 "spartan-group",
#                 "layer-1"
#             ],
#             "max_supply": null,
#             "circulating_supply": 1531325012.0303056,
#             "total_supply": 1531325012.0303056,
#             "infinite_supply": true,
#             "platform": null,
#             "cmc_rank": 17,
#             "self_reported_circulating_supply": 1531322674.760708,
#             "self_reported_market_cap": 10408626154.547083,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-22T22:15:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 6.7971475418618645,
#                     "volume_24h": 372066450.04827017,
#                     "volume_change_24h": -34.2599,
#                     "percent_change_1h": -1.18360386,
#                     "percent_change_24h": -1.28075303,
#                     "percent_change_7d": -21.94934719,
#                     "percent_change_30d": 5.53796395,
#                     "percent_change_60d": 62.24489954,
#                     "percent_change_90d": 53.66445677,
#                     "market_cap": 10408642041.313381,
#                     "market_cap_dominance": 0.3205,
#                     "fully_diluted_market_cap": 10408642041.31,
#                     "tvl": null,
#                     "last_updated": "2024-12-22T22:15:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 4642,
#             "name": "Hedera",
#             "symbol": "HBAR",
#             "slug": "hedera",
#             "num_market_pairs": 301,
#             "date_added": "2019-09-17T00:00:00.000Z",
#             "tags": [
#                 "dag",
#                 "marketplace",
#                 "enterprise-solutions",
#                 "defi",
#                 "payments",
#                 "dcg-portfolio",
#                 "hedera-hashgraph-ecosystem",
#                 "real-world-assets",
#                 "layer-1"
#             ],
#             "max_supply": 50000000000,
#             "circulating_supply": 38252162549.98448,
#             "total_supply": 50000000000,
#             "infinite_supply": false,
#             "platform": null,
#             "cmc_rank": 18,
#             "self_reported_circulating_supply": null,
#             "self_reported_market_cap": null,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-22T22:15:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 0.26335246422033803,
#                     "volume_24h": 880825347.7817771,
#                     "volume_change_24h": -17.1722,
#                     "percent_change_1h": -1.33340087,
#                     "percent_change_24h": 4.8039474,
#                     "percent_change_7d": -7.72783314,
#                     "percent_change_30d": 74.57873044,
#                     "percent_change_60d": 415.58901288,
#                     "percent_change_90d": 356.59913897,
#                     "market_cap": 10073801269.295343,
#                     "market_cap_dominance": 0.3102,
#                     "fully_diluted_market_cap": 13167623211.02,
#                     "tvl": null,
#                     "last_updated": "2024-12-22T22:15:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 1831,
#             "name": "Bitcoin Cash",
#             "symbol": "BCH",
#             "slug": "bitcoin-cash",
#             "num_market_pairs": 961,
#             "date_added": "2017-07-23T00:00:00.000Z",
#             "tags": [
#                 "mineable",
#                 "pow",
#                 "sha-256",
#                 "marketplace",
#                 "medium-of-exchange",
#                 "store-of-value",
#                 "enterprise-solutions",
#                 "payments",
#                 "bitcoin-ecosystem",
#                 "layer-1",
#                 "2017-2018-alt-season"
#             ],
#             "max_supply": 21000000,
#             "circulating_supply": 19805443.75,
#             "total_supply": 19805443.75,
#             "infinite_supply": false,
#             "platform": null,
#             "cmc_rank": 19,
#             "self_reported_circulating_supply": null,
#             "self_reported_market_cap": null,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-22T22:15:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 441.78214349294683,
#                     "volume_24h": 389587893.05264217,
#                     "volume_change_24h": -19.0854,
#                     "percent_change_1h": -1.15230206,
#                     "percent_change_24h": -1.73187406,
#                     "percent_change_7d": -16.08985486,
#                     "percent_change_30d": -9.60098976,
#                     "percent_change_60d": 27.37870759,
#                     "percent_change_90d": 29.35733097,
#                     "market_cap": 8749691392.703987,
#                     "market_cap_dominance": 0.2694,
#                     "fully_diluted_market_cap": 9277425013.35,
#                     "tvl": null,
#                     "last_updated": "2024-12-22T22:15:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 3957,
#             "name": "UNUS SED LEO",
#             "symbol": "LEO",
#             "slug": "unus-sed-leo",
#             "num_market_pairs": 55,
#             "date_added": "2019-05-21T00:00:00.000Z",
#             "tags": [
#                 "marketplace",
#                 "centralized-exchange",
#                 "discount-token",
#                 "payments",
#                 "kenetic-capital-portfolio",
#                 "alameda-research-portfolio"
#             ],
#             "max_supply": null,
#             "circulating_supply": 924449778.9,
#             "total_supply": 985239504,
#             "platform": {
#                 "id": 1027,
#                 "name": "Ethereum",
#                 "symbol": "ETH",
#                 "slug": "ethereum",
#                 "token_address": "0x2af5d2ad76741191d15dfe7bf6ac92d4bd912ca3"
#             },
#             "infinite_supply": false,
#             "cmc_rank": 20,
#             "self_reported_circulating_supply": null,
#             "self_reported_market_cap": null,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-22T22:15:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 9.310250174242055,
#                     "volume_24h": 843117.97272948,
#                     "volume_change_24h": -65.1417,
#                     "percent_change_1h": -0.1877513,
#                     "percent_change_24h": -0.25422426,
#                     "percent_change_7d": -0.62266596,
#                     "percent_change_30d": 9.84126791,
#                     "percent_change_60d": 53.22375826,
#                     "percent_change_90d": 65.2785063,
#                     "market_cap": 8606858715.081755,
#                     "market_cap_dominance": 0.265,
#                     "fully_diluted_market_cap": 9172826263.79,
#                     "tvl": null,
#                     "last_updated": "2024-12-22T22:15:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 7083,
#             "name": "Uniswap",
#             "symbol": "UNI",
#             "slug": "uniswap",
#             "num_market_pairs": 1149,
#             "date_added": "2020-09-17T00:00:00.000Z",
#             "tags": [
#                 "decentralized-exchange-dex-token",
#                 "defi",
#                 "dao",
#                 "yield-farming",
#                 "amm",
#                 "coinbase-ventures-portfolio",
#                 "three-arrows-capital-portfolio",
#                 "governance",
#                 "blockchain-capital-portfolio",
#                 "defiance-capital-portfolio",
#                 "alameda-research-portfolio",
#                 "a16z-portfolio",
#                 "pantera-capital-portfolio",
#                 "parafi-capital",
#                 "paradigm-portfolio",
#                 "arbitrum-ecosytem",
#                 "injective-ecosystem",
#                 "optimism-ecosystem",
#                 "cmc-crypto-awards-2024"
#             ],
#             "max_supply": null,
#             "circulating_supply": 600483073.71,
#             "total_supply": 1000000000,
#             "platform": {
#                 "id": 1027,
#                 "name": "Ethereum",
#                 "symbol": "ETH",
#                 "slug": "ethereum",
#                 "token_address": "0x1f9840a85d5af5bf1d1762f925bdaddc4201f984"
#             },
#             "infinite_supply": false,
#             "cmc_rank": 21,
#             "self_reported_circulating_supply": null,
#             "self_reported_market_cap": null,
#             "tvl_ratio": 1.58349598,
#             "last_updated": "2024-12-22T22:15:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 13.717083870356282,
#                     "volume_24h": 669492763.7159259,
#                     "volume_change_24h": -2.0107,
#                     "percent_change_1h": -2.24674726,
#                     "percent_change_24h": 3.61174644,
#                     "percent_change_7d": -16.4308171,
#                     "percent_change_30d": 44.65522537,
#                     "percent_change_60d": 77.01259735,
#                     "percent_change_90d": 99.78862944,
#                     "market_cap": 8236876684.809403,
#                     "market_cap_dominance": 0.2536,
#                     "fully_diluted_market_cap": 13717083870.36,
#                     "tvl": 5201703562.71899,
#                     "last_updated": "2024-12-22T22:15:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 32196,
#             "name": "Hyperliquid",
#             "symbol": "HYPE",
#             "slug": "hyperliquid",
#             "num_market_pairs": 32,
#             "date_added": "2024-07-15T10:14:50.000Z",
#             "tags": [
#                 "decentralized-exchange-dex-token",
#                 "derivatives",
#                 "layer-1",
#                 "hyperliquid-ecosystem"
#             ],
#             "max_supply": 1000000000,
#             "circulating_supply": 270908567,
#             "total_supply": 999993930,
#             "infinite_supply": false,
#             "platform": null,
#             "cmc_rank": 22,
#             "self_reported_circulating_supply": 333931719,
#             "self_reported_market_cap": 9222787985.878214,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-22T22:15:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 27.618783904377214,
#                     "volume_24h": 489971504.00098604,
#                     "volume_change_24h": -0.6086,
#                     "percent_change_1h": -3.43763164,
#                     "percent_change_24h": -13.92647079,
#                     "percent_change_7d": 20.12123672,
#                     "percent_change_30d": 763.0124346,
#                     "percent_change_60d": 763.0124346,
#                     "percent_change_90d": 763.0124346,
#                     "market_cap": 7482165169.817496,
#                     "market_cap_dominance": 0.2304,
#                     "fully_diluted_market_cap": 27618783904.38,
#                     "tvl": null,
#                     "last_updated": "2024-12-22T22:15:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 2,
#             "name": "Litecoin",
#             "symbol": "LTC",
#             "slug": "litecoin",
#             "num_market_pairs": 1294,
#             "date_added": "2013-04-28T00:00:00.000Z",
#             "tags": [
#                 "mineable",
#                 "pow",
#                 "scrypt",
#                 "medium-of-exchange",
#                 "2017-2018-alt-season"
#             ],
#             "max_supply": 84000000,
#             "circulating_supply": 75335712.05410936,
#             "total_supply": 84000000,
#             "infinite_supply": false,
#             "platform": null,
#             "cmc_rank": 23,
#             "self_reported_circulating_supply": null,
#             "self_reported_market_cap": null,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-22T22:15:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 98.92176612705676,
#                     "volume_24h": 660283464.916997,
#                     "volume_change_24h": -26.7826,
#                     "percent_change_1h": -1.56219976,
#                     "percent_change_24h": -0.58578885,
#                     "percent_change_7d": -14.93646764,
#                     "percent_change_30d": 8.86589447,
#                     "percent_change_60d": 41.94775525,
#                     "percent_change_90d": 47.54435163,
#                     "market_cap": 7452341688.831897,
#                     "market_cap_dominance": 0.2295,
#                     "fully_diluted_market_cap": 8309428354.67,
#                     "tvl": null,
#                     "last_updated": "2024-12-22T22:15:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 24478,
#             "name": "Pepe",
#             "symbol": "PEPE",
#             "slug": "pepe",
#             "num_market_pairs": 495,
#             "date_added": "2023-04-17T06:18:08.000Z",
#             "tags": [
#                 "memes"
#             ],
#             "max_supply": 420690000000000,
#             "circulating_supply": 420689899999994.8,
#             "total_supply": 420689899999994.8,
#             "platform": {
#                 "id": 1027,
#                 "name": "Ethereum",
#                 "symbol": "ETH",
#                 "slug": "ethereum",
#                 "token_address": "0x6982508145454ce325ddbe47a25d4ec3d2311933"
#             },
#             "infinite_supply": false,
#             "cmc_rank": 24,
#             "self_reported_circulating_supply": null,
#             "self_reported_market_cap": null,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-22T22:15:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 1.760144174131035e-05,
#                     "volume_24h": 2273632113.5264335,
#                     "volume_change_24h": -34.1991,
#                     "percent_change_1h": -2.22575089,
#                     "percent_change_24h": 2.91066563,
#                     "percent_change_7d": -23.51331135,
#                     "percent_change_30d": -13.44397709,
#                     "percent_change_60d": 80.50999497,
#                     "percent_change_90d": 117.71359982,
#                     "market_cap": 7404748766.007586,
#                     "market_cap_dominance": 0.228,
#                     "fully_diluted_market_cap": 7404750526.15,
#                     "tvl": null,
#                     "last_updated": "2024-12-22T22:15:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 6535,
# ...
#             "max_supply": null,
#             "circulating_supply": 1145421775.9298017,
#             "total_supply": 1145421775.9298017,
#             "infinite_supply": false,
#             "platform": null,
#             "cmc_rank": 92,
#             "self_reported_circulating_supply": 1145417252.481577,
#             "self_reported_market_cap": 1048040998.2049822,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-22T22:15:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 0.9149862165375748,
#                     "volume_24h": 29462664.09734765,
#                     "volume_change_24h": -10.4465,
#                     "percent_change_1h": -2.07729419,
#                     "percent_change_24h": 0.80839715,
#                     "percent_change_7d": -18.52563483,
#                     "percent_change_30d": 11.86160741,
#                     "percent_change_60d": 104.8418444,
#                     "percent_change_90d": 91.53017582,
#                     "market_cap": 1048045137.097759,
#                     "market_cap_dominance": 0.0323,
#                     "fully_diluted_market_cap": 1048045137.1,
#                     "tvl": null,
#                     "last_updated": "2024-12-22T22:15:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 22691,
#             "name": "Starknet",
#             "symbol": "STRK",
#             "slug": "starknet-token",
#             "num_market_pairs": 209,
#             "date_added": "2024-02-20T12:19:19.000Z",
#             "tags": [
#                 "zero-knowledge-proofs",
#                 "dapp",
#                 "ethereum-ecosystem",
#                 "layer-2",
#                 "rollups"
#             ],
#             "max_supply": 10000000000,
#             "circulating_supply": 2259283720,
#             "total_supply": 10000000000,
#             "platform": {
#                 "id": 1027,
#                 "name": "Ethereum",
#                 "symbol": "ETH",
#                 "slug": "ethereum",
#                 "token_address": "0xCa14007Eff0dB1f8135f4C25B34De49AB0d42766"
#             },
#             "infinite_supply": false,
#             "cmc_rank": 93,
#             "self_reported_circulating_supply": 2259283720,
#             "self_reported_market_cap": 1043752660.8313644,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-22T22:15:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 0.46198388081659986,
#                     "volume_24h": 115353822.5269195,
#                     "volume_change_24h": -26.6397,
#                     "percent_change_1h": -1.68953971,
#                     "percent_change_24h": -0.93385257,
#                     "percent_change_7d": -25.38845588,
#                     "percent_change_30d": -11.35945981,
#                     "percent_change_60d": 16.0188159,
#                     "percent_change_90d": 14.58230346,
#                     "market_cap": 1043752660.8313644,
#                     "market_cap_dominance": 0.0321,
#                     "fully_diluted_market_cap": 4619838808.17,
#                     "tvl": null,
#                     "last_updated": "2024-12-22T22:15:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 3602,
#             "name": "Bitcoin SV",
#             "symbol": "BSV",
#             "slug": "bitcoin-sv",
#             "num_market_pairs": 261,
#             "date_added": "2018-11-09T00:00:00.000Z",
#             "tags": [
#                 "mineable",
#                 "pow",
#                 "sha-256",
#                 "medium-of-exchange",
#                 "store-of-value",
#                 "state-channel",
#                 "bitcoin-ecosystem",
#                 "2017-2018-alt-season"
#             ],
#             "max_supply": null,
#             "circulating_supply": 19800943.75,
#             "total_supply": 19800943.75,
#             "infinite_supply": false,
#             "platform": null,
#             "cmc_rank": 94,
#             "self_reported_circulating_supply": null,
#             "self_reported_market_cap": null,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-22T22:15:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 52.22046406726391,
#                     "volume_24h": 54973870.32318244,
#                     "volume_change_24h": -17.8542,
#                     "percent_change_1h": -1.20368888,
#                     "percent_change_24h": 0.47469387,
#                     "percent_change_7d": -19.23678972,
#                     "percent_change_30d": -22.51091426,
#                     "percent_change_60d": 11.96229668,
#                     "percent_change_90d": 6.45798291,
#                     "market_cap": 1034014471.5947889,
#                     "market_cap_dominance": 0.0318,
#                     "fully_diluted_market_cap": 1034014471.59,
#                     "tvl": null,
#                     "last_updated": "2024-12-22T22:15:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 1720,
#             "name": "IOTA",
#             "symbol": "IOTA",
#             "slug": "iota",
#             "num_market_pairs": 168,
#             "date_added": "2017-06-13T00:00:00.000Z",
#             "tags": [
#                 "dag",
#                 "medium-of-exchange",
#                 "iot",
#                 "sharing-economy",
#                 "real-world-assets",
#                 "dwf-labs-portfolio",
#                 "depin",
#                 "2017-2018-alt-season"
#             ],
#             "max_supply": null,
#             "circulating_supply": 3554846536,
#             "total_supply": 3554846536,
#             "infinite_supply": false,
#             "platform": null,
#             "cmc_rank": 95,
#             "self_reported_circulating_supply": null,
#             "self_reported_market_cap": null,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-22T22:15:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 0.2878596256825436,
#                     "volume_24h": 56723422.99519151,
#                     "volume_change_24h": -38.2719,
#                     "percent_change_1h": -1.55756548,
#                     "percent_change_24h": 0.73752912,
#                     "percent_change_7d": -24.29081591,
#                     "percent_change_30d": 49.71432934,
#                     "percent_change_60d": 149.66842775,
#                     "percent_change_90d": 103.38183456,
#                     "market_cap": 1023296793.2118467,
#                     "market_cap_dominance": 0.0315,
#                     "fully_diluted_market_cap": 1023296793.21,
#                     "tvl": null,
#                     "last_updated": "2024-12-22T22:15:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 6538,
#             "name": "Curve DAO Token",
#             "symbol": "CRV",
#             "slug": "curve-dao-token",
#             "num_market_pairs": 786,
#             "date_added": "2020-08-14T00:00:00.000Z",
#             "tags": [
#                 "decentralized-exchange-dex-token",
#                 "defi",
#                 "dao",
#                 "yield-farming",
#                 "amm",
#                 "governance",
#                 "framework-ventures-portfolio",
#                 "alameda-research-portfolio",
#                 "polygon-ecosystem",
#                 "fantom-ecosystem",
#                 "arbitrum-ecosytem",
#                 "optimism-ecosystem",
#                 "dwf-labs-portfolio"
#             ],
#             "max_supply": null,
#             "circulating_supply": 1255622525,
#             "total_supply": 2206615497.4134026,
#             "platform": {
#                 "id": 1027,
#                 "name": "Ethereum",
#                 "symbol": "ETH",
#                 "slug": "ethereum",
#                 "token_address": "0xD533a949740bb3306d119CC777fa900bA034cd52"
#             },
#             "infinite_supply": false,
#             "cmc_rank": 96,
#             "self_reported_circulating_supply": null,
#             "self_reported_market_cap": null,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-22T22:15:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 0.8111778795770045,
#                     "volume_24h": 345537436.41687393,
#                     "volume_change_24h": -25.6093,
#                     "percent_change_1h": -1.99177498,
#                     "percent_change_24h": 3.4223101,
#                     "percent_change_7d": -24.60511356,
#                     "percent_change_30d": 79.82166178,
#                     "percent_change_60d": 221.53522606,
#                     "percent_change_90d": 173.35718481,
#                     "market_cap": 1018533217.3786243,
#                     "market_cap_dominance": 0.0314,
#                     "fully_diluted_market_cap": 1789957680.23,
#                     "tvl": null,
#                     "last_updated": "2024-12-22T22:15:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 28324,
#             "name": "dYdX (Native)",
#             "symbol": "DYDX",
#             "slug": "dydx-chain",
#             "num_market_pairs": 209,
#             "date_added": "2021-08-03T00:00:00.000Z",
#             "tags": [
#                 "decentralized-exchange-dex-token"
#             ],
#             "max_supply": null,
#             "circulating_supply": 711239959.5935245,
#             "total_supply": 773782706.07,
#             "platform": {
#                 "id": 12220,
#                 "name": "Osmosis",
#                 "symbol": "OSMO",
#                 "slug": "osmosis",
#                 "token_address": "ibc/831F0B1BBB1D08A2B75311892876D71565478C532967545476DF4C2D7492E48C"
#             },
#             "infinite_supply": false,
#             "cmc_rank": 97,
#             "self_reported_circulating_supply": 501325666.72,
#             "self_reported_market_cap": 710236923.1656411,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-22T22:15:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 1.4167176554363852,
#                     "volume_24h": 52410825.74648169,
#                     "volume_change_24h": -28.8888,
#                     "percent_change_1h": -1.2811793,
#                     "percent_change_24h": 0.74550187,
#                     "percent_change_7d": -31.00835787,
#                     "percent_change_30d": 10.40139029,
#                     "percent_change_60d": 30.95130042,
#                     "percent_change_90d": 48.57255122,
#                     "market_cap": 1007626208.0080073,
#                     "market_cap_dominance": 0.031,
#                     "fully_diluted_market_cap": 1096231621.16,
#                     "tvl": null,
#                     "last_updated": "2024-12-22T22:15:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 23254,
#             "name": "Core",
#             "symbol": "CORE",
#             "slug": "core-dao",
#             "num_market_pairs": 83,
#             "date_added": "2023-02-08T12:26:11.000Z",
#             "tags": [],
#             "max_supply": 2100000000,
#             "circulating_supply": 930157598.0033675,
#             "total_supply": 2093769839.0352812,
#             "infinite_supply": false,
#             "platform": null,
#             "cmc_rank": 98,
#             "self_reported_circulating_supply": null,
#             "self_reported_market_cap": null,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-22T22:15:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 1.0616643576209905,
#                     "volume_24h": 58327147.8095191,
#                     "volume_change_24h": -36.1448,
#                     "percent_change_1h": -1.17669577,
#                     "percent_change_24h": -4.1568349,
#                     "percent_change_7d": -21.00889636,
#                     "percent_change_30d": 9.88777754,
#                     "percent_change_60d": 17.61643479,
#                     "percent_change_90d": 1.3057294,
#                     "market_cap": 987515168.7705288,
#                     "market_cap_dominance": 0.0304,
#                     "fully_diluted_market_cap": 2229495151,
#                     "tvl": null,
#                     "last_updated": "2024-12-22T22:15:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 1376,
#             "name": "Neo",
#             "symbol": "NEO",
#             "slug": "neo",
#             "num_market_pairs": 357,
#             "date_added": "2016-09-08T00:00:00.000Z",
#             "tags": [
#                 "platform",
#                 "enterprise-solutions",
#                 "smart-contracts",
#                 "2017-2018-alt-season"
#             ],
#             "max_supply": 100000000,
#             "circulating_supply": 70538831,
#             "total_supply": 100000000,
#             "infinite_supply": false,
#             "platform": null,
#             "cmc_rank": 99,
#             "self_reported_circulating_supply": null,
#             "self_reported_market_cap": null,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-22T22:15:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 13.902983160661663,
#                     "volume_24h": 44771602.18955094,
#                     "volume_change_24h": -16.6308,
#                     "percent_change_1h": -1.1931807,
#                     "percent_change_24h": 1.93416737,
#                     "percent_change_7d": -20.88467961,
#                     "percent_change_30d": 2.4652085,
#                     "percent_change_60d": 38.28337415,
#                     "percent_change_90d": 39.02939419,
#                     "market_cap": 980700179.5657588,
#                     "market_cap_dominance": 0.0302,
#                     "fully_diluted_market_cap": 1390298316.07,
#                     "tvl": null,
#                     "last_updated": "2024-12-22T22:15:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 4195,
#             "name": "FTX Token",
#             "symbol": "FTT",
#             "slug": "ftx-token",
#             "num_market_pairs": 240,
#             "date_added": "2019-07-31T00:00:00.000Z",
#             "tags": [
#                 "marketplace",
#                 "centralized-exchange",
#                 "derivatives",
#                 "cms-holdings-portfolio",
#                 "kenetic-capital-portfolio",
#                 "alameda-research-portfolio",
#                 "pantera-capital-portfolio",
#                 "exnetwork-capital-portfolio",
#                 "ftx-bankruptcy-estate",
#                 "alleged-sec-securities",
#                 "celsius-bankruptcy-estate"
#             ],
#             "max_supply": null,
#             "circulating_supply": 328895103.813207,
#             "total_supply": 328895103.813207,
#             "platform": {
#                 "id": 1839,
#                 "name": "BNB Beacon Chain (BEP2)",
#                 "symbol": "BNB",
#                 "slug": "bnb",
#                 "token_address": "FTT-F11"
#             },
#             "infinite_supply": false,
#             "cmc_rank": 100,
#             "self_reported_circulating_supply": null,
#             "self_reported_market_cap": null,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-22T22:15:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 2.8858016931857704,
#                     "volume_24h": 51280029.78643229,
#                     "volume_change_24h": 55.619,
#                     "percent_change_1h": -0.35778149,
#                     "percent_change_24h": 8.00833419,
#                     "percent_change_7d": 8.12951934,
#                     "percent_change_30d": 17.951637,
#                     "percent_change_60d": 48.28276408,
#                     "percent_change_90d": 113.2651985,
#                     "market_cap": 949126047.4646624,
#                     "market_cap_dominance": 0.0292,
#                     "fully_diluted_market_cap": 949126047.46,
#                     "tvl": null,
#                     "last_updated": "2024-12-22T22:15:00.000Z"
#                 }
#             }
#         }
#     ]
# }

# %%
# Database Configuration
DB_USER = "postgres"
DB_HOST = "localhost"
DB_PORT = "5432"
DB_NAME = "signal"
table_name = "crypto_price_history"
DATABASE_URL = f"postgresql+psycopg2://{DB_USER}@{DB_HOST}:{DB_PORT}/{DB_NAME}"
engine = create_engine(DATABASE_URL)

from sqlalchemy import inspect
inspector = inspect(engine)
if "crypto_price_history" not in inspector.get_table_names():
    print("Table 'crypto_price_history' does not exist.")
else:
    print(inspector.get_columns("crypto_price_history"))
# Out:
# [{'name': 'id', 'type': INTEGER(), 'nullable': False, 'default': "nextval('crypto_price_history_id_seq'::regclass)", 'autoincrement': True, 'comment': None}, {'name': 'symbol', 'type': VARCHAR(length=10), 'nullable': False, 'default': None, 'autoincrement': False, 'comment': None}, {'name': 'name', 'type': VARCHAR(length=50), 'nullable': True, 'default': None, 'autoincrement': False, 'comment': None}, {'name': 'cmc_rank', 'type': INTEGER(), 'nullable': True, 'default': None, 'autoincrement': False, 'comment': None}, {'name': 'price', 'type': NUMERIC(precision=20, scale=8), 'nullable': True, 'default': None, 'autoincrement': False, 'comment': None}, {'name': 'volume_24h', 'type': NUMERIC(precision=20, scale=8), 'nullable': True, 'default': None, 'autoincrement': False, 'comment': None}, {'name': 'market_cap', 'type': NUMERIC(precision=20, scale=8), 'nullable': True, 'default': None, 'autoincrement': False, 'comment': None}, {'name': 'market_cap_dominance', 'type': NUMERIC(precision=5, scale=2), 'nullable': True, 'default': None, 'autoincrement': False, 'comment': None}, {'name': 'circulating_supply', 'type': NUMERIC(precision=20, scale=8), 'nullable': True, 'default': None, 'autoincrement': False, 'comment': None}, {'name': 'max_supply', 'type': NUMERIC(precision=20, scale=8), 'nullable': True, 'default': None, 'autoincrement': False, 'comment': None}, {'name': 'percent_change_1h', 'type': NUMERIC(precision=8, scale=4), 'nullable': True, 'default': None, 'autoincrement': False, 'comment': None}, {'name': 'percent_change_24h', 'type': NUMERIC(precision=8, scale=4), 'nullable': True, 'default': None, 'autoincrement': False, 'comment': None}, {'name': 'percent_change_7d', 'type': NUMERIC(precision=8, scale=4), 'nullable': True, 'default': None, 'autoincrement': False, 'comment': None}, {'name': 'last_updated', 'type': TIMESTAMP(), 'nullable': True, 'default': None, 'autoincrement': False, 'comment': None}, {'name': 'pulled_at', 'type': TIMESTAMP(), 'nullable': True, 'default': 'now()', 'autoincrement': False, 'comment': None}]

# %%
import requests
import pandas as pd


# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = 'https://www.alphavantage.co/query?function=TREASURY_YIELD&interval=daily&maturity=10year&apikey=SFRHBUTCXB3RDG5S'
r = requests.get(url)
data = r.json()

df = pd.DataFrame(data['data'])
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[28], line 10
#       7 r = requests.get(url)
#       8 data = r.json()
# ---> 10 df = pd.DataFrame(data['data'])
#      11 df.head()
#
# KeyError: 'data'

# %%
import requests
import pandas as pd

# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = 'https://www.alphavantage.co/query?function=FEDERAL_FUNDS_RATE&interval=daily&apikey=SFRHBUTCXB3RDG5S'
r = requests.get(url)
data = r.json()

df = pd.DataFrame(data['data'])
df.head()
# Out:
#          date value
# 0  2025-01-02  4.33
# 1  2025-01-01  4.33
# 2  2024-12-31  4.33
# 3  2024-12-30  4.33
# 4  2024-12-29  4.33

# %%
import requests
import pandas as pd

# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = 'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=VOO&apikey=SFRHBUTCXB3RDG5S'
r = requests.get(url)
data = r.json()

time_series = data['Time Series (Daily)']

df = pd.DataFrame.from_dict(time_series, orient='index')

df.rename(columns={
    '1. open': 'open',
    '2. high': 'high',
    '3. low': 'low',
    '4. close': 'close',
    '5. volume': 'volume'
}, inplace=True)

df.index = pd.to_datetime(df.index)
df.reset_index(inplace=True)

# Rename the index column to 'date'
df.rename(columns={'index': 'date'}, inplace=True)

# Ensure numerical columns are of the correct type
for col in ['open', 'high', 'low', 'close', 'volume']:
    df[col] = pd.to_numeric(df[col])

df.head()
# Out:
#         date    open      high       low   close   volume
# 0 2025-01-03  540.19  544.8800  539.2000  544.40  6419663
# 1 2025-01-02  542.02  543.5399  533.7950  537.46  7142698
# 2 2024-12-31  542.45  543.0651  537.4001  538.81  6040750
# 3 2024-12-30  540.56  544.0900  537.4000  540.99  6505089
# 4 2024-12-27  549.37  549.6200  543.2001  547.08  7077135

# %%
import requests
import pandas as pd

# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = 'https://www.alphavantage.co/query?function=NEWS_SENTIMENT&CRYPTO:BTC&apikey=SFRHBUTCXB3RDG5S'
r = requests.get(url)
data = r.json()

feed_data = data['feed']

df = pd.DataFrame(feed_data)

df.head()
# Out:
#                                                title
# 0  ROSEN, SKILLED INVESTOR COUNSEL, Encourages Tr...  \
# 1  ROSEN, A LEADING LAW FIRM, Encourages Cassava ...
# 2  'Don't Invest In Rap, Restaurant And Liquor Co...
# 3                                Before you continue
# 4  Ray Dalio's Timeless Advice: 'If You Don't Own...
#
#                                                  url   time_published
# 0  https://www.benzinga.com/pressreleases/25/01/g...  20250105T172500  \
# 1  https://www.benzinga.com/pressreleases/25/01/g...  20250105T171200
# 2  https://www.benzinga.com/news/25/01/42805180/d...  20250105T170217
# 3                       https://consent.google.com/m  20250105T165341
# 4  https://www.benzinga.com/markets/25/01/4280513...  20250105T164715
#
#             authors                                            summary
# 0  [Globe Newswire]  NEW YORK, Jan. 05, 2025 ( GLOBE NEWSWIRE ) -- ...  \
# 1  [Globe Newswire]  NEW YORK, Jan. 05, 2025 ( GLOBE NEWSWIRE ) -- ...
# 2  [Adrian Volenik]  Mark Cuban, billionaire investor and part-owne...
# 3                []  Looking back to look ahead to 2025: Economy, c...
# 4  [Bibhu Pattnaik]  Ray Dalio predicts a looming economic shift, u...
#
#                                         banner_image             source
# 0  https://www.benzinga.com/next-assets/images/sc...           Benzinga  \
# 1  https://www.benzinga.com/next-assets/images/sc...           Benzinga
# 2  https://cdn.benzinga.com/files/images/story/20...           Benzinga
# 3                                               None  Business Standard
# 4  https://cdn.benzinga.com/files/images/story/20...           Benzinga
#
#   category_within_source       source_domain
# 0                   News    www.benzinga.com  \
# 1                   News    www.benzinga.com
# 2                   News    www.benzinga.com
# 3              GoogleRSS  consent.google.com
# 4                Markets    www.benzinga.com
#
#                                               topics  overall_sentiment_score
# 0  [{'topic': 'Energy & Transportation', 'relevan...                 0.182901  \
# 1  [{'topic': 'Life Sciences', 'relevance_score':...                 0.217214
# 2  [{'topic': 'Life Sciences', 'relevance_score':...                 0.464739
# 3  [{'topic': 'Technology', 'relevance_score': '1...                 0.086343
# 4  [{'topic': 'Economy - Monetary', 'relevance_sc...                 0.111100
#
#   overall_sentiment_label                                   ticker_sentiment
# 0        Somewhat-Bullish  [{'ticker': 'META', 'relevance_score': '0.0621...
# 1        Somewhat-Bullish  [{'ticker': 'META', 'relevance_score': '0.0600...
# 2                 Bullish  [{'ticker': 'ABNB', 'relevance_score': '0.0641...
# 3                 Neutral  [{'ticker': 'GOOG', 'relevance_score': '0.2130...
# 4                 Neutral                                                 []
