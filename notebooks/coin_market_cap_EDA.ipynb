# %%
import requests
import json
import pandas as pd
from sqlalchemy import create_engine
from datetime import datetime

# Replace 'YOUR_API_KEY' with your actual CoinMarketCap API key
api_key = '42485936-1986-4342-9e0a-e854c8b0fe47'
url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'

parameters = {
    'start': '1',
    'limit': '100',  # Number of cryptocurrencies to retrieve
    'convert': 'USD'  # Convert prices to USD
}

headers = {
    'Accepts': 'application/json',
    'X-CMC_PRO_API_KEY': api_key,
}

response = requests.get(url, headers=headers, params=parameters)
data = response.json()

# Pretty-print the JSON response
print(json.dumps(data, indent=4))
# Out:
# {
#     "status": {
#         "timestamp": "2024-12-16T02:47:16.891Z",
#         "error_code": 0,
#         "error_message": null,
#         "elapsed": 14,
#         "credit_count": 1,
#         "notice": null,
#         "total_count": 10311
#     },
#     "data": [
#         {
#             "id": 1,
#             "name": "Bitcoin",
#             "symbol": "BTC",
#             "slug": "bitcoin",
#             "num_market_pairs": 11841,
#             "date_added": "2010-07-13T00:00:00.000Z",
#             "tags": [
#                 "mineable",
#                 "pow",
#                 "sha-256",
#                 "store-of-value",
#                 "state-channel",
#                 "coinbase-ventures-portfolio",
#                 "three-arrows-capital-portfolio",
#                 "polychain-capital-portfolio",
#                 "binance-labs-portfolio",
#                 "blockchain-capital-portfolio",
#                 "boostvc-portfolio",
#                 "cms-holdings-portfolio",
#                 "dcg-portfolio",
#                 "dragonfly-capital-portfolio",
#                 "electric-capital-portfolio",
#                 "fabric-ventures-portfolio",
#                 "framework-ventures-portfolio",
#                 "galaxy-digital-portfolio",
#                 "huobi-capital-portfolio",
#                 "alameda-research-portfolio",
#                 "a16z-portfolio",
#                 "1confirmation-portfolio",
#                 "winklevoss-capital-portfolio",
#                 "usv-portfolio",
#                 "placeholder-ventures-portfolio",
#                 "pantera-capital-portfolio",
#                 "multicoin-capital-portfolio",
#                 "paradigm-portfolio",
#                 "bitcoin-ecosystem",
#                 "ftx-bankruptcy-estate",
#                 "2017-2018-alt-season"
#             ],
#             "max_supply": 21000000,
#             "circulating_supply": 19796690,
#             "total_supply": 19796690,
#             "infinite_supply": false,
#             "platform": null,
#             "cmc_rank": 1,
#             "self_reported_circulating_supply": null,
#             "self_reported_market_cap": null,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-16T02:44:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 104627.18305064192,
#                     "volume_24h": 60728419585.20978,
#                     "volume_change_24h": 62.2763,
#                     "percent_change_1h": -0.53373192,
#                     "percent_change_24h": 2.81085312,
#                     "percent_change_7d": 5.37791902,
#                     "percent_change_30d": 14.39221882,
#                     "percent_change_60d": 55.01418348,
#                     "percent_change_90d": 80.06921476,
#                     "market_cap": 2071271908426.8125,
#                     "market_cap_dominance": 55.9182,
#                     "fully_diluted_market_cap": 2197170844063.48,
#                     "tvl": null,
#                     "last_updated": "2024-12-16T02:44:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 1027,
#             "name": "Ethereum",
#             "symbol": "ETH",
#             "slug": "ethereum",
#             "num_market_pairs": 9682,
#             "date_added": "2015-08-07T00:00:00.000Z",
#             "tags": [
#                 "pos",
#                 "smart-contracts",
#                 "ethereum-ecosystem",
#                 "coinbase-ventures-portfolio",
#                 "three-arrows-capital-portfolio",
#                 "polychain-capital-portfolio",
#                 "binance-labs-portfolio",
#                 "blockchain-capital-portfolio",
#                 "boostvc-portfolio",
#                 "cms-holdings-portfolio",
#                 "dcg-portfolio",
#                 "dragonfly-capital-portfolio",
#                 "electric-capital-portfolio",
#                 "fabric-ventures-portfolio",
#                 "framework-ventures-portfolio",
#                 "hashkey-capital-portfolio",
#                 "kenetic-capital-portfolio",
#                 "huobi-capital-portfolio",
#                 "alameda-research-portfolio",
#                 "a16z-portfolio",
#                 "1confirmation-portfolio",
#                 "winklevoss-capital-portfolio",
#                 "usv-portfolio",
#                 "placeholder-ventures-portfolio",
#                 "pantera-capital-portfolio",
#                 "multicoin-capital-portfolio",
#                 "paradigm-portfolio",
#                 "layer-1",
#                 "ftx-bankruptcy-estate"
#             ],
#             "max_supply": null,
#             "circulating_supply": 120450223.41769607,
#             "total_supply": 120450223.41769607,
#             "infinite_supply": true,
#             "platform": null,
#             "cmc_rank": 2,
#             "self_reported_circulating_supply": null,
#             "self_reported_market_cap": null,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-16T02:45:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 3971.1099880945785,
#                     "volume_24h": 30184836183.890614,
#                     "volume_change_24h": 9.4671,
#                     "percent_change_1h": -0.60036099,
#                     "percent_change_24h": 2.22866404,
#                     "percent_change_7d": 0.70772966,
#                     "percent_change_30d": 27.49244426,
#                     "percent_change_60d": 51.3603422,
#                     "percent_change_90d": 73.69306268,
#                     "market_cap": 478321085282.2364,
#                     "market_cap_dominance": 12.9162,
#                     "fully_diluted_market_cap": 478321085282.24,
#                     "tvl": null,
#                     "last_updated": "2024-12-16T02:45:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 825,
#             "name": "Tether USDt",
#             "symbol": "USDT",
#             "slug": "tether",
#             "num_market_pairs": 108430,
#             "date_added": "2015-02-25T00:00:00.000Z",
#             "tags": [
#                 "stablecoin",
#                 "asset-backed-stablecoin",
#                 "avalanche-ecosystem",
#                 "solana-ecosystem",
#                 "arbitrum-ecosytem",
#                 "moonriver-ecosystem",
#                 "injective-ecosystem",
#                 "bnb-chain",
#                 "usd-stablecoin",
#                 "optimism-ecosystem",
#                 "fiat-stablecoin"
#             ],
#             "max_supply": null,
#             "circulating_supply": 140253672849.4435,
#             "total_supply": 143442815980.71503,
#             "platform": {
#                 "id": 1027,
#                 "name": "Ethereum",
#                 "symbol": "ETH",
#                 "slug": "ethereum",
#                 "token_address": "0xdac17f958d2ee523a2206206994597c13d831ec7"
#             },
#             "infinite_supply": true,
#             "cmc_rank": 3,
#             "self_reported_circulating_supply": null,
#             "self_reported_market_cap": null,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-16T02:44:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 0.9994591805917705,
#                     "volume_24h": 126808222355.33275,
#                     "volume_change_24h": 26.292,
#                     "percent_change_1h": 0.00337728,
#                     "percent_change_24h": -0.02219209,
#                     "percent_change_7d": -0.12919312,
#                     "percent_change_30d": -0.10560676,
#                     "percent_change_60d": -0.02417533,
#                     "percent_change_90d": -0.04721494,
#                     "market_cap": 140177820941.09106,
#                     "market_cap_dominance": 3.7844,
#                     "fully_diluted_market_cap": 143365239321.86,
#                     "tvl": null,
#                     "last_updated": "2024-12-16T02:44:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 52,
#             "name": "XRP",
#             "symbol": "XRP",
#             "slug": "xrp",
#             "num_market_pairs": 1478,
#             "date_added": "2013-08-04T00:00:00.000Z",
#             "tags": [
#                 "medium-of-exchange",
#                 "enterprise-solutions",
#                 "arrington-xrp-capital-portfolio",
#                 "galaxy-digital-portfolio",
#                 "a16z-portfolio",
#                 "pantera-capital-portfolio",
#                 "ftx-bankruptcy-estate",
#                 "2017-2018-alt-season"
#             ],
#             "max_supply": 100000000000,
#             "circulating_supply": 57187870382,
#             "total_supply": 99986858106,
#             "infinite_supply": false,
#             "platform": null,
#             "cmc_rank": 4,
#             "self_reported_circulating_supply": null,
#             "self_reported_market_cap": null,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-16T02:45:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 2.4144926581856345,
#                     "volume_24h": 6615564190.752316,
#                     "volume_change_24h": -11.3782,
#                     "percent_change_1h": -0.95482562,
#                     "percent_change_24h": -0.29573326,
#                     "percent_change_7d": -2.44945998,
#                     "percent_change_30d": 170.25089321,
#                     "percent_change_60d": 341.74402011,
#                     "percent_change_90d": 313.35172593,
#                     "market_cap": 138079693174.6107,
#                     "market_cap_dominance": 3.7289,
#                     "fully_diluted_market_cap": 241449265818.56,
#                     "tvl": null,
#                     "last_updated": "2024-12-16T02:45:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 5426,
#             "name": "Solana",
#             "symbol": "SOL",
#             "slug": "solana",
#             "num_market_pairs": 809,
#             "date_added": "2020-04-10T00:00:00.000Z",
#             "tags": [
#                 "pos",
#                 "platform",
#                 "solana-ecosystem",
#                 "cms-holdings-portfolio",
#                 "kenetic-capital-portfolio",
#                 "alameda-research-portfolio",
#                 "multicoin-capital-portfolio",
#                 "okx-ventures-portfolio",
#                 "layer-1",
#                 "ftx-bankruptcy-estate",
#                 "alleged-sec-securities",
#                 "cmc-crypto-awards-2024"
#             ],
#             "max_supply": null,
#             "circulating_supply": 479143909.6084545,
#             "total_supply": 590246857.9054407,
#             "infinite_supply": true,
#             "platform": null,
#             "cmc_rank": 5,
#             "self_reported_circulating_supply": null,
#             "self_reported_market_cap": null,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-16T02:45:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 223.013612810306,
#                     "volume_24h": 3426023818.906196,
#                     "volume_change_24h": 21.3903,
#                     "percent_change_1h": -1.21291747,
#                     "percent_change_24h": 0.84445286,
#                     "percent_change_7d": -3.61696907,
#                     "percent_change_30d": 1.56066849,
#                     "percent_change_60d": 44.64643736,
#                     "percent_change_90d": 69.80077058,
#                     "market_cap": 106855614337.83614,
#                     "market_cap_dominance": 2.8856,
#                     "fully_diluted_market_cap": 131633084231.42,
#                     "tvl": null,
#                     "last_updated": "2024-12-16T02:45:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 1839,
#             "name": "BNB",
#             "symbol": "BNB",
#             "slug": "bnb",
#             "num_market_pairs": 2305,
#             "date_added": "2017-07-25T00:00:00.000Z",
#             "tags": [
#                 "marketplace",
#                 "centralized-exchange",
#                 "payments",
#                 "smart-contracts",
#                 "alameda-research-portfolio",
#                 "multicoin-capital-portfolio",
#                 "bnb-chain",
#                 "layer-1",
#                 "alleged-sec-securities",
#                 "celsius-bankruptcy-estate"
#             ],
#             "max_supply": null,
#             "circulating_supply": 144008294.1,
#             "total_supply": 144008294.1,
#             "infinite_supply": false,
#             "platform": null,
#             "cmc_rank": 6,
#             "self_reported_circulating_supply": null,
#             "self_reported_market_cap": null,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-16T02:45:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 713.7478876019771,
#                     "volume_24h": 1986333373.0189416,
#                     "volume_change_24h": 6.2903,
#                     "percent_change_1h": -0.75840371,
#                     "percent_change_24h": -0.4204814,
#                     "percent_change_7d": -1.06225333,
#                     "percent_change_30d": 14.75566134,
#                     "percent_change_60d": 18.33690128,
#                     "percent_change_90d": 33.65652278,
#                     "market_cap": 102785615711.03926,
#                     "market_cap_dominance": 2.7755,
#                     "fully_diluted_market_cap": 102785615711.04,
#                     "tvl": null,
#                     "last_updated": "2024-12-16T02:45:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 74,
#             "name": "Dogecoin",
#             "symbol": "DOGE",
#             "slug": "dogecoin",
#             "num_market_pairs": 1128,
#             "date_added": "2013-12-15T00:00:00.000Z",
#             "tags": [
#                 "mineable",
#                 "pow",
#                 "scrypt",
#                 "medium-of-exchange",
#                 "memes",
#                 "payments",
#                 "doggone-doggerel",
#                 "bnb-chain",
#                 "ftx-bankruptcy-estate"
#             ],
#             "max_supply": null,
#             "circulating_supply": 147218346383.7052,
#             "total_supply": 147218346383.7052,
#             "infinite_supply": true,
#             "platform": null,
#             "cmc_rank": 7,
#             "self_reported_circulating_supply": null,
#             "self_reported_market_cap": null,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-16T02:45:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 0.40742843712706356,
#                     "volume_24h": 2957345538.972241,
#                     "volume_change_24h": -3.6101,
#                     "percent_change_1h": -0.73941969,
#                     "percent_change_24h": 2.24936405,
#                     "percent_change_7d": -9.69176867,
#                     "percent_change_30d": 6.58589055,
#                     "percent_change_60d": 227.84708252,
#                     "percent_change_90d": 309.35189382,
#                     "market_cap": 59980940783.5437,
#                     "market_cap_dominance": 1.6198,
#                     "fully_diluted_market_cap": 59980940783.54,
#                     "tvl": null,
#                     "last_updated": "2024-12-16T02:45:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 3408,
#             "name": "USDC",
#             "symbol": "USDC",
#             "slug": "usd-coin",
#             "num_market_pairs": 23860,
#             "date_added": "2018-10-08T00:00:00.000Z",
#             "tags": [
#                 "medium-of-exchange",
#                 "stablecoin",
#                 "asset-backed-stablecoin",
#                 "coinbase-ventures-portfolio",
#                 "solana-ecosystem",
#                 "hedera-hashgraph-ecosystem",
#                 "arbitrum-ecosytem",
#                 "moonriver-ecosystem",
#                 "bnb-chain",
#                 "usd-stablecoin",
#                 "optimism-ecosystem",
#                 "base-ecosystem",
#                 "fiat-stablecoin"
#             ],
#             "max_supply": null,
#             "circulating_supply": 42128104328.03739,
#             "total_supply": 42128104328.03739,
#             "platform": {
#                 "id": 1027,
#                 "name": "Ethereum",
#                 "symbol": "ETH",
#                 "slug": "ethereum",
#                 "token_address": "0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48"
#             },
#             "infinite_supply": false,
#             "cmc_rank": 8,
#             "self_reported_circulating_supply": null,
#             "self_reported_market_cap": null,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-16T02:45:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 0.9999395539923663,
#                     "volume_24h": 8544464209.661106,
#                     "volume_change_24h": 45.1685,
#                     "percent_change_1h": 0.0137044,
#                     "percent_change_24h": 0.0093029,
#                     "percent_change_7d": -0.00502863,
#                     "percent_change_30d": 0.00487791,
#                     "percent_change_60d": 0.0168177,
#                     "percent_change_90d": -0.00280456,
#                     "market_cap": 42125557852.32159,
#                     "market_cap_dominance": 1.1375,
#                     "fully_diluted_market_cap": 42125557852.32,
#                     "tvl": null,
#                     "last_updated": "2024-12-16T02:45:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 2010,
#             "name": "Cardano",
#             "symbol": "ADA",
#             "slug": "cardano",
#             "num_market_pairs": 1389,
#             "date_added": "2017-10-01T00:00:00.000Z",
#             "tags": [
#                 "dpos",
#                 "pos",
#                 "platform",
#                 "research",
#                 "smart-contracts",
#                 "staking",
#                 "cardano-ecosystem",
#                 "cardano",
#                 "layer-1",
#                 "alleged-sec-securities",
#                 "2017-2018-alt-season"
#             ],
#             "max_supply": 45000000000,
#             "circulating_supply": 35119317307.65075,
#             "total_supply": 44995089702.96723,
#             "infinite_supply": false,
#             "platform": null,
#             "cmc_rank": 9,
#             "self_reported_circulating_supply": null,
#             "self_reported_market_cap": null,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-16T02:45:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 1.0852645841130173,
#                     "volume_24h": 1147632872.3334687,
#                     "volume_change_24h": -72.8575,
#                     "percent_change_1h": -1.97932878,
#                     "percent_change_24h": 1.23755328,
#                     "percent_change_7d": -6.76200161,
#                     "percent_change_30d": 49.01949573,
#                     "percent_change_60d": 208.66800071,
#                     "percent_change_90d": 227.22840644,
#                     "market_cap": 38113751292.22068,
#                     "market_cap_dominance": 1.0292,
#                     "fully_diluted_market_cap": 48836906285.09,
#                     "tvl": null,
#                     "last_updated": "2024-12-16T02:45:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 1958,
#             "name": "TRON",
#             "symbol": "TRX",
#             "slug": "tron",
#             "num_market_pairs": 1082,
#             "date_added": "2017-09-13T00:00:00.000Z",
#             "tags": [
#                 "media",
#                 "payments",
#                 "tron-ecosystem",
#                 "layer-1",
#                 "dwf-labs-portfolio",
#                 "alleged-sec-securities",
#                 "2017-2018-alt-season"
#             ],
#             "max_supply": null,
#             "circulating_supply": 86242235774.70238,
#             "total_supply": 86242235275.63507,
#             "infinite_supply": true,
#             "platform": null,
#             "cmc_rank": 10,
#             "self_reported_circulating_supply": null,
#             "self_reported_market_cap": null,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-16T02:44:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 0.2848488936945425,
#                     "volume_24h": 902922148.0291888,
#                     "volume_change_24h": -15.3096,
#                     "percent_change_1h": -0.96367832,
#                     "percent_change_24h": 0.93793696,
#                     "percent_change_7d": -9.52511121,
#                     "percent_change_30d": 49.95100014,
#                     "percent_change_60d": 78.19197548,
#                     "percent_change_90d": 90.64258552,
#                     "market_cap": 24566005450.16787,
#                     "market_cap_dominance": 0.6633,
#                     "fully_diluted_market_cap": 24566005308.01,
#                     "tvl": null,
#                     "last_updated": "2024-12-16T02:44:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 5805,
#             "name": "Avalanche",
#             "symbol": "AVAX",
#             "slug": "avalanche",
#             "num_market_pairs": 821,
#             "date_added": "2020-07-13T00:00:00.000Z",
#             "tags": [
#                 "defi",
#                 "smart-contracts",
#                 "three-arrows-capital-portfolio",
#                 "polychain-capital-portfolio",
#                 "avalanche-ecosystem",
#                 "cms-holdings-portfolio",
#                 "dragonfly-capital-portfolio",
#                 "real-world-assets",
#                 "layer-1"
#             ],
#             "max_supply": 715748719,
#             "circulating_supply": 409698418.3082831,
#             "total_supply": 448034718.3082831,
#             "infinite_supply": false,
#             "platform": null,
#             "cmc_rank": 11,
#             "self_reported_circulating_supply": null,
#             "self_reported_market_cap": null,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-16T02:45:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 50.36459556380408,
#                     "volume_24h": 826098148.554512,
#                     "volume_change_24h": 17.8576,
#                     "percent_change_1h": -2.10985593,
#                     "percent_change_24h": 0.50747831,
#                     "percent_change_7d": -3.5609215,
#                     "percent_change_30d": 50.28218768,
#                     "percent_change_60d": 79.79605037,
#                     "percent_change_90d": 114.89797623,
#                     "market_cap": 20634295141.226902,
#                     "market_cap_dominance": 0.5572,
#                     "fully_diluted_market_cap": 36048394757.75,
#                     "tvl": null,
#                     "last_updated": "2024-12-16T02:45:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 1975,
#             "name": "Chainlink",
#             "symbol": "LINK",
#             "slug": "chainlink",
#             "num_market_pairs": 1898,
#             "date_added": "2017-09-20T00:00:00.000Z",
#             "tags": [
#                 "platform",
#                 "defi",
#                 "oracles",
#                 "smart-contracts",
#                 "substrate",
#                 "polkadot",
#                 "avalanche-ecosystem",
#                 "solana-ecosystem",
#                 "framework-ventures-portfolio",
#                 "polygon-ecosystem",
#                 "fantom-ecosystem",
#                 "cardano-ecosystem",
#                 "web3",
#                 "near-protocol-ecosystem",
#                 "arbitrum-ecosytem",
#                 "cardano",
#                 "injective-ecosystem",
#                 "optimism-ecosystem",
#                 "real-world-assets",
#                 "celsius-bankruptcy-estate"
#             ],
#             "max_supply": null,
#             "circulating_supply": 626849970.4527867,
#             "total_supply": 1000000000,
#             "platform": {
#                 "id": 1027,
#                 "name": "Ethereum",
#                 "symbol": "ETH",
#                 "slug": "ethereum",
#                 "token_address": "0x514910771af9ca656af840dff83e8264ecf986ca"
#             },
#             "infinite_supply": false,
#             "cmc_rank": 12,
#             "self_reported_circulating_supply": null,
#             "self_reported_market_cap": null,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-16T02:45:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 28.75521992434188,
#                     "volume_24h": 1446530686.9332457,
#                     "volume_change_24h": -25.4039,
#                     "percent_change_1h": -1.72113614,
#                     "percent_change_24h": -1.7021147,
#                     "percent_change_7d": 8.36049847,
#                     "percent_change_30d": 105.21705819,
#                     "percent_change_60d": 155.3268891,
#                     "percent_change_90d": 173.92625387,
#                     "market_cap": 18025208759.93709,
#                     "market_cap_dominance": 0.4868,
#                     "fully_diluted_market_cap": 28755219924.34,
#                     "tvl": null,
#                     "last_updated": "2024-12-16T02:45:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 5994,
#             "name": "Shiba Inu",
#             "symbol": "SHIB",
#             "slug": "shiba-inu",
#             "num_market_pairs": 917,
#             "date_added": "2020-08-01T00:00:00.000Z",
#             "tags": [
#                 "memes",
#                 "ethereum-ecosystem",
#                 "doggone-doggerel"
#             ],
#             "max_supply": null,
#             "circulating_supply": 589255537557602.8,
#             "total_supply": 589508581438258.8,
#             "platform": {
#                 "id": 1027,
#                 "name": "Ethereum",
#                 "symbol": "ETH",
#                 "slug": "ethereum",
#                 "token_address": "0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce"
#             },
#             "infinite_supply": false,
#             "cmc_rank": 13,
#             "self_reported_circulating_supply": null,
#             "self_reported_market_cap": null,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-16T02:45:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 2.769607444616555e-05,
#                     "volume_24h": 643820790.8428112,
#                     "volume_change_24h": -13.1949,
#                     "percent_change_1h": -1.28179386,
#                     "percent_change_24h": 0.67011478,
#                     "percent_change_7d": -11.06115433,
#                     "percent_change_30d": 8.89451318,
#                     "percent_change_60d": 51.15607514,
#                     "percent_change_90d": 110.66377483,
#                     "market_cap": 16320065236.010668,
#                     "market_cap_dominance": 0.4407,
#                     "fully_diluted_market_cap": 16327073558.17,
#                     "tvl": null,
#                     "last_updated": "2024-12-16T02:45:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 11419,
#             "name": "Toncoin",
#             "symbol": "TON",
#             "slug": "toncoin",
#             "num_market_pairs": 634,
#             "date_added": "2021-08-26T13:40:22.000Z",
#             "tags": [
#                 "pos",
#                 "layer-1",
#                 "ftx-bankruptcy-estate",
#                 "dwf-labs-portfolio",
#                 "toncoin-ecosystem"
#             ],
#             "max_supply": null,
#             "circulating_supply": 2551180470.008867,
#             "total_supply": 5117492479.406826,
#             "infinite_supply": true,
#             "platform": null,
#             "cmc_rank": 14,
#             "self_reported_circulating_supply": 3414166606,
#             "self_reported_market_cap": 21670191327.14516,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-16T02:44:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 6.347139383608968,
#                     "volume_24h": 231163240.46489328,
#                     "volume_change_24h": 5.9249,
#                     "percent_change_1h": -1.0093379,
#                     "percent_change_24h": 1.24844228,
#                     "percent_change_7d": -4.86840295,
#                     "percent_change_30d": 16.68260756,
#                     "percent_change_60d": 21.59465555,
#                     "percent_change_90d": 16.10696688,
#                     "market_cap": 16192698035.887316,
#                     "market_cap_dominance": 0.4372,
#                     "fully_diluted_market_cap": 32481438061.37,
#                     "tvl": null,
#                     "last_updated": "2024-12-16T02:44:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 20947,
#             "name": "Sui",
#             "symbol": "SUI",
#             "slug": "sui",
#             "num_market_pairs": 468,
#             "date_added": "2022-07-12T08:03:11.000Z",
#             "tags": [
#                 "binance-launchpool",
#                 "coinbase-ventures-portfolio",
#                 "binance-labs-portfolio",
#                 "electric-capital-portfolio",
#                 "a16z-portfolio",
#                 "sui-ecosystem",
#                 "layer-1",
#                 "move-vm"
#             ],
#             "max_supply": 10000000000,
#             "circulating_supply": 2927660018.558888,
#             "total_supply": 10000000000,
#             "infinite_supply": false,
#             "platform": null,
#             "cmc_rank": 15,
#             "self_reported_circulating_supply": null,
#             "self_reported_market_cap": null,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-16T02:45:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 4.769321216559656,
#                     "volume_24h": 1736787043.8066905,
#                     "volume_change_24h": 38.6033,
#                     "percent_change_1h": -1.5430332,
#                     "percent_change_24h": 7.13705082,
#                     "percent_change_7d": 12.05560666,
#                     "percent_change_30d": 26.34552533,
#                     "percent_change_60d": 123.60861738,
#                     "percent_change_90d": 353.89574161,
#                     "market_cap": 13962951041.386341,
#                     "market_cap_dominance": 0.377,
#                     "fully_diluted_market_cap": 47693212165.6,
#                     "tvl": null,
#                     "last_updated": "2024-12-16T02:45:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 6636,
#             "name": "Polkadot",
#             "symbol": "DOT",
#             "slug": "polkadot-new",
#             "num_market_pairs": 850,
#             "date_added": "2020-08-19T00:00:00.000Z",
#             "tags": [
#                 "substrate",
#                 "polkadot",
#                 "polkadot-ecosystem",
#                 "three-arrows-capital-portfolio",
#                 "polychain-capital-portfolio",
#                 "arrington-xrp-capital-portfolio",
#                 "blockchain-capital-portfolio",
#                 "boostvc-portfolio",
#                 "cms-holdings-portfolio",
#                 "coinfund-portfolio",
#                 "fabric-ventures-portfolio",
#                 "fenbushi-capital-portfolio",
#                 "hashkey-capital-portfolio",
#                 "kenetic-capital-portfolio",
#                 "1confirmation-portfolio",
#                 "placeholder-ventures-portfolio",
#                 "pantera-capital-portfolio",
#                 "exnetwork-capital-portfolio",
#                 "web3",
#                 "spartan-group",
#                 "layer-1"
#             ],
#             "max_supply": null,
#             "circulating_supply": 1529024494.1847577,
#             "total_supply": 1529024494.1847577,
#             "infinite_supply": true,
#             "platform": null,
#             "cmc_rank": 16,
#             "self_reported_circulating_supply": 1529022747.461945,
#             "self_reported_market_cap": 13728141820.757036,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-16T02:45:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 8.978376445703407,
#                     "volume_24h": 692463114.8799474,
#                     "volume_change_24h": 32.2108,
#                     "percent_change_1h": -1.6057721,
#                     "percent_change_24h": 4.18449604,
#                     "percent_change_7d": -11.30569893,
#                     "percent_change_30d": 73.33881008,
#                     "percent_change_60d": 107.56856842,
#                     "percent_change_90d": 114.84850523,
#                     "market_cap": 13728157503.491995,
#                     "market_cap_dominance": 0.3707,
#                     "fully_diluted_market_cap": 13728157503.49,
#                     "tvl": null,
#                     "last_updated": "2024-12-16T02:45:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 512,
#             "name": "Stellar",
#             "symbol": "XLM",
#             "slug": "stellar",
#             "num_market_pairs": 648,
#             "date_added": "2014-08-05T00:00:00.000Z",
#             "tags": [
#                 "medium-of-exchange",
#                 "enterprise-solutions",
#                 "decentralized-exchange-dex-token",
#                 "smart-contracts",
#                 "hashkey-capital-portfolio",
#                 "2017-2018-alt-season"
#             ],
#             "max_supply": 50001806812,
#             "circulating_supply": 30177012855.44095,
#             "total_supply": 50001786911.162926,
#             "infinite_supply": false,
#             "platform": null,
#             "cmc_rank": 17,
#             "self_reported_circulating_supply": null,
#             "self_reported_market_cap": null,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-16T02:45:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 0.42476811264383174,
#                     "volume_24h": 484565243.91048944,
#                     "volume_change_24h": -11.1801,
#                     "percent_change_1h": -1.47915937,
#                     "percent_change_24h": -0.2408256,
#                     "percent_change_7d": -10.65308395,
#                     "percent_change_30d": 198.18099885,
#                     "percent_change_60d": 344.46956745,
#                     "percent_change_90d": 346.19616595,
#                     "market_cap": 12818232795.8343,
#                     "market_cap_dominance": 0.3461,
#                     "fully_diluted_market_cap": 21239173108.31,
#                     "tvl": null,
#                     "last_updated": "2024-12-16T02:45:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 4642,
#             "name": "Hedera",
#             "symbol": "HBAR",
#             "slug": "hedera",
#             "num_market_pairs": 297,
#             "date_added": "2019-09-17T00:00:00.000Z",
#             "tags": [
#                 "dag",
#                 "marketplace",
#                 "enterprise-solutions",
#                 "defi",
#                 "payments",
#                 "dcg-portfolio",
#                 "hedera-hashgraph-ecosystem",
#                 "layer-1"
#             ],
#             "max_supply": 50000000000,
#             "circulating_supply": 38238361609.50461,
#             "total_supply": 50000000000,
#             "infinite_supply": false,
#             "platform": null,
#             "cmc_rank": 18,
#             "self_reported_circulating_supply": null,
#             "self_reported_market_cap": null,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-16T02:45:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 0.28993083383415574,
#                     "volume_24h": 642139186.6497355,
#                     "volume_change_24h": -6.6671,
#                     "percent_change_1h": -1.65350425,
#                     "percent_change_24h": -1.32529853,
#                     "percent_change_7d": -7.60616935,
#                     "percent_change_30d": 260.9507668,
#                     "percent_change_60d": 445.81423755,
#                     "percent_change_90d": 488.56913397,
#                     "market_cap": 11086480065.895641,
#                     "market_cap_dominance": 0.2994,
#                     "fully_diluted_market_cap": 14496541691.71,
#                     "tvl": null,
#                     "last_updated": "2024-12-16T02:45:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 1831,
#             "name": "Bitcoin Cash",
#             "symbol": "BCH",
#             "slug": "bitcoin-cash",
#             "num_market_pairs": 957,
#             "date_added": "2017-07-23T00:00:00.000Z",
#             "tags": [
#                 "mineable",
#                 "pow",
#                 "sha-256",
#                 "marketplace",
#                 "medium-of-exchange",
#                 "store-of-value",
#                 "enterprise-solutions",
#                 "payments",
#                 "bitcoin-ecosystem",
#                 "layer-1",
#                 "2017-2018-alt-season"
#             ],
#             "max_supply": 21000000,
#             "circulating_supply": 19802475,
#             "total_supply": 19802475,
#             "infinite_supply": false,
#             "platform": null,
#             "cmc_rank": 19,
#             "self_reported_circulating_supply": null,
#             "self_reported_market_cap": null,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-16T02:45:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 543.2460627974618,
#                     "volume_24h": 482332490.7328448,
#                     "volume_change_24h": 20.6681,
#                     "percent_change_1h": -1.69144987,
#                     "percent_change_24h": 1.8526542,
#                     "percent_change_7d": -10.82682901,
#                     "percent_change_30d": 25.26268358,
#                     "percent_change_60d": 48.63650007,
#                     "percent_change_90d": 73.81655876,
#                     "market_cap": 10757616577.395168,
#                     "market_cap_dominance": 0.2905,
#                     "fully_diluted_market_cap": 11408167318.75,
#                     "tvl": null,
#                     "last_updated": "2024-12-16T02:45:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 24478,
#             "name": "Pepe",
#             "symbol": "PEPE",
#             "slug": "pepe",
#             "num_market_pairs": 488,
#             "date_added": "2023-04-17T06:18:08.000Z",
#             "tags": [
#                 "memes"
#             ],
#             "max_supply": 420690000000000,
#             "circulating_supply": 420689899999994.8,
#             "total_supply": 420689899999994.8,
#             "platform": {
#                 "id": 1027,
#                 "name": "Ethereum",
#                 "symbol": "ETH",
#                 "slug": "ethereum",
#                 "token_address": "0x6982508145454ce325ddbe47a25d4ec3d2311933"
#             },
#             "infinite_supply": false,
#             "cmc_rank": 20,
#             "self_reported_circulating_supply": null,
#             "self_reported_market_cap": null,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-16T02:45:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 2.420587760597086e-05,
#                     "volume_24h": 1902289023.7831252,
#                     "volume_change_24h": 19.9109,
#                     "percent_change_1h": -1.59504063,
#                     "percent_change_24h": 2.94698692,
#                     "percent_change_7d": -9.25206242,
#                     "percent_change_30d": 4.43664986,
#                     "percent_change_60d": 132.67511575,
#                     "percent_change_90d": 235.40142218,
#                     "market_cap": 10183168229.467995,
#                     "market_cap_dominance": 0.275,
#                     "fully_diluted_market_cap": 10183170650.06,
#                     "tvl": null,
#                     "last_updated": "2024-12-16T02:45:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 7083,
#             "name": "Uniswap",
#             "symbol": "UNI",
#             "slug": "uniswap",
#             "num_market_pairs": 1142,
#             "date_added": "2020-09-17T00:00:00.000Z",
#             "tags": [
#                 "decentralized-exchange-dex-token",
#                 "defi",
#                 "dao",
#                 "yield-farming",
#                 "amm",
#                 "coinbase-ventures-portfolio",
#                 "three-arrows-capital-portfolio",
#                 "governance",
#                 "blockchain-capital-portfolio",
#                 "defiance-capital-portfolio",
#                 "alameda-research-portfolio",
#                 "a16z-portfolio",
#                 "pantera-capital-portfolio",
#                 "parafi-capital",
#                 "paradigm-portfolio",
#                 "arbitrum-ecosytem",
#                 "injective-ecosystem",
#                 "optimism-ecosystem",
#                 "cmc-crypto-awards-2024"
#             ],
#             "max_supply": null,
#             "circulating_supply": 600483073.71,
#             "total_supply": 1000000000,
#             "platform": {
#                 "id": 1027,
#                 "name": "Ethereum",
#                 "symbol": "ETH",
#                 "slug": "ethereum",
#                 "token_address": "0x1f9840a85d5af5bf1d1762f925bdaddc4201f984"
#             },
#             "infinite_supply": false,
#             "cmc_rank": 21,
#             "self_reported_circulating_supply": null,
#             "self_reported_market_cap": null,
#             "tvl_ratio": 1.95367723,
#             "last_updated": "2024-12-16T02:45:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 16.923790594775216,
#                     "volume_24h": 557447826.971168,
#                     "volume_change_24h": 4.6437,
#                     "percent_change_1h": -2.20806207,
#                     "percent_change_24h": 0.32802663,
#                     "percent_change_7d": -7.03210556,
#                     "percent_change_30d": 93.84163975,
#                     "percent_change_60d": 123.41357444,
#                     "percent_change_90d": 163.9503354,
#                     "market_cap": 10162449795.17501,
#                     "market_cap_dominance": 0.2744,
#                     "fully_diluted_market_cap": 16923790594.78,
#                     "tvl": 5201703562.71899,
#                     "last_updated": "2024-12-16T02:45:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 2,
#             "name": "Litecoin",
#             "symbol": "LTC",
#             "slug": "litecoin",
#             "num_market_pairs": 1288,
#             "date_added": "2013-04-28T00:00:00.000Z",
#             "tags": [
#                 "mineable",
#                 "pow",
#                 "scrypt",
#                 "medium-of-exchange",
#                 "2017-2018-alt-season"
#             ],
#             "max_supply": 84000000,
#             "circulating_supply": 75311087.05410936,
#             "total_supply": 84000000,
#             "infinite_supply": false,
#             "platform": null,
#             "cmc_rank": 22,
#             "self_reported_circulating_supply": null,
#             "self_reported_market_cap": null,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-16T02:45:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 122.56501505526845,
#                     "volume_24h": 877882941.1001828,
#                     "volume_change_24h": 19.1522,
#                     "percent_change_1h": -0.67796369,
#                     "percent_change_24h": 2.79456429,
#                     "percent_change_7d": -6.1131563,
#                     "percent_change_30d": 45.08275099,
#                     "percent_change_60d": 74.06789722,
#                     "percent_change_90d": 95.78011613,
#                     "market_cap": 9230504518.615547,
#                     "market_cap_dominance": 0.2493,
#                     "fully_diluted_market_cap": 10295461264.64,
#                     "tvl": null,
#                     "last_updated": "2024-12-16T02:45:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 3957,
#             "name": "UNUS SED LEO",
#             "symbol": "LEO",
#             "slug": "unus-sed-leo",
#             "num_market_pairs": 53,
#             "date_added": "2019-05-21T00:00:00.000Z",
#             "tags": [
#                 "marketplace",
#                 "centralized-exchange",
#                 "discount-token",
#                 "payments",
#                 "kenetic-capital-portfolio",
#                 "alameda-research-portfolio"
#             ],
#             "max_supply": null,
#             "circulating_supply": 924517292.9,
#             "total_supply": 985239504,
#             "platform": {
#                 "id": 1027,
#                 "name": "Ethereum",
#                 "symbol": "ETH",
#                 "slug": "ethereum",
#                 "token_address": "0x2af5d2ad76741191d15dfe7bf6ac92d4bd912ca3"
#             },
#             "infinite_supply": false,
#             "cmc_rank": 23,
#             "self_reported_circulating_supply": null,
#             "self_reported_market_cap": null,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-16T02:45:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 9.537191397263374,
#                     "volume_24h": 706355.57601315,
#                     "volume_change_24h": 132.9569,
#                     "percent_change_1h": 0.3830441,
#                     "percent_change_24h": 1.73934588,
#                     "percent_change_7d": 2.03561936,
#                     "percent_change_30d": 23.23710402,
#                     "percent_change_60d": 56.16044237,
#                     "percent_change_90d": 67.65883367,
#                     "market_cap": 8817298372.467102,
#                     "market_cap_dominance": 0.2381,
#                     "fully_diluted_market_cap": 9396417721.79,
#                     "tvl": null,
#                     "last_updated": "2024-12-16T02:45:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 6535,
#             "name": "NEAR Protocol",
#             "symbol": "NEAR",
#             "slug": "near-protocol",
#             "num_market_pairs": 476,
#             "date_added": "2020-08-11T00:00:00.000Z",
#             "tags": [
#                 "platform",
#                 "ai-big-data",
#                 "staking",
#                 "coinbase-ventures-portfolio",
#                 "three-arrows-capital-portfolio",
#                 "arrington-xrp-capital-portfolio",
#                 "coinfund-portfolio",
#                 "electric-capital-portfolio",
#                 "fabric-ventures-portfolio",
#                 "kenetic-capital-portfolio",
#                 "near-protocol-ecosystem",
#                 "cross-chain",
#                 "injective-ecosystem",
#                 "circle-ventures-portfolio",
#                 "layer-1",
#                 "alleged-sec-securities",
#                 "account-abstraction",
#                 "data-availability"
#             ],
#             "max_supply": null,
#             "circulating_supply": 1217906155,
#             "total_supply": 1225346372,
#             "infinite_supply": false,
#             "platform": null,
#             "cmc_rank": 24,
#             "self_reported_circulating_supply": null,
#             "self_reported_market_cap": null,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-16T02:44:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 6.856774149546582,
#                     "volume_24h": 384330509.3803656,
#                     "volume_change_24h": 11.5948,
#                     "percent_change_1h": -1.60667009,
#                     "percent_change_24h": 2.74143738,
#                     "percent_change_7d": -8.73070507,
# ...
#                     "tvl": null,
#                     "last_updated": "2024-12-16T02:45:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 1376,
#             "name": "Neo",
#             "symbol": "NEO",
#             "slug": "neo",
#             "num_market_pairs": 356,
#             "date_added": "2016-09-08T00:00:00.000Z",
#             "tags": [
#                 "platform",
#                 "enterprise-solutions",
#                 "smart-contracts",
#                 "2017-2018-alt-season"
#             ],
#             "max_supply": 100000000,
#             "circulating_supply": 70538831,
#             "total_supply": 100000000,
#             "infinite_supply": false,
#             "platform": null,
#             "cmc_rank": 93,
#             "self_reported_circulating_supply": null,
#             "self_reported_market_cap": null,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-16T02:45:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 18.405020567763174,
#                     "volume_24h": 53554929.82815433,
#                     "volume_change_24h": 8.8112,
#                     "percent_change_1h": -1.89923721,
#                     "percent_change_24h": 2.83483417,
#                     "percent_change_7d": -10.37992213,
#                     "percent_change_30d": 58.35892515,
#                     "percent_change_60d": 73.3283956,
#                     "percent_change_90d": 100.8334282,
#                     "market_cap": 1298268635.3809705,
#                     "market_cap_dominance": 0.0351,
#                     "fully_diluted_market_cap": 1840502056.78,
#                     "tvl": null,
#                     "last_updated": "2024-12-16T02:45:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 9104,
#             "name": "AIOZ Network",
#             "symbol": "AIOZ",
#             "slug": "aioz-network",
#             "num_market_pairs": 121,
#             "date_added": "2021-04-02T00:00:00.000Z",
#             "tags": [
#                 "media",
#                 "platform",
#                 "ai-big-data",
#                 "distributed-computing",
#                 "smart-contracts",
#                 "video",
#                 "storage",
#                 "web3",
#                 "bnb-chain",
#                 "generative-ai",
#                 "layer-1",
#                 "dwf-labs-portfolio",
#                 "depin"
#             ],
#             "max_supply": null,
#             "circulating_supply": 1143775134.554449,
#             "total_supply": 1143775134.554449,
#             "infinite_supply": false,
#             "platform": null,
#             "cmc_rank": 94,
#             "self_reported_circulating_supply": 1143780640.6360846,
#             "self_reported_market_cap": 1295828017.2738917,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-16T02:45:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 1.1329340358071194,
#                     "volume_24h": 23170161.55185742,
#                     "volume_change_24h": 52.5986,
#                     "percent_change_1h": -1.64663559,
#                     "percent_change_24h": 5.18228709,
#                     "percent_change_7d": 0.43853015,
#                     "percent_change_30d": 47.10081026,
#                     "percent_change_60d": 128.02507932,
#                     "percent_change_90d": 210.78419529,
#                     "market_cap": 1295821779.246603,
#                     "market_cap_dominance": 0.035,
#                     "fully_diluted_market_cap": 1295821779.25,
#                     "tvl": null,
#                     "last_updated": "2024-12-16T02:45:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 6892,
#             "name": "MultiversX",
#             "symbol": "EGLD",
#             "slug": "multiversx-egld",
#             "num_market_pairs": 277,
#             "date_added": "2020-09-04T00:00:00.000Z",
#             "tags": [
#                 "pos",
#                 "enterprise-solutions",
#                 "distributed-computing",
#                 "loyalty",
#                 "defi",
#                 "gaming",
#                 "identity",
#                 "payments",
#                 "scaling",
#                 "smart-contracts",
#                 "software",
#                 "binance-launchpad",
#                 "binance-labs-portfolio",
#                 "metaverse",
#                 "electric-capital-portfolio",
#                 "exnetwork-capital-portfolio",
#                 "mobile-payment",
#                 "web3",
#                 "elrond-ecosystem",
#                 "injective-ecosystem",
#                 "bnb-chain",
#                 "layer-1",
#                 "dwf-labs-portfolio",
#                 "multiversx-ecosystem",
#                 "depin"
#             ],
#             "max_supply": 31415926,
#             "circulating_supply": 27661747.44302762,
#             "total_supply": 27721611,
#             "infinite_supply": false,
#             "platform": null,
#             "cmc_rank": 95,
#             "self_reported_circulating_supply": 27721611,
#             "self_reported_market_cap": 1289145489.4938352,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-16T02:44:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 46.50326741450326,
#                     "volume_24h": 69123989.84202388,
#                     "volume_change_24h": 21.3603,
#                     "percent_change_1h": -1.71484019,
#                     "percent_change_24h": -0.08988469,
#                     "percent_change_7d": -12.92769746,
#                     "percent_change_30d": 60.35659789,
#                     "percent_change_60d": 78.52853681,
#                     "percent_change_90d": 87.52419705,
#                     "market_cap": 1286361638.4955652,
#                     "market_cap_dominance": 0.0347,
#                     "fully_diluted_market_cap": 1460943207.85,
#                     "tvl": null,
#                     "last_updated": "2024-12-16T02:44:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 16086,
#             "name": "BitTorrent [New]",
#             "symbol": "BTT",
#             "slug": "bittorrent-new",
#             "num_market_pairs": 176,
#             "date_added": "2019-01-31T00:00:00.000Z",
#             "tags": [
#                 "platform",
#                 "distributed-computing",
#                 "filesharing",
#                 "interoperability",
#                 "staking",
#                 "tron-ecosystem",
#                 "storage",
#                 "binance-launchpad",
#                 "binance-labs-portfolio",
#                 "web3",
#                 "bnb-chain",
#                 "alleged-sec-securities",
#                 "depin"
#             ],
#             "max_supply": null,
#             "circulating_supply": 968246428571000,
#             "total_supply": 990000000000000,
#             "platform": {
#                 "id": 1958,
#                 "name": "Tron20",
#                 "symbol": "TRX",
#                 "slug": "tron",
#                 "token_address": "TAFjULxiVgT4qWk6UZwjqwZXTSaGaqnVp4"
#             },
#             "infinite_supply": false,
#             "cmc_rank": 96,
#             "self_reported_circulating_supply": null,
#             "self_reported_market_cap": null,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-16T02:45:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 1.3151932732541166e-06,
#                     "volume_24h": 32067099.18095289,
#                     "volume_change_24h": -3.6429,
#                     "percent_change_1h": -1.39381637,
#                     "percent_change_24h": 0.92322743,
#                     "percent_change_7d": -13.83031956,
#                     "percent_change_30d": 19.43030704,
#                     "percent_change_60d": 41.7330511,
#                     "percent_change_90d": 50.18770877,
#                     "market_cap": 1273431189.7089016,
#                     "market_cap_dominance": 0.0344,
#                     "fully_diluted_market_cap": 1302041340.52,
#                     "tvl": null,
#                     "last_updated": "2024-12-16T02:45:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 2634,
#             "name": "XDC Network",
#             "symbol": "XDC",
#             "slug": "xdc-network",
#             "num_market_pairs": 117,
#             "date_added": "2018-04-12T00:00:00.000Z",
#             "tags": [
#                 "enterprise-solutions",
#                 "masternodes",
#                 "smart-contracts",
#                 "xdc-ecosystem",
#                 "real-world-assets",
#                 "layer-1"
#             ],
#             "max_supply": null,
#             "circulating_supply": 14932919359.85,
#             "total_supply": 37951146329.85,
#             "infinite_supply": false,
#             "platform": null,
#             "cmc_rank": 97,
#             "self_reported_circulating_supply": 14930334691.55,
#             "self_reported_market_cap": 1246767517.858876,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-16T02:45:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 0.08350566438168991,
#                     "volume_24h": 38357961.04370613,
#                     "volume_change_24h": 16.9645,
#                     "percent_change_1h": -0.62567439,
#                     "percent_change_24h": 3.65531156,
#                     "percent_change_7d": -5.37072101,
#                     "percent_change_30d": 168.71417225,
#                     "percent_change_60d": 201.96774235,
#                     "percent_change_90d": 199.85757333,
#                     "market_cap": 1246983352.3024738,
#                     "market_cap_dominance": 0.0337,
#                     "fully_diluted_market_cap": 3169135688.32,
#                     "tvl": null,
#                     "last_updated": "2024-12-16T02:45:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 18876,
#             "name": "ApeCoin",
#             "symbol": "APE",
#             "slug": "apecoin-ape",
#             "num_market_pairs": 472,
#             "date_added": "2022-03-17T12:26:36.000Z",
#             "tags": [
#                 "collectibles-nfts",
#                 "content-creation",
#                 "gaming",
#                 "entertainment",
#                 "dao",
#                 "governance",
#                 "metaverse",
#                 "animoca-brands-portfolio"
#             ],
#             "max_supply": 1000000000,
#             "circulating_supply": 752651515,
#             "total_supply": 1000000000,
#             "platform": {
#                 "id": 1027,
#                 "name": "Ethereum",
#                 "symbol": "ETH",
#                 "slug": "ethereum",
#                 "token_address": "0x4d224452801aced8b2f0aebe155379bb5d594381"
#             },
#             "infinite_supply": false,
#             "cmc_rank": 98,
#             "self_reported_circulating_supply": 752651515,
#             "self_reported_market_cap": 1223725147.103469,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-16T02:45:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 1.6258854499262767,
#                     "volume_24h": 163724739.44819847,
#                     "volume_change_24h": -6.8594,
#                     "percent_change_1h": -0.88964918,
#                     "percent_change_24h": 4.74126214,
#                     "percent_change_7d": -9.9538179,
#                     "percent_change_30d": 45.26411677,
#                     "percent_change_60d": 127.46190891,
#                     "percent_change_90d": 125.12527801,
#                     "market_cap": 1223725147.103469,
#                     "market_cap_dominance": 0.033,
#                     "fully_diluted_market_cap": 1625885449.93,
#                     "tvl": null,
#                     "last_updated": "2024-12-16T02:45:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 1966,
#             "name": "Decentraland",
#             "symbol": "MANA",
#             "slug": "decentraland",
#             "num_market_pairs": 544,
#             "date_added": "2017-09-17T00:00:00.000Z",
#             "tags": [
#                 "platform",
#                 "collectibles-nfts",
#                 "gaming",
#                 "payments",
#                 "metaverse",
#                 "boostvc-portfolio",
#                 "dcg-portfolio",
#                 "fabric-ventures-portfolio",
#                 "kenetic-capital-portfolio",
#                 "polygon-ecosystem",
#                 "play-to-earn",
#                 "alleged-sec-securities"
#             ],
#             "max_supply": null,
#             "circulating_supply": 1942255184.1130493,
#             "total_supply": 2193179327.320146,
#             "platform": {
#                 "id": 1027,
#                 "name": "Ethereum",
#                 "symbol": "ETH",
#                 "slug": "ethereum",
#                 "token_address": "0x0f5d2fb29fb7d3cfee444a200298f468908cc942"
#             },
#             "infinite_supply": false,
#             "cmc_rank": 99,
#             "self_reported_circulating_supply": null,
#             "self_reported_market_cap": null,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-16T02:45:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 0.6271651147438696,
#                     "volume_24h": 144316782.5203962,
#                     "volume_change_24h": 13.7283,
#                     "percent_change_1h": -1.66733317,
#                     "percent_change_24h": 2.10691804,
#                     "percent_change_7d": -13.06633619,
#                     "percent_change_30d": 76.89325279,
#                     "percent_change_60d": 103.18254019,
#                     "percent_change_90d": 136.04232813,
#                     "market_cap": 1218114695.406136,
#                     "market_cap_dominance": 0.0329,
#                     "fully_diluted_market_cap": 1375485564.47,
#                     "tvl": null,
#                     "last_updated": "2024-12-16T02:45:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 4269,
#             "name": "GateToken",
#             "symbol": "GT",
#             "slug": "gatetoken",
#             "num_market_pairs": 28,
#             "date_added": "2019-08-20T00:00:00.000Z",
#             "tags": [
#                 "marketplace",
#                 "centralized-exchange",
#                 "discount-token",
#                 "ftx-bankruptcy-estate"
#             ],
#             "max_supply": null,
#             "circulating_supply": 88722559.87848262,
#             "total_supply": 300000000,
#             "platform": {
#                 "id": 1027,
#                 "name": "Ethereum",
#                 "symbol": "ETH",
#                 "slug": "ethereum",
#                 "token_address": "0xe66747a101bff2dba3697199dcce5b743b454759"
#             },
#             "infinite_supply": false,
#             "cmc_rank": 100,
#             "self_reported_circulating_supply": null,
#             "self_reported_market_cap": null,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-16T02:45:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 13.574873811399064,
#                     "volume_24h": 6884405.29166006,
#                     "volume_change_24h": -26.3516,
#                     "percent_change_1h": -0.98289276,
#                     "percent_change_24h": 0.29678239,
#                     "percent_change_7d": 5.89113871,
#                     "percent_change_30d": 39.97695409,
#                     "percent_change_60d": 48.9845864,
#                     "percent_change_90d": 70.55296479,
#                     "market_cap": 1204397554.5746992,
#                     "market_cap_dominance": 0.0325,
#                     "fully_diluted_market_cap": 4072462143.42,
#                     "tvl": null,
#                     "last_updated": "2024-12-16T02:45:00.000Z"
#                 }
#             }
#         }
#     ]
# }

# %%
organized_data = []
for item in data['data']:
    btc_info = {
        "id": item['id'],
        "name": item['name'],
        "symbol": item['symbol'],
        "cmc_rank": item['cmc_rank'],
        "price": item['quote']['USD']['price'],
        "volume_24h": item['quote']['USD']['volume_24h'],
        "market_cap": item['quote']['USD']['market_cap'],
        "market_cap_dominance": item['quote']['USD']['market_cap_dominance'],
        "circulating_supply": item['circulating_supply'],
        "max_supply": item['max_supply'],
        "percent_change_1h": item['quote']['USD']['percent_change_1h'],
        "percent_change_24h": item['quote']['USD']['percent_change_24h'],
        "percent_change_7d": item['quote']['USD']['percent_change_7d'],
        "last_updated": item['quote']['USD']['last_updated']
    }
    organized_data.append(btc_info)

# Convert to a DataFrame
df = pd.DataFrame(organized_data)

# Display the DataFrame
df.head()
# Out:
#      id         name symbol  cmc_rank          price    volume_24h
# 0     1      Bitcoin    BTC         1  104627.183051  6.072842e+10  \
# 1  1027     Ethereum    ETH         2    3971.109988  3.018484e+10
# 2   825  Tether USDt   USDT         3       0.999459  1.268082e+11
# 3    52          XRP    XRP         4       2.414493  6.615564e+09
# 4  5426       Solana    SOL         5     223.013613  3.426024e+09
#
#      market_cap  market_cap_dominance  circulating_supply    max_supply
# 0  2.071272e+12               55.9182        1.979669e+07  2.100000e+07  \
# 1  4.783211e+11               12.9162        1.204502e+08           NaN
# 2  1.401778e+11                3.7844        1.402537e+11           NaN
# 3  1.380797e+11                3.7289        5.718787e+10  1.000000e+11
# 4  1.068556e+11                2.8856        4.791439e+08           NaN
#
#    percent_change_1h  percent_change_24h  percent_change_7d
# 0          -0.533732            2.810853           5.377919  \
# 1          -0.600361            2.228664           0.707730
# 2           0.003377           -0.022192          -0.129193
# 3          -0.954826           -0.295733          -2.449460
# 4          -1.212917            0.844453          -3.616969
#
#                last_updated
# 0  2024-12-16T02:44:00.000Z
# 1  2024-12-16T02:45:00.000Z
# 2  2024-12-16T02:44:00.000Z
# 3  2024-12-16T02:45:00.000Z
# 4  2024-12-16T02:45:00.000Z

# %%
# Convert 'last_update' to a proper datetime object
df["last_updated"] = pd.to_datetime(df["last_updated"])

# Add 'pulled_at' field with the current timestamp
df["pulled_at"] = datetime.now()

# %%
# Database connection setup
DB_USER = "postgres"
#DB_PASSWORD = ""
DB_HOST = "localhost"
DB_PORT = "5432"
DB_NAME = "signal"

# %%
# Replace with your actual database URL
#DATABASE_URL = f"postgresql+psycopg2://{DB_USER}:{DB_PASSWORD}@{DB_HOST}:{DB_PORT}/{DB_NAME}"
DATABASE_URL = f"postgresql+psycopg2://{DB_USER}@{DB_HOST}:{DB_PORT}/{DB_NAME}"

# Create database engine
engine = create_engine(DATABASE_URL)

# %%
# Define the table name
table_name = "crypto_price_history"

# %%
# Function to upsert data
def upsert_crypto_data(df, table_name, engine):
    with engine.connect() as connection:
        # Query existing records (symbol + last_updated)
        query = f"""
        SELECT symbol, last_updated
        FROM {table_name};
        """
        existing_data = pd.read_sql(query, connection)
        
        # Merge to find new records
        new_data = df.merge(
            existing_data,
            on=["symbol", "last_updated"],
            how="left",
            indicator=True
        ).query('_merge == "left_only"').drop(columns=['_merge'])
        
        # Insert new records
        if not new_data.empty:
            new_data.to_sql(table_name, engine, if_exists="append", index=False)
            print(f"Inserted {len(new_data)} new records into {table_name}.")
        else:
            print("No new records to insert.")

# %%
df.describe()
# Out:
#                  id    cmc_rank          price    volume_24h    market_cap
# count    100.000000  100.000000     100.000000  1.000000e+02  1.000000e+02  \
# mean   10750.110000   50.500000    1141.431342  2.782319e+09  3.592750e+10
# min        1.000000    1.000000       0.000001  7.063556e+05  1.204398e+09
# 25%     3135.500000   25.750000       0.623075  1.044067e+08  1.675630e+09
# 50%     6537.000000   50.500000       2.049288  2.719367e+08  3.201977e+09
# 75%    20533.750000   75.250000      12.926276  5.675573e+08  6.607382e+09
# max    32880.000000  100.000000  104627.183051  1.268082e+11  2.071272e+12
# std    10066.048948   29.011492   10462.915696  1.425240e+10  2.122810e+11
#
#        market_cap_dominance  circulating_supply    max_supply
# count            100.000000        1.000000e+02  3.900000e+01  \
# mean               0.970026        2.064561e+13  1.317658e+13
# min                0.032500        8.908856e+05  1.005577e+06
# 25%                0.045225        4.428726e+08  2.053500e+08
# 50%                0.086500        1.369880e+09  2.000000e+09
# 75%                0.178400        6.500741e+09  1.000000e+10
# max               55.918200        9.682464e+14  4.206900e+14
# std                5.731026        1.199708e+14  6.859556e+13
#
#        percent_change_1h  percent_change_24h  percent_change_7d
# count         100.000000          100.000000         100.000000  \
# mean           -1.351780            2.496177          -4.089482
# min            -2.568851           -2.242258         -21.269521
# 25%            -1.759644            0.499999         -10.911598
# 50%            -1.498384            1.864904          -6.750866
# 75%            -1.007319            3.367078          -0.536250
# max             0.383044           16.341314          66.211199
# std             0.624468            3.241105          12.197047
#
#                            pulled_at
# count                            100
# mean   2024-12-15 20:47:17.026378752
# min       2024-12-15 20:47:17.026379
# 25%    2024-12-15 20:47:17.026379008
# 50%    2024-12-15 20:47:17.026379008
# 75%    2024-12-15 20:47:17.026379008
# max       2024-12-15 20:47:17.026379
# std                              NaN

# %%
def validate_and_truncate(df):
    # Truncate string fields to match database limits
    df["symbol"] = df["symbol"].str[:10]
    df["name"] = df["name"].str[:50]

    # Clip numeric fields to match database constraints
    df["price"] = df["price"].clip(upper=10**12 - 1)
    df["volume_24h"] = df["volume_24h"].clip(upper=10**12 - 1)
    df["market_cap"] = df["market_cap"].clip(upper=10**12 - 1)
    df["market_cap_dominance"] = df["market_cap_dominance"].clip(upper=999.99)
    df["circulating_supply"] = df["circulating_supply"].clip(upper=10**12 - 1)
    df["max_supply"] = df["max_supply"].clip(upper=10**12 - 1)
    df["percent_change_1h"] = df["percent_change_1h"].clip(-9999.9999, 9999.9999)
    df["percent_change_24h"] = df["percent_change_24h"].clip(-9999.9999, 9999.9999)
    df["percent_change_7d"] = df["percent_change_7d"].clip(-9999.9999, 9999.9999)

    # Ensure no null values in required fields (if applicable)
    df = df.dropna(subset=["symbol", "last_updated"])

    return df

# %%
# Validate and truncate DataFrame
df_cleaned = validate_and_truncate(df)

# %%
# Call the function
upsert_crypto_data(df_cleaned, table_name, engine)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 2
#       1 # Call the function
# ----> 2 upsert_crypto_data(df_cleaned, table_name, engine)
#
# Cell In[18], line 12, in upsert_crypto_data(df, table_name, engine)
#       9 existing_data = pd.read_sql(query, connection)
#      11 # Merge to find new records
# ---> 12 new_data = df.merge(
#      13     existing_data,
#      14     on=["symbol", "last_updated"],
#      15     how="left",
#      16     indicator=True
#      17 ).query('_merge == "left_only"').drop(columns=['_merge'])
#      19 # Insert new records
#      20 if not new_data.empty:
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/frame.py:9843, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    9824 @Substitution("")
#    9825 @Appender(_merge_doc, indents=2)
#    9826 def merge(
#    (...)
#    9839     validate: str | None = None,
#    9840 ) -> DataFrame:
#    9841     from pandas.core.reshape.merge import merge
# -> 9843     return merge(
#    9844         self,
#    9845         right,
#    9846         how=how,
#    9847         on=on,
#    9848         left_on=left_on,
#    9849         right_on=right_on,
#    9850         left_index=left_index,
#    9851         right_index=right_index,
#    9852         sort=sort,
#    9853         suffixes=suffixes,
#    9854         copy=copy,
#    9855         indicator=indicator,
#    9856         validate=validate,
#    9857     )
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/reshape/merge.py:142, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     125 @Substitution("\nleft : DataFrame or named Series")
#     126 @Appender(_merge_doc, indents=0)
#     127 def merge(
#    (...)
#     140     validate: str | None = None,
#     141 ) -> DataFrame:
# --> 142     op = _MergeOperation(
#     143         left,
#     144         right,
#     145         how=how,
#     146         on=on,
#     147         left_on=left_on,
#     148         right_on=right_on,
#     149         left_index=left_index,
#     150         right_index=right_index,
#     151         sort=sort,
#     152         suffixes=suffixes,
#     153         indicator=indicator,
#     154         validate=validate,
#     155     )
#     156     return op.get_result(copy=copy)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/reshape/merge.py:735, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, indicator, validate)
#     727 (
#     728     self.left_join_keys,
#     729     self.right_join_keys,
#     730     self.join_names,
#     731 ) = self._get_merge_keys()
#     733 # validate the merge keys dtypes. We may need to coerce
#     734 # to avoid incompatible dtypes
# --> 735 self._maybe_coerce_merge_keys()
#     737 # If argument passed to validate,
#     738 # check if columns specified as unique
#     739 # are in fact unique.
#     740 if validate is not None:
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/reshape/merge.py:1397, in _MergeOperation._maybe_coerce_merge_keys(self)
#    1393     raise ValueError(msg)
#    1394 elif isinstance(lk.dtype, DatetimeTZDtype) and not isinstance(
#    1395     rk.dtype, DatetimeTZDtype
#    1396 ):
# -> 1397     raise ValueError(msg)
#    1398 elif not isinstance(lk.dtype, DatetimeTZDtype) and isinstance(
#    1399     rk.dtype, DatetimeTZDtype
#    1400 ):
#    1401     raise ValueError(msg)
#
# ValueError: You are trying to merge on datetime64[ns, UTC] and datetime64[ns] columns. If you wish to proceed you should use pd.concat
