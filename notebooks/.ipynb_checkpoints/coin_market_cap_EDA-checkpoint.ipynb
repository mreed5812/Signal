# %%
import requests
import json
import pandas as pd
from sqlalchemy import create_engine
from datetime import datetime

# Replace 'YOUR_API_KEY' with your actual CoinMarketCap API key
api_key = '42485936-1986-4342-9e0a-e854c8b0fe47'
url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'

parameters = {
    'start': '1',
    'limit': '100',  # Number of cryptocurrencies to retrieve
    'convert': 'USD'  # Convert prices to USD
}

headers = {
    'Accepts': 'application/json',
    'X-CMC_PRO_API_KEY': api_key,
}

response = requests.get(url, headers=headers, params=parameters)
data = response.json()

# Pretty-print the JSON response
print(json.dumps(data, indent=4))
# Out:
# {
#     "status": {
#         "timestamp": "2024-12-15T21:48:08.447Z",
#         "error_code": 0,
#         "error_message": null,
#         "elapsed": 14,
#         "credit_count": 1,
#         "notice": null,
#         "total_count": 10329
#     },
#     "data": [
#         {
#             "id": 1,
#             "name": "Bitcoin",
#             "symbol": "BTC",
#             "slug": "bitcoin",
#             "num_market_pairs": 11840,
#             "date_added": "2010-07-13T00:00:00.000Z",
#             "tags": [
#                 "mineable",
#                 "pow",
#                 "sha-256",
#                 "store-of-value",
#                 "state-channel",
#                 "coinbase-ventures-portfolio",
#                 "three-arrows-capital-portfolio",
#                 "polychain-capital-portfolio",
#                 "binance-labs-portfolio",
#                 "blockchain-capital-portfolio",
#                 "boostvc-portfolio",
#                 "cms-holdings-portfolio",
#                 "dcg-portfolio",
#                 "dragonfly-capital-portfolio",
#                 "electric-capital-portfolio",
#                 "fabric-ventures-portfolio",
#                 "framework-ventures-portfolio",
#                 "galaxy-digital-portfolio",
#                 "huobi-capital-portfolio",
#                 "alameda-research-portfolio",
#                 "a16z-portfolio",
#                 "1confirmation-portfolio",
#                 "winklevoss-capital-portfolio",
#                 "usv-portfolio",
#                 "placeholder-ventures-portfolio",
#                 "pantera-capital-portfolio",
#                 "multicoin-capital-portfolio",
#                 "paradigm-portfolio",
#                 "bitcoin-ecosystem",
#                 "ftx-bankruptcy-estate",
#                 "2017-2018-alt-season"
#             ],
#             "max_supply": 21000000,
#             "circulating_supply": 19796600,
#             "total_supply": 19796600,
#             "infinite_supply": false,
#             "platform": null,
#             "cmc_rank": 1,
#             "self_reported_circulating_supply": null,
#             "self_reported_market_cap": null,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-15T21:46:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 103021.33063089015,
#                     "volume_24h": 43161311554.0694,
#                     "volume_change_24h": 5.4632,
#                     "percent_change_1h": -0.08974471,
#                     "percent_change_24h": 1.88223017,
#                     "percent_change_7d": 2.97783358,
#                     "percent_change_30d": 12.78543236,
#                     "percent_change_60d": 52.59811303,
#                     "percent_change_90d": 78.10668328,
#                     "market_cap": 2039472073967.48,
#                     "market_cap_dominance": 56.0653,
#                     "fully_diluted_market_cap": 2163447943248.69,
#                     "tvl": null,
#                     "last_updated": "2024-12-15T21:46:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 1027,
#             "name": "Ethereum",
#             "symbol": "ETH",
#             "slug": "ethereum",
#             "num_market_pairs": 9682,
#             "date_added": "2015-08-07T00:00:00.000Z",
#             "tags": [
#                 "pos",
#                 "smart-contracts",
#                 "ethereum-ecosystem",
#                 "coinbase-ventures-portfolio",
#                 "three-arrows-capital-portfolio",
#                 "polychain-capital-portfolio",
#                 "binance-labs-portfolio",
#                 "blockchain-capital-portfolio",
#                 "boostvc-portfolio",
#                 "cms-holdings-portfolio",
#                 "dcg-portfolio",
#                 "dragonfly-capital-portfolio",
#                 "electric-capital-portfolio",
#                 "fabric-ventures-portfolio",
#                 "framework-ventures-portfolio",
#                 "hashkey-capital-portfolio",
#                 "kenetic-capital-portfolio",
#                 "huobi-capital-portfolio",
#                 "alameda-research-portfolio",
#                 "a16z-portfolio",
#                 "1confirmation-portfolio",
#                 "winklevoss-capital-portfolio",
#                 "usv-portfolio",
#                 "placeholder-ventures-portfolio",
#                 "pantera-capital-portfolio",
#                 "multicoin-capital-portfolio",
#                 "paradigm-portfolio",
#                 "layer-1",
#                 "ftx-bankruptcy-estate"
#             ],
#             "max_supply": null,
#             "circulating_supply": 120448515.52700861,
#             "total_supply": 120448515.52700861,
#             "infinite_supply": true,
#             "platform": null,
#             "cmc_rank": 2,
#             "self_reported_circulating_supply": null,
#             "self_reported_market_cap": null,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-15T21:46:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 3865.3731611849153,
#                     "volume_24h": 22672213271.944176,
#                     "volume_change_24h": -20.1774,
#                     "percent_change_1h": -0.88137894,
#                     "percent_change_24h": 0.28337878,
#                     "percent_change_7d": -3.1334057,
#                     "percent_change_30d": 25.381646,
#                     "percent_change_60d": 48.0182194,
#                     "percent_change_90d": 69.13644387,
#                     "market_cap": 465578459222.66364,
#                     "market_cap_dominance": 12.8116,
#                     "fully_diluted_market_cap": 465578459222.66,
#                     "tvl": null,
#                     "last_updated": "2024-12-15T21:46:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 825,
#             "name": "Tether USDt",
#             "symbol": "USDT",
#             "slug": "tether",
#             "num_market_pairs": 108420,
#             "date_added": "2015-02-25T00:00:00.000Z",
#             "tags": [
#                 "stablecoin",
#                 "asset-backed-stablecoin",
#                 "avalanche-ecosystem",
#                 "solana-ecosystem",
#                 "arbitrum-ecosytem",
#                 "moonriver-ecosystem",
#                 "injective-ecosystem",
#                 "bnb-chain",
#                 "usd-stablecoin",
#                 "optimism-ecosystem",
#                 "fiat-stablecoin"
#             ],
#             "max_supply": null,
#             "circulating_supply": 140253672849.47852,
#             "total_supply": 143442815980.75003,
#             "platform": {
#                 "id": 1027,
#                 "name": "Ethereum",
#                 "symbol": "ETH",
#                 "slug": "ethereum",
#                 "token_address": "0xdac17f958d2ee523a2206206994597c13d831ec7"
#             },
#             "infinite_supply": true,
#             "cmc_rank": 3,
#             "self_reported_circulating_supply": null,
#             "self_reported_market_cap": null,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-15T21:46:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 0.9996829253141716,
#                     "volume_24h": 98686762432.57756,
#                     "volume_change_24h": -6.4904,
#                     "percent_change_1h": 0.00633058,
#                     "percent_change_24h": -0.00652116,
#                     "percent_change_7d": -0.08764658,
#                     "percent_change_30d": -0.07711146,
#                     "percent_change_60d": -0.00906481,
#                     "percent_change_90d": -0.01809114,
#                     "market_cap": 140209201960.22348,
#                     "market_cap_dominance": 3.8612,
#                     "fully_diluted_market_cap": 143397333894.94,
#                     "tvl": null,
#                     "last_updated": "2024-12-15T21:46:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 52,
#             "name": "XRP",
#             "symbol": "XRP",
#             "slug": "xrp",
#             "num_market_pairs": 1477,
#             "date_added": "2013-08-04T00:00:00.000Z",
#             "tags": [
#                 "medium-of-exchange",
#                 "enterprise-solutions",
#                 "arrington-xrp-capital-portfolio",
#                 "galaxy-digital-portfolio",
#                 "a16z-portfolio",
#                 "pantera-capital-portfolio",
#                 "ftx-bankruptcy-estate",
#                 "2017-2018-alt-season"
#             ],
#             "max_supply": 100000000000,
#             "circulating_supply": 57187870382,
#             "total_supply": 99986858106,
#             "infinite_supply": false,
#             "platform": null,
#             "cmc_rank": 4,
#             "self_reported_circulating_supply": null,
#             "self_reported_market_cap": null,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-15T21:46:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 2.3870618719920853,
#                     "volume_24h": 5288497468.638848,
#                     "volume_change_24h": -33.3147,
#                     "percent_change_1h": -0.92342706,
#                     "percent_change_24h": -0.01851745,
#                     "percent_change_7d": -7.11600258,
#                     "percent_change_30d": 163.37006418,
#                     "percent_change_60d": 334.39112226,
#                     "percent_change_90d": 308.13785176,
#                     "market_cap": 136510984929.29765,
#                     "market_cap_dominance": 3.7549,
#                     "fully_diluted_market_cap": 238706187199.21,
#                     "tvl": null,
#                     "last_updated": "2024-12-15T21:46:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 5426,
#             "name": "Solana",
#             "symbol": "SOL",
#             "slug": "solana",
#             "num_market_pairs": 809,
#             "date_added": "2020-04-10T00:00:00.000Z",
#             "tags": [
#                 "pos",
#                 "platform",
#                 "solana-ecosystem",
#                 "cms-holdings-portfolio",
#                 "kenetic-capital-portfolio",
#                 "alameda-research-portfolio",
#                 "multicoin-capital-portfolio",
#                 "okx-ventures-portfolio",
#                 "layer-1",
#                 "ftx-bankruptcy-estate",
#                 "alleged-sec-securities",
#                 "cmc-crypto-awards-2024"
#             ],
#             "max_supply": null,
#             "circulating_supply": 479146256.76646066,
#             "total_supply": 590249005.3942467,
#             "infinite_supply": true,
#             "platform": null,
#             "cmc_rank": 5,
#             "self_reported_circulating_supply": null,
#             "self_reported_market_cap": null,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-15T21:46:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 217.82951409748958,
#                     "volume_24h": 2642508009.9938154,
#                     "volume_change_24h": -9.3788,
#                     "percent_change_1h": -1.33766741,
#                     "percent_change_24h": 0.10841473,
#                     "percent_change_7d": -7.58302684,
#                     "percent_change_30d": -0.05857103,
#                     "percent_change_60d": 41.67376224,
#                     "percent_change_90d": 65.87044924,
#                     "market_cap": 104372196293.0691,
#                     "market_cap_dominance": 2.8743,
#                     "fully_diluted_market_cap": 128573654041.56,
#                     "tvl": null,
#                     "last_updated": "2024-12-15T21:46:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 1839,
#             "name": "BNB",
#             "symbol": "BNB",
#             "slug": "bnb",
#             "num_market_pairs": 2305,
#             "date_added": "2017-07-25T00:00:00.000Z",
#             "tags": [
#                 "marketplace",
#                 "centralized-exchange",
#                 "payments",
#                 "smart-contracts",
#                 "alameda-research-portfolio",
#                 "multicoin-capital-portfolio",
#                 "bnb-chain",
#                 "layer-1",
#                 "alleged-sec-securities",
#                 "celsius-bankruptcy-estate"
#             ],
#             "max_supply": null,
#             "circulating_supply": 144008305.94,
#             "total_supply": 144008305.94,
#             "infinite_supply": false,
#             "platform": null,
#             "cmc_rank": 6,
#             "self_reported_circulating_supply": null,
#             "self_reported_market_cap": null,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-15T21:46:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 711.2231958444042,
#                     "volume_24h": 1734204047.7665265,
#                     "volume_change_24h": -12.2397,
#                     "percent_change_1h": -0.88795844,
#                     "percent_change_24h": -0.01215624,
#                     "percent_change_7d": -4.03396357,
#                     "percent_change_30d": 15.19277356,
#                     "percent_change_60d": 18.47206577,
#                     "percent_change_90d": 34.19991478,
#                     "market_cap": 102422047578.7855,
#                     "market_cap_dominance": 2.8206,
#                     "fully_diluted_market_cap": 102422047578.79,
#                     "tvl": null,
#                     "last_updated": "2024-12-15T21:46:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 74,
#             "name": "Dogecoin",
#             "symbol": "DOGE",
#             "slug": "dogecoin",
#             "num_market_pairs": 1128,
#             "date_added": "2013-12-15T00:00:00.000Z",
#             "tags": [
#                 "mineable",
#                 "pow",
#                 "scrypt",
#                 "medium-of-exchange",
#                 "memes",
#                 "payments",
#                 "doggone-doggerel",
#                 "bnb-chain",
#                 "ftx-bankruptcy-estate"
#             ],
#             "max_supply": null,
#             "circulating_supply": 147215486383.70523,
#             "total_supply": 147215486383.70523,
#             "infinite_supply": true,
#             "platform": null,
#             "cmc_rank": 7,
#             "self_reported_circulating_supply": null,
#             "self_reported_market_cap": null,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-15T21:46:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 0.39979793182587703,
#                     "volume_24h": 2461621582.206817,
#                     "volume_change_24h": -20.1197,
#                     "percent_change_1h": -0.62154135,
#                     "percent_change_24h": 2.04685554,
#                     "percent_change_7d": -13.86209497,
#                     "percent_change_30d": 7.26262224,
#                     "percent_change_60d": 214.74888307,
#                     "percent_change_90d": 303.80863,
#                     "market_cap": 58856446988.945915,
#                     "market_cap_dominance": 1.6189,
#                     "fully_diluted_market_cap": 58856446988.95,
#                     "tvl": null,
#                     "last_updated": "2024-12-15T21:46:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 3408,
#             "name": "USDC",
#             "symbol": "USDC",
#             "slug": "usd-coin",
#             "num_market_pairs": 23855,
#             "date_added": "2018-10-08T00:00:00.000Z",
#             "tags": [
#                 "medium-of-exchange",
#                 "stablecoin",
#                 "asset-backed-stablecoin",
#                 "coinbase-ventures-portfolio",
#                 "solana-ecosystem",
#                 "hedera-hashgraph-ecosystem",
#                 "arbitrum-ecosytem",
#                 "moonriver-ecosystem",
#                 "bnb-chain",
#                 "usd-stablecoin",
#                 "optimism-ecosystem",
#                 "base-ecosystem",
#                 "fiat-stablecoin"
#             ],
#             "max_supply": null,
#             "circulating_supply": 42075907984.99198,
#             "total_supply": 42075907984.99198,
#             "platform": {
#                 "id": 1027,
#                 "name": "Ethereum",
#                 "symbol": "ETH",
#                 "slug": "ethereum",
#                 "token_address": "0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48"
#             },
#             "infinite_supply": false,
#             "cmc_rank": 8,
#             "self_reported_circulating_supply": null,
#             "self_reported_market_cap": null,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-15T21:46:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 0.9999016549610098,
#                     "volume_24h": 6167102390.29397,
#                     "volume_change_24h": -2.7252,
#                     "percent_change_1h": -0.01108693,
#                     "percent_change_24h": 0.0119771,
#                     "percent_change_7d": -0.00238035,
#                     "percent_change_30d": -0.00762451,
#                     "percent_change_60d": -0.00327143,
#                     "percent_change_90d": 0.00599393,
#                     "market_cap": 42071770028.18065,
#                     "market_cap_dominance": 1.1577,
#                     "fully_diluted_market_cap": 42071770028.18,
#                     "tvl": null,
#                     "last_updated": "2024-12-15T21:46:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 2010,
#             "name": "Cardano",
#             "symbol": "ADA",
#             "slug": "cardano",
#             "num_market_pairs": 1389,
#             "date_added": "2017-10-01T00:00:00.000Z",
#             "tags": [
#                 "dpos",
#                 "pos",
#                 "platform",
#                 "research",
#                 "smart-contracts",
#                 "staking",
#                 "cardano-ecosystem",
#                 "cardano",
#                 "layer-1",
#                 "alleged-sec-securities",
#                 "2017-2018-alt-season"
#             ],
#             "max_supply": 45000000000,
#             "circulating_supply": 35112728715.27779,
#             "total_supply": 44995057356.92572,
#             "infinite_supply": false,
#             "platform": null,
#             "cmc_rank": 9,
#             "self_reported_circulating_supply": null,
#             "self_reported_market_cap": null,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-15T21:47:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 1.0691805777891743,
#                     "volume_24h": 882898085.5905334,
#                     "volume_change_24h": -15.3205,
#                     "percent_change_1h": -1.45127688,
#                     "percent_change_24h": 1.40095607,
#                     "percent_change_7d": -9.56452645,
#                     "percent_change_30d": 59.6234828,
#                     "percent_change_60d": 201.94816853,
#                     "percent_change_90d": 225.66945266,
#                     "market_cap": 37541847575.55524,
#                     "market_cap_dominance": 1.0331,
#                     "fully_diluted_market_cap": 48113126000.51,
#                     "tvl": null,
#                     "last_updated": "2024-12-15T21:47:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 1958,
#             "name": "TRON",
#             "symbol": "TRX",
#             "slug": "tron",
#             "num_market_pairs": 1082,
#             "date_added": "2017-09-13T00:00:00.000Z",
#             "tags": [
#                 "media",
#                 "payments",
#                 "tron-ecosystem",
#                 "layer-1",
#                 "dwf-labs-portfolio",
#                 "alleged-sec-securities",
#                 "2017-2018-alt-season"
#             ],
#             "max_supply": null,
#             "circulating_supply": 86242106165.70956,
#             "total_supply": 86242114264.27933,
#             "infinite_supply": true,
#             "platform": null,
#             "cmc_rank": 10,
#             "self_reported_circulating_supply": null,
#             "self_reported_market_cap": null,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-15T21:47:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 0.28034808659633104,
#                     "volume_24h": 734083764.1526438,
#                     "volume_change_24h": -31.3752,
#                     "percent_change_1h": -1.44323962,
#                     "percent_change_24h": 0.03080806,
#                     "percent_change_7d": -11.63234535,
#                     "percent_change_30d": 48.24993204,
#                     "percent_change_60d": 75.28325802,
#                     "percent_change_90d": 88.63911314,
#                     "market_cap": 24177809447.59432,
#                     "market_cap_dominance": 0.665,
#                     "fully_diluted_market_cap": 24177811718.01,
#                     "tvl": null,
#                     "last_updated": "2024-12-15T21:47:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 5805,
#             "name": "Avalanche",
#             "symbol": "AVAX",
#             "slug": "avalanche",
#             "num_market_pairs": 821,
#             "date_added": "2020-07-13T00:00:00.000Z",
#             "tags": [
#                 "defi",
#                 "smart-contracts",
#                 "three-arrows-capital-portfolio",
#                 "polychain-capital-portfolio",
#                 "avalanche-ecosystem",
#                 "cms-holdings-portfolio",
#                 "dragonfly-capital-portfolio",
#                 "real-world-assets",
#                 "layer-1"
#             ],
#             "max_supply": 715748719,
#             "circulating_supply": 409697639.4586511,
#             "total_supply": 448033939.4586511,
#             "infinite_supply": false,
#             "platform": null,
#             "cmc_rank": 11,
#             "self_reported_circulating_supply": null,
#             "self_reported_market_cap": null,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-15T21:46:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 49.218647583411546,
#                     "volume_24h": 640989500.8290635,
#                     "volume_change_24h": -12.6674,
#                     "percent_change_1h": -1.8517825,
#                     "percent_change_24h": -1.4191088,
#                     "percent_change_7d": -8.29131695,
#                     "percent_change_30d": 49.29032316,
#                     "percent_change_60d": 76.37941867,
#                     "percent_change_90d": 110.32650182,
#                     "market_cap": 20164763732.270954,
#                     "market_cap_dominance": 0.5543,
#                     "fully_diluted_market_cap": 35228183958.74,
#                     "tvl": null,
#                     "last_updated": "2024-12-15T21:46:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 1975,
#             "name": "Chainlink",
#             "symbol": "LINK",
#             "slug": "chainlink",
#             "num_market_pairs": 1898,
#             "date_added": "2017-09-20T00:00:00.000Z",
#             "tags": [
#                 "platform",
#                 "defi",
#                 "oracles",
#                 "smart-contracts",
#                 "substrate",
#                 "polkadot",
#                 "avalanche-ecosystem",
#                 "solana-ecosystem",
#                 "framework-ventures-portfolio",
#                 "polygon-ecosystem",
#                 "fantom-ecosystem",
#                 "cardano-ecosystem",
#                 "web3",
#                 "near-protocol-ecosystem",
#                 "arbitrum-ecosytem",
#                 "cardano",
#                 "injective-ecosystem",
#                 "optimism-ecosystem",
#                 "real-world-assets",
#                 "celsius-bankruptcy-estate"
#             ],
#             "max_supply": null,
#             "circulating_supply": 626849970.4527867,
#             "total_supply": 1000000000,
#             "platform": {
#                 "id": 1027,
#                 "name": "Ethereum",
#                 "symbol": "ETH",
#                 "slug": "ethereum",
#                 "token_address": "0x514910771af9ca656af840dff83e8264ecf986ca"
#             },
#             "infinite_supply": false,
#             "cmc_rank": 12,
#             "self_reported_circulating_supply": null,
#             "self_reported_market_cap": null,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-15T21:47:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 28.33742975850578,
#                     "volume_24h": 1333306034.8154638,
#                     "volume_change_24h": -41.1594,
#                     "percent_change_1h": -1.84980599,
#                     "percent_change_24h": -4.17864893,
#                     "percent_change_7d": 8.33758311,
#                     "percent_change_30d": 105.47696402,
#                     "percent_change_60d": 151.86707092,
#                     "percent_change_90d": 170.31375316,
#                     "market_cap": 17763317006.827267,
#                     "market_cap_dominance": 0.4886,
#                     "fully_diluted_market_cap": 28337429758.51,
#                     "tvl": null,
#                     "last_updated": "2024-12-15T21:47:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 11419,
#             "name": "Toncoin",
#             "symbol": "TON",
#             "slug": "toncoin",
#             "num_market_pairs": 634,
#             "date_added": "2021-08-26T13:40:22.000Z",
#             "tags": [
#                 "pos",
#                 "layer-1",
#                 "ftx-bankruptcy-estate",
#                 "dwf-labs-portfolio",
#                 "toncoin-ecosystem"
#             ],
#             "max_supply": null,
#             "circulating_supply": 2551167407.1028643,
#             "total_supply": 5117479413.312785,
#             "infinite_supply": true,
#             "platform": null,
#             "cmc_rank": 13,
#             "self_reported_circulating_supply": 3414166606,
#             "self_reported_market_cap": 21539808916.621616,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-15T21:46:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 6.308950734497816,
#                     "volume_24h": 205562678.71823883,
#                     "volume_change_24h": -7.7235,
#                     "percent_change_1h": -1.31013353,
#                     "percent_change_24h": 2.43895456,
#                     "percent_change_7d": -6.53558391,
#                     "percent_change_30d": 17.4353811,
#                     "percent_change_60d": 20.42817767,
#                     "percent_change_90d": 15.73360019,
#                     "market_cap": 16095189486.868504,
#                     "market_cap_dominance": 0.4432,
#                     "fully_diluted_market_cap": 32285925503.4,
#                     "tvl": null,
#                     "last_updated": "2024-12-15T21:46:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 5994,
#             "name": "Shiba Inu",
#             "symbol": "SHIB",
#             "slug": "shiba-inu",
#             "num_market_pairs": 917,
#             "date_added": "2020-08-01T00:00:00.000Z",
#             "tags": [
#                 "memes",
#                 "ethereum-ecosystem",
#                 "doggone-doggerel"
#             ],
#             "max_supply": null,
#             "circulating_supply": 589255537557602.8,
#             "total_supply": 589508581438258.8,
#             "platform": {
#                 "id": 1027,
#                 "name": "Ethereum",
#                 "symbol": "ETH",
#                 "slug": "ethereum",
#                 "token_address": "0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce"
#             },
#             "infinite_supply": false,
#             "cmc_rank": 14,
#             "self_reported_circulating_supply": null,
#             "self_reported_market_cap": null,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-15T21:47:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 2.7237218536652394e-05,
#                     "volume_24h": 520526780.04628515,
#                     "volume_change_24h": -31.3395,
#                     "percent_change_1h": -1.27976836,
#                     "percent_change_24h": -0.04884238,
#                     "percent_change_7d": -14.71243492,
#                     "percent_change_30d": 8.71116116,
#                     "percent_change_60d": 45.64662801,
#                     "percent_change_90d": 107.75778842,
#                     "market_cap": 16049681850.38901,
#                     "market_cap_dominance": 0.4412,
#                     "fully_diluted_market_cap": 16056574061.87,
#                     "tvl": null,
#                     "last_updated": "2024-12-15T21:47:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 20947,
#             "name": "Sui",
#             "symbol": "SUI",
#             "slug": "sui",
#             "num_market_pairs": 467,
#             "date_added": "2022-07-12T08:03:11.000Z",
#             "tags": [
#                 "binance-launchpool",
#                 "coinbase-ventures-portfolio",
#                 "binance-labs-portfolio",
#                 "electric-capital-portfolio",
#                 "a16z-portfolio",
#                 "sui-ecosystem",
#                 "layer-1",
#                 "move-vm"
#             ],
#             "max_supply": 10000000000,
#             "circulating_supply": 2927660018.558888,
#             "total_supply": 10000000000,
#             "infinite_supply": false,
#             "platform": null,
#             "cmc_rank": 15,
#             "self_reported_circulating_supply": null,
#             "self_reported_market_cap": null,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-15T21:46:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 4.686563102779741,
#                     "volume_24h": 1377742097.6544523,
#                     "volume_change_24h": 4.551,
#                     "percent_change_1h": -1.93609248,
#                     "percent_change_24h": 5.57849382,
#                     "percent_change_7d": 11.36298549,
#                     "percent_change_30d": 35.45263024,
#                     "percent_change_60d": 121.65049793,
#                     "percent_change_90d": 352.37052477,
#                     "market_cap": 13720663420.461535,
#                     "market_cap_dominance": 0.3776,
#                     "fully_diluted_market_cap": 46865631027.8,
#                     "tvl": null,
#                     "last_updated": "2024-12-15T21:46:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 6636,
#             "name": "Polkadot",
#             "symbol": "DOT",
#             "slug": "polkadot-new",
#             "num_market_pairs": 850,
#             "date_added": "2020-08-19T00:00:00.000Z",
#             "tags": [
#                 "substrate",
#                 "polkadot",
#                 "polkadot-ecosystem",
#                 "three-arrows-capital-portfolio",
#                 "polychain-capital-portfolio",
#                 "arrington-xrp-capital-portfolio",
#                 "blockchain-capital-portfolio",
#                 "boostvc-portfolio",
#                 "cms-holdings-portfolio",
#                 "coinfund-portfolio",
#                 "fabric-ventures-portfolio",
#                 "fenbushi-capital-portfolio",
#                 "hashkey-capital-portfolio",
#                 "kenetic-capital-portfolio",
#                 "1confirmation-portfolio",
#                 "placeholder-ventures-portfolio",
#                 "pantera-capital-portfolio",
#                 "exnetwork-capital-portfolio",
#                 "web3",
#                 "spartan-group",
#                 "layer-1"
#             ],
#             "max_supply": null,
#             "circulating_supply": 1529018770.694863,
#             "total_supply": 1529018770.694863,
#             "infinite_supply": true,
#             "platform": null,
#             "cmc_rank": 16,
#             "self_reported_circulating_supply": 1529016549.817319,
#             "self_reported_market_cap": 13455232672.445038,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-15T21:46:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 8.799926118558114,
#                     "volume_24h": 585409685.2016958,
#                     "volume_change_24h": 8.5316,
#                     "percent_change_1h": -1.24872988,
#                     "percent_change_24h": 3.91562384,
#                     "percent_change_7d": -14.93934208,
#                     "percent_change_30d": 71.29878676,
#                     "percent_change_60d": 103.50237392,
#                     "percent_change_90d": 110.73482924,
#                     "market_cap": 13455252216.003345,
#                     "market_cap_dominance": 0.3701,
#                     "fully_diluted_market_cap": 13455252216,
#                     "tvl": null,
#                     "last_updated": "2024-12-15T21:46:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 512,
#             "name": "Stellar",
#             "symbol": "XLM",
#             "slug": "stellar",
#             "num_market_pairs": 648,
#             "date_added": "2014-08-05T00:00:00.000Z",
#             "tags": [
#                 "medium-of-exchange",
#                 "enterprise-solutions",
#                 "decentralized-exchange-dex-token",
#                 "smart-contracts",
#                 "hashkey-capital-portfolio",
#                 "2017-2018-alt-season"
#             ],
#             "max_supply": 50001806812,
#             "circulating_supply": 30177014259.829643,
#             "total_supply": 50001786911.162926,
#             "infinite_supply": false,
#             "platform": null,
#             "cmc_rank": 17,
#             "self_reported_circulating_supply": null,
#             "self_reported_market_cap": null,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-15T21:46:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 0.4216945601273582,
#                     "volume_24h": 408466312.45210904,
#                     "volume_change_24h": -25.7569,
#                     "percent_change_1h": -1.22261814,
#                     "percent_change_24h": 1.23200215,
#                     "percent_change_7d": -13.92712308,
#                     "percent_change_30d": 199.30850978,
#                     "percent_change_60d": 344.08018896,
#                     "percent_change_90d": 345.85569447,
#                     "market_cap": 12725482754.255877,
#                     "market_cap_dominance": 0.3504,
#                     "fully_diluted_market_cap": 21085489929.16,
#                     "tvl": null,
#                     "last_updated": "2024-12-15T21:46:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 4642,
#             "name": "Hedera",
#             "symbol": "HBAR",
#             "slug": "hedera",
#             "num_market_pairs": 297,
#             "date_added": "2019-09-17T00:00:00.000Z",
#             "tags": [
#                 "dag",
#                 "marketplace",
#                 "enterprise-solutions",
#                 "defi",
#                 "payments",
#                 "dcg-portfolio",
#                 "hedera-hashgraph-ecosystem",
#                 "layer-1"
#             ],
#             "max_supply": 50000000000,
#             "circulating_supply": 38238361609.50115,
#             "total_supply": 50000000000,
#             "infinite_supply": false,
#             "platform": null,
#             "cmc_rank": 18,
#             "self_reported_circulating_supply": null,
#             "self_reported_market_cap": null,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-15T21:46:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 0.2872944245368529,
#                     "volume_24h": 550943268.6447077,
#                     "volume_change_24h": -28.7477,
#                     "percent_change_1h": -1.51223947,
#                     "percent_change_24h": -1.02219856,
#                     "percent_change_7d": -12.93019587,
#                     "percent_change_30d": 298.44710225,
#                     "percent_change_60d": 433.62815925,
#                     "percent_change_90d": 482.09871542,
#                     "market_cap": 10985668093.833721,
#                     "market_cap_dominance": 0.3022,
#                     "fully_diluted_market_cap": 14364721226.84,
#                     "tvl": null,
#                     "last_updated": "2024-12-15T21:46:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 1831,
#             "name": "Bitcoin Cash",
#             "symbol": "BCH",
#             "slug": "bitcoin-cash",
#             "num_market_pairs": 957,
#             "date_added": "2017-07-23T00:00:00.000Z",
#             "tags": [
#                 "mineable",
#                 "pow",
#                 "sha-256",
#                 "marketplace",
#                 "medium-of-exchange",
#                 "store-of-value",
#                 "enterprise-solutions",
#                 "payments",
#                 "bitcoin-ecosystem",
#                 "layer-1",
#                 "2017-2018-alt-season"
#             ],
#             "max_supply": 21000000,
#             "circulating_supply": 19802340.625,
#             "total_supply": 19802340.625,
#             "infinite_supply": false,
#             "platform": null,
#             "cmc_rank": 19,
#             "self_reported_circulating_supply": null,
#             "self_reported_market_cap": null,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-15T21:46:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 531.0791035685719,
#                     "volume_24h": 392399093.353862,
#                     "volume_change_24h": -10.418,
#                     "percent_change_1h": -1.196197,
#                     "percent_change_24h": 1.32457194,
#                     "percent_change_7d": -14.13806081,
#                     "percent_change_30d": 22.21260792,
#                     "percent_change_60d": 46.44586675,
#                     "percent_change_90d": 71.40589892,
#                     "market_cap": 10516609307.684513,
#                     "market_cap_dominance": 0.2893,
#                     "fully_diluted_market_cap": 11152661174.94,
#                     "tvl": null,
#                     "last_updated": "2024-12-15T21:46:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 7083,
#             "name": "Uniswap",
#             "symbol": "UNI",
#             "slug": "uniswap",
#             "num_market_pairs": 1142,
#             "date_added": "2020-09-17T00:00:00.000Z",
#             "tags": [
#                 "decentralized-exchange-dex-token",
#                 "defi",
#                 "dao",
#                 "yield-farming",
#                 "amm",
#                 "coinbase-ventures-portfolio",
#                 "three-arrows-capital-portfolio",
#                 "governance",
#                 "blockchain-capital-portfolio",
#                 "defiance-capital-portfolio",
#                 "alameda-research-portfolio",
#                 "a16z-portfolio",
#                 "pantera-capital-portfolio",
#                 "parafi-capital",
#                 "paradigm-portfolio",
#                 "arbitrum-ecosytem",
#                 "injective-ecosystem",
#                 "optimism-ecosystem",
#                 "cmc-crypto-awards-2024"
#             ],
#             "max_supply": null,
#             "circulating_supply": 600483073.71,
#             "total_supply": 1000000000,
#             "platform": {
#                 "id": 1027,
#                 "name": "Ethereum",
#                 "symbol": "ETH",
#                 "slug": "ethereum",
#                 "token_address": "0x1f9840a85d5af5bf1d1762f925bdaddc4201f984"
#             },
#             "infinite_supply": false,
#             "cmc_rank": 20,
#             "self_reported_circulating_supply": null,
#             "self_reported_market_cap": null,
#             "tvl_ratio": 1.90089644,
#             "last_updated": "2024-12-15T21:46:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 16.466575399001023,
#                     "volume_24h": 441300949.2420568,
#                     "volume_change_24h": -22.2836,
#                     "percent_change_1h": -1.66381847,
#                     "percent_change_24h": -1.89966136,
#                     "percent_change_7d": -10.34158362,
#                     "percent_change_30d": 94.5948381,
#                     "percent_change_60d": 116.1022777,
#                     "percent_change_90d": 158.26384087,
#                     "market_cap": 9887899809.069605,
#                     "market_cap_dominance": 0.272,
#                     "fully_diluted_market_cap": 16466575399,
#                     "tvl": 5201703562.71899,
#                     "last_updated": "2024-12-15T21:46:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 24478,
#             "name": "Pepe",
#             "symbol": "PEPE",
#             "slug": "pepe",
#             "num_market_pairs": 488,
#             "date_added": "2023-04-17T06:18:08.000Z",
#             "tags": [
#                 "memes"
#             ],
#             "max_supply": 420690000000000,
#             "circulating_supply": 420689899999994.8,
#             "total_supply": 420689899999994.8,
#             "platform": {
#                 "id": 1027,
#                 "name": "Ethereum",
#                 "symbol": "ETH",
#                 "slug": "ethereum",
#                 "token_address": "0x6982508145454ce325ddbe47a25d4ec3d2311933"
#             },
#             "infinite_supply": false,
#             "cmc_rank": 21,
#             "self_reported_circulating_supply": null,
#             "self_reported_market_cap": null,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-15T21:47:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 2.3378515555442334e-05,
#                     "volume_24h": 1449363466.9861412,
#                     "volume_change_24h": -16.8204,
#                     "percent_change_1h": -1.67172229,
#                     "percent_change_24h": 0.72312984,
#                     "percent_change_7d": -11.15857956,
#                     "percent_change_30d": 6.13394048,
#                     "percent_change_60d": 121.28107014,
#                     "percent_change_90d": 227.32703883,
#                     "market_cap": 9835105371.167358,
#                     "market_cap_dominance": 0.2703,
#                     "fully_diluted_market_cap": 9835107709.02,
#                     "tvl": null,
#                     "last_updated": "2024-12-15T21:47:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 2,
#             "name": "Litecoin",
#             "symbol": "LTC",
#             "slug": "litecoin",
#             "num_market_pairs": 1288,
#             "date_added": "2013-04-28T00:00:00.000Z",
#             "tags": [
#                 "mineable",
#                 "pow",
#                 "scrypt",
#                 "medium-of-exchange",
#                 "2017-2018-alt-season"
#             ],
#             "max_supply": 84000000,
#             "circulating_supply": 75310268.30410936,
#             "total_supply": 84000000,
#             "infinite_supply": false,
#             "platform": null,
#             "cmc_rank": 22,
#             "self_reported_circulating_supply": null,
#             "self_reported_market_cap": null,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-15T21:46:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 117.27482901817258,
#                     "volume_24h": 685929750.2984713,
#                     "volume_change_24h": -20.2694,
#                     "percent_change_1h": -1.63481114,
#                     "percent_change_24h": 0.23793868,
#                     "percent_change_7d": -11.99030629,
#                     "percent_change_30d": 39.4663213,
#                     "percent_change_60d": 67.70072982,
#                     "percent_change_90d": 88.36402957,
#                     "market_cap": 8831998838.677128,
#                     "market_cap_dominance": 0.2429,
#                     "fully_diluted_market_cap": 9851085637.53,
#                     "tvl": null,
#                     "last_updated": "2024-12-15T21:46:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 3957,
#             "name": "UNUS SED LEO",
#             "symbol": "LEO",
#             "slug": "unus-sed-leo",
#             "num_market_pairs": 53,
#             "date_added": "2019-05-21T00:00:00.000Z",
#             "tags": [
#                 "marketplace",
#                 "centralized-exchange",
#                 "discount-token",
#                 "payments",
#                 "kenetic-capital-portfolio",
#                 "alameda-research-portfolio"
#             ],
#             "max_supply": null,
#             "circulating_supply": 924519166.9,
#             "total_supply": 985239504,
#             "platform": {
#                 "id": 1027,
#                 "name": "Ethereum",
#                 "symbol": "ETH",
#                 "slug": "ethereum",
#                 "token_address": "0x2af5d2ad76741191d15dfe7bf6ac92d4bd912ca3"
#             },
#             "infinite_supply": false,
#             "cmc_rank": 23,
#             "self_reported_circulating_supply": null,
#             "self_reported_market_cap": null,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-15T21:47:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 9.362148342956157,
#                     "volume_24h": 401847.16920923,
#                     "volume_change_24h": 15.7779,
#                     "percent_change_1h": 0.10476785,
#                     "percent_change_24h": -0.16848193,
#                     "percent_change_7d": 1.4818216,
#                     "percent_change_30d": 21.49097843,
#                     "percent_change_60d": 52.73118289,
#                     "percent_change_90d": 63.21649506,
#                     "market_cap": 8655485586.424042,
#                     "market_cap_dominance": 0.2379,
#                     "fully_diluted_market_cap": 9223958389.79,
#                     "tvl": null,
#                     "last_updated": "2024-12-15T21:47:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 6535,
#             "name": "NEAR Protocol",
#             "symbol": "NEAR",
#             "slug": "near-protocol",
#             "num_market_pairs": 476,
#             "date_added": "2020-08-11T00:00:00.000Z",
#             "tags": [
#                 "platform",
#                 "ai-big-data",
#                 "staking",
#                 "coinbase-ventures-portfolio",
#                 "three-arrows-capital-portfolio",
#                 "arrington-xrp-capital-portfolio",
#                 "coinfund-portfolio",
#                 "electric-capital-portfolio",
#                 "fabric-ventures-portfolio",
#                 "kenetic-capital-portfolio",
#                 "near-protocol-ecosystem",
#                 "cross-chain",
#                 "injective-ecosystem",
#                 "circle-ventures-portfolio",
#                 "layer-1",
#                 "alleged-sec-securities",
#                 "account-abstraction",
#                 "data-availability"
#             ],
#             "max_supply": null,
#             "circulating_supply": 1217906155,
#             "total_supply": 1225347071,
#             "infinite_supply": false,
#             "platform": null,
#             "cmc_rank": 24,
#             "self_reported_circulating_supply": null,
#             "self_reported_market_cap": null,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-15T21:46:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 6.666345073560206,
#                     "volume_24h": 301279568.4695526,
#                     "volume_change_24h": -20.6559,
#                     "percent_change_1h": -1.54703726,
#                     "percent_change_24h": 1.11322049,
#                     "percent_change_7d": -13.59979198,
# ...
#                     "percent_change_7d": -17.68194558,
#                     "percent_change_30d": -1.5838071,
#                     "percent_change_60d": 28.0852798,
#                     "percent_change_90d": 41.79275322,
#                     "market_cap": 1289298018.9467666,
#                     "market_cap_dominance": 0.0355,
#                     "fully_diluted_market_cap": 1289298018.95,
#                     "tvl": null,
#                     "last_updated": "2024-12-15T21:46:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 16086,
#             "name": "BitTorrent [New]",
#             "symbol": "BTT",
#             "slug": "bittorrent-new",
#             "num_market_pairs": 176,
#             "date_added": "2019-01-31T00:00:00.000Z",
#             "tags": [
#                 "platform",
#                 "distributed-computing",
#                 "filesharing",
#                 "interoperability",
#                 "staking",
#                 "tron-ecosystem",
#                 "storage",
#                 "binance-launchpad",
#                 "binance-labs-portfolio",
#                 "web3",
#                 "bnb-chain",
#                 "alleged-sec-securities",
#                 "depin"
#             ],
#             "max_supply": null,
#             "circulating_supply": 968246428571000,
#             "total_supply": 990000000000000,
#             "platform": {
#                 "id": 1958,
#                 "name": "Tron20",
#                 "symbol": "TRX",
#                 "slug": "tron",
#                 "token_address": "TAFjULxiVgT4qWk6UZwjqwZXTSaGaqnVp4"
#             },
#             "infinite_supply": false,
#             "cmc_rank": 93,
#             "self_reported_circulating_supply": null,
#             "self_reported_market_cap": null,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-15T21:46:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 1.3046341915929235e-06,
#                     "volume_24h": 30206031.80705912,
#                     "volume_change_24h": -12.73,
#                     "percent_change_1h": -1.3006258,
#                     "percent_change_24h": 1.24287284,
#                     "percent_change_7d": -15.73893906,
#                     "percent_change_30d": 18.75064632,
#                     "percent_change_60d": 40.49706491,
#                     "percent_change_90d": 55.64502542,
#                     "market_cap": 1263207396.601462,
#                     "market_cap_dominance": 0.0348,
#                     "fully_diluted_market_cap": 1291587849.68,
#                     "tvl": null,
#                     "last_updated": "2024-12-15T21:46:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 6892,
#             "name": "MultiversX",
#             "symbol": "EGLD",
#             "slug": "multiversx-egld",
#             "num_market_pairs": 277,
#             "date_added": "2020-09-04T00:00:00.000Z",
#             "tags": [
#                 "pos",
#                 "enterprise-solutions",
#                 "distributed-computing",
#                 "loyalty",
#                 "defi",
#                 "gaming",
#                 "identity",
#                 "payments",
#                 "scaling",
#                 "smart-contracts",
#                 "software",
#                 "binance-launchpad",
#                 "binance-labs-portfolio",
#                 "metaverse",
#                 "electric-capital-portfolio",
#                 "exnetwork-capital-portfolio",
#                 "mobile-payment",
#                 "web3",
#                 "elrond-ecosystem",
#                 "injective-ecosystem",
#                 "bnb-chain",
#                 "layer-1",
#                 "dwf-labs-portfolio",
#                 "multiversx-ecosystem",
#                 "depin"
#             ],
#             "max_supply": 31415926,
#             "circulating_supply": 27661747.44302762,
#             "total_supply": 27721611,
#             "infinite_supply": false,
#             "platform": null,
#             "cmc_rank": 94,
#             "self_reported_circulating_supply": 27721611,
#             "self_reported_market_cap": 1262963341.0939422,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-15T21:46:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 45.558800355936825,
#                     "volume_24h": 66206162.88271013,
#                     "volume_change_24h": 28.8923,
#                     "percent_change_1h": -2.12366898,
#                     "percent_change_24h": -0.03552209,
#                     "percent_change_7d": -15.46921972,
#                     "percent_change_30d": 58.47868316,
#                     "percent_change_60d": 72.78930036,
#                     "percent_change_90d": 84.50748301,
#                     "market_cap": 1260236029.2532413,
#                     "market_cap_dominance": 0.0347,
#                     "fully_diluted_market_cap": 1431271900.63,
#                     "tvl": null,
#                     "last_updated": "2024-12-15T21:46:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 23254,
#             "name": "Core",
#             "symbol": "CORE",
#             "slug": "core-dao",
#             "num_market_pairs": 82,
#             "date_added": "2023-02-08T12:26:11.000Z",
#             "tags": [],
#             "max_supply": 2100000000,
#             "circulating_supply": 929003658.21966,
#             "total_supply": 2093769839.0352812,
#             "infinite_supply": false,
#             "platform": null,
#             "cmc_rank": 95,
#             "self_reported_circulating_supply": null,
#             "self_reported_market_cap": null,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-15T21:46:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 1.3531806278975127,
#                     "volume_24h": 53958059.86510296,
#                     "volume_change_24h": -37.0834,
#                     "percent_change_1h": -1.97028015,
#                     "percent_change_24h": -0.79478372,
#                     "percent_change_7d": -11.76526278,
#                     "percent_change_30d": 45.33542462,
#                     "percent_change_60d": 40.41466043,
#                     "percent_change_90d": 52.22585121,
#                     "market_cap": 1257109753.548766,
#                     "market_cap_dominance": 0.0346,
#                     "fully_diluted_market_cap": 2841679318.58,
#                     "tvl": null,
#                     "last_updated": "2024-12-15T21:46:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 1376,
#             "name": "Neo",
#             "symbol": "NEO",
#             "slug": "neo",
#             "num_market_pairs": 356,
#             "date_added": "2016-09-08T00:00:00.000Z",
#             "tags": [
#                 "platform",
#                 "enterprise-solutions",
#                 "smart-contracts",
#                 "2017-2018-alt-season"
#             ],
#             "max_supply": 100000000,
#             "circulating_supply": 70538831,
#             "total_supply": 100000000,
#             "infinite_supply": false,
#             "platform": null,
#             "cmc_rank": 96,
#             "self_reported_circulating_supply": null,
#             "self_reported_market_cap": null,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-15T21:46:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 17.78112496388852,
#                     "volume_24h": 44000184.8165979,
#                     "volume_change_24h": -12.7405,
#                     "percent_change_1h": -1.97431359,
#                     "percent_change_24h": 1.40415233,
#                     "percent_change_7d": -15.37893774,
#                     "percent_change_30d": 54.31070412,
#                     "percent_change_60d": 66.87253805,
#                     "percent_change_90d": 96.05934406,
#                     "market_cap": 1254259768.8176134,
#                     "market_cap_dominance": 0.0345,
#                     "fully_diluted_market_cap": 1778112496.39,
#                     "tvl": null,
#                     "last_updated": "2024-12-15T21:46:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 2634,
#             "name": "XDC Network",
#             "symbol": "XDC",
#             "slug": "xdc-network",
#             "num_market_pairs": 117,
#             "date_added": "2018-04-12T00:00:00.000Z",
#             "tags": [
#                 "enterprise-solutions",
#                 "masternodes",
#                 "smart-contracts",
#                 "xdc-ecosystem",
#                 "real-world-assets",
#                 "layer-1"
#             ],
#             "max_supply": null,
#             "circulating_supply": 14932919359.85,
#             "total_supply": 37951146329.85,
#             "infinite_supply": false,
#             "platform": null,
#             "cmc_rank": 97,
#             "self_reported_circulating_supply": 14930334691.55,
#             "self_reported_market_cap": 1228500792.7396603,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-15T21:46:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 0.08228220050786571,
#                     "volume_24h": 35618915.84365905,
#                     "volume_change_24h": 9.1055,
#                     "percent_change_1h": -2.03346008,
#                     "percent_change_24h": 4.10215187,
#                     "percent_change_7d": -10.95592464,
#                     "percent_change_30d": 171.8544416,
#                     "percent_change_60d": 198.46258002,
#                     "percent_change_90d": 196.63189958,
#                     "market_cap": 1228713464.9349673,
#                     "market_cap_dominance": 0.0338,
#                     "fully_diluted_market_cap": 3122703831.82,
#                     "tvl": null,
#                     "last_updated": "2024-12-15T21:46:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 4269,
#             "name": "GateToken",
#             "symbol": "GT",
#             "slug": "gatetoken",
#             "num_market_pairs": 28,
#             "date_added": "2019-08-20T00:00:00.000Z",
#             "tags": [
#                 "marketplace",
#                 "centralized-exchange",
#                 "discount-token",
#                 "ftx-bankruptcy-estate"
#             ],
#             "max_supply": null,
#             "circulating_supply": 88722559.87848262,
#             "total_supply": 300000000,
#             "platform": {
#                 "id": 1027,
#                 "name": "Ethereum",
#                 "symbol": "ETH",
#                 "slug": "ethereum",
#                 "token_address": "0xe66747a101bff2dba3697199dcce5b743b454759"
#             },
#             "infinite_supply": false,
#             "cmc_rank": 98,
#             "self_reported_circulating_supply": null,
#             "self_reported_market_cap": null,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-15T21:46:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 13.44053952659992,
#                     "volume_24h": 6839520.72434557,
#                     "volume_change_24h": -25.1394,
#                     "percent_change_1h": 0.04412918,
#                     "percent_change_24h": 1.26147355,
#                     "percent_change_7d": 4.12555602,
#                     "percent_change_30d": 42.61328919,
#                     "percent_change_60d": 47.74457833,
#                     "percent_change_90d": 68.90280297,
#                     "market_cap": 1192479072.9478738,
#                     "market_cap_dominance": 0.0328,
#                     "fully_diluted_market_cap": 4032161857.98,
#                     "tvl": null,
#                     "last_updated": "2024-12-15T21:46:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 1966,
#             "name": "Decentraland",
#             "symbol": "MANA",
#             "slug": "decentraland",
#             "num_market_pairs": 544,
#             "date_added": "2017-09-17T00:00:00.000Z",
#             "tags": [
#                 "platform",
#                 "collectibles-nfts",
#                 "gaming",
#                 "payments",
#                 "metaverse",
#                 "boostvc-portfolio",
#                 "dcg-portfolio",
#                 "fabric-ventures-portfolio",
#                 "kenetic-capital-portfolio",
#                 "polygon-ecosystem",
#                 "play-to-earn",
#                 "alleged-sec-securities"
#             ],
#             "max_supply": null,
#             "circulating_supply": 1942255184.1130493,
#             "total_supply": 2193179327.320146,
#             "platform": {
#                 "id": 1027,
#                 "name": "Ethereum",
#                 "symbol": "ETH",
#                 "slug": "ethereum",
#                 "token_address": "0x0f5d2fb29fb7d3cfee444a200298f468908cc942"
#             },
#             "infinite_supply": false,
#             "cmc_rank": 99,
#             "self_reported_circulating_supply": null,
#             "self_reported_market_cap": null,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-15T21:47:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 0.6123867485699507,
#                     "volume_24h": 126907796.6435536,
#                     "volume_change_24h": -1.7776,
#                     "percent_change_1h": -1.99172805,
#                     "percent_change_24h": 1.18318169,
#                     "percent_change_7d": -16.57922377,
#                     "percent_change_30d": 78.10865608,
#                     "percent_change_60d": 99.59189824,
#                     "percent_change_90d": 133.82858576,
#                     "market_cap": 1189411337.0921211,
#                     "market_cap_dominance": 0.0327,
#                     "fully_diluted_market_cap": 1343073957.29,
#                     "tvl": null,
#                     "last_updated": "2024-12-15T21:47:00.000Z"
#                 }
#             }
#         },
#         {
#             "id": 6783,
#             "name": "Axie Infinity",
#             "symbol": "AXS",
#             "slug": "axie-infinity",
#             "num_market_pairs": 497,
#             "date_added": "2020-08-31T00:00:00.000Z",
#             "tags": [
#                 "collectibles-nfts",
#                 "gaming",
#                 "binance-launchpad",
#                 "metaverse",
#                 "defiance-capital-portfolio",
#                 "play-to-earn",
#                 "animoca-brands-portfolio",
#                 "alleged-sec-securities"
#             ],
#             "max_supply": null,
#             "circulating_supply": 155828417.79405698,
#             "total_supply": 270000000,
#             "platform": {
#                 "id": 1027,
#                 "name": "Ethereum",
#                 "symbol": "ETH",
#                 "slug": "ethereum",
#                 "token_address": "0xbb0e17ef65f82ab018d8edd776e8dd940327b28b"
#             },
#             "infinite_supply": false,
#             "cmc_rank": 100,
#             "self_reported_circulating_supply": 155828255.8882171,
#             "self_reported_market_cap": 1176433181.7787492,
#             "tvl_ratio": null,
#             "last_updated": "2024-12-15T21:46:00.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 7.54954982376662,
#                     "volume_24h": 90964437.03476776,
#                     "volume_change_24h": 0.6109,
#                     "percent_change_1h": -1.52546984,
#                     "percent_change_24h": 0.58941742,
#                     "percent_change_7d": -19.05804116,
#                     "percent_change_30d": 44.06894944,
#                     "percent_change_60d": 58.32326345,
#                     "percent_change_90d": 68.60598451,
#                     "market_cap": 1176434404.0949543,
#                     "market_cap_dominance": 0.0324,
#                     "fully_diluted_market_cap": 2038378452.42,
#                     "tvl": null,
#                     "last_updated": "2024-12-15T21:46:00.000Z"
#                 }
#             }
#         }
#     ]
# }

# %%
organized_data = []
for item in data['data']:
    btc_info = {
        "id": item['id'],
        "name": item['name'],
        "symbol": item['symbol'],
        "cmc_rank": item['cmc_rank'],
        "price": item['quote']['USD']['price'],
        "volume_24h": item['quote']['USD']['volume_24h'],
        "market_cap": item['quote']['USD']['market_cap'],
        "market_cap_dominance": item['quote']['USD']['market_cap_dominance'],
        "circulating_supply": item['circulating_supply'],
        "max_supply": item['max_supply'],
        "percent_change_1h": item['quote']['USD']['percent_change_1h'],
        "percent_change_24h": item['quote']['USD']['percent_change_24h'],
        "percent_change_7d": item['quote']['USD']['percent_change_7d'],
        "last_updated": item['quote']['USD']['last_updated']
    }
    organized_data.append(btc_info)

# Convert to a DataFrame
df = pd.DataFrame(organized_data)

# Display the DataFrame
df.head()
# Out:
#      id         name symbol  cmc_rank          price    volume_24h
# 0     1      Bitcoin    BTC         1  103021.330631  4.316131e+10  \
# 1  1027     Ethereum    ETH         2    3865.373161  2.267221e+10
# 2   825  Tether USDt   USDT         3       0.999683  9.868676e+10
# 3    52          XRP    XRP         4       2.387062  5.288497e+09
# 4  5426       Solana    SOL         5     217.829514  2.642508e+09
#
#      market_cap  market_cap_dominance  circulating_supply    max_supply
# 0  2.039472e+12               56.0653        1.979660e+07  2.100000e+07  \
# 1  4.655785e+11               12.8116        1.204485e+08           NaN
# 2  1.402092e+11                3.8612        1.402537e+11           NaN
# 3  1.365110e+11                3.7549        5.718787e+10  1.000000e+11
# 4  1.043722e+11                2.8743        4.791463e+08           NaN
#
#    percent_change_1h  percent_change_24h  percent_change_7d
# 0          -0.089745            1.882230           2.977834  \
# 1          -0.881379            0.283379          -3.133406
# 2           0.006331           -0.006521          -0.087647
# 3          -0.923427           -0.018517          -7.116003
# 4          -1.337667            0.108415          -7.583027
#
#                last_updated
# 0  2024-12-15T21:46:00.000Z
# 1  2024-12-15T21:46:00.000Z
# 2  2024-12-15T21:46:00.000Z
# 3  2024-12-15T21:46:00.000Z
# 4  2024-12-15T21:46:00.000Z

# %%
# Convert 'last_update' to a proper datetime object
df["last_updated"] = pd.to_datetime(df["last_updated"])

# Add 'pulled_at' field with the current timestamp
df["pulled_at"] = datetime.now()

# %%
# Database connection setup
DB_USER = "postgres"
#DB_PASSWORD = ""
DB_HOST = "localhost"
DB_PORT = "5432"
DB_NAME = "signal"

# %%
# Replace with your actual database URL
#DATABASE_URL = f"postgresql+psycopg2://{DB_USER}:{DB_PASSWORD}@{DB_HOST}:{DB_PORT}/{DB_NAME}"
DATABASE_URL = f"postgresql+psycopg2://{DB_USER}@{DB_HOST}:{DB_PORT}/{DB_NAME}"

# Create database engine
engine = create_engine(DATABASE_URL)

# %%
# Define the table name
table_name = "crypto_price_history"

# %%
# Function to upsert data
def upsert_crypto_data(df, table_name, engine):
    with engine.connect() as connection:
        # Query existing records (symbol + last_updated)
        query = f"""
        SELECT symbol, last_updated
        FROM {table_name};
        """
        existing_data = pd.read_sql(query, connection)
        
        # Merge to find new records
        new_data = df.merge(
            existing_data,
            on=["symbol", "last_updated"],
            how="left",
            indicator=True
        ).query('_merge == "left_only"').drop(columns=['_merge'])
        
        # Insert new records
        if not new_data.empty:
            new_data.to_sql(table_name, engine, if_exists="append", index=False)
            print(f"Inserted {len(new_data)} new records into {table_name}.")
        else:
            print("No new records to insert.")
# Out:
# ---------------------------------------------------------------------------
# NumericValueOutOfRange                    Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sqlalchemy/engine/base.py:2120, in Connection._exec_insertmany_context(self, dialect, context)
#    2119     else:
# -> 2120         dialect.do_execute(
#    2121             cursor,
#    2122             sub_stmt,
#    2123             sub_params,
#    2124             context,
#    2125         )
#    2127 except BaseException as e:
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sqlalchemy/engine/default.py:919, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     918 def do_execute(self, cursor, statement, parameters, context=None):
# --> 919     cursor.execute(statement, parameters)
#
# NumericValueOutOfRange: numeric field overflow
# DETAIL:  A field with precision 20, scale 8 must round to an absolute value less than 10^12.
#
#
# The above exception was the direct cause of the following exception:
#
# DataError                                 Traceback (most recent call last)
# Cell In[8], line 27
#      24             print("No new records to insert.")
#      26 # Call the function
# ---> 27 upsert_crypto_data(df, table_name, engine)
#
# Cell In[8], line 21, in upsert_crypto_data(df, table_name, engine)
#      19 # Insert new records
#      20 if not new_data.empty:
# ---> 21     new_data.to_sql(table_name, engine, if_exists="append", index=False)
#      22     print(f"Inserted {len(new_data)} new records into {table_name}.")
#      23 else:
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/generic.py:2878, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2713 """
#    2714 Write records stored in a DataFrame to a SQL database.
#    2715
#    (...)
#    2874 [(1,), (None,), (2,)]
#    2875 """  # noqa:E501
#    2876 from pandas.io import sql
# -> 2878 return sql.to_sql(
#    2879     self,
#    2880     name,
#    2881     con,
#    2882     schema=schema,
#    2883     if_exists=if_exists,
#    2884     index=index,
#    2885     index_label=index_label,
#    2886     chunksize=chunksize,
#    2887     dtype=dtype,
#    2888     method=method,
#    2889 )
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/sql.py:767, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     762     raise NotImplementedError(
#     763         "'frame' argument should be either a Series or a DataFrame"
#     764     )
#     766 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
# --> 767     return pandas_sql.to_sql(
#     768         frame,
#     769         name,
#     770         if_exists=if_exists,
#     771         index=index,
#     772         index_label=index_label,
#     773         schema=schema,
#     774         chunksize=chunksize,
#     775         dtype=dtype,
#     776         method=method,
#     777         engine=engine,
#     778         **engine_kwargs,
#     779     )
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/sql.py:1918, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1906 sql_engine = get_engine(engine)
#    1908 table = self.prep_table(
#    1909     frame=frame,
#    1910     name=name,
#    (...)
#    1915     dtype=dtype,
#    1916 )
# -> 1918 total_inserted = sql_engine.insert_records(
#    1919     table=table,
#    1920     con=self.con,
#    1921     frame=frame,
#    1922     name=name,
#    1923     index=index,
#    1924     schema=schema,
#    1925     chunksize=chunksize,
#    1926     method=method,
#    1927     **engine_kwargs,
#    1928 )
#    1930 self.check_case_sensitive(name=name, schema=schema)
#    1931 return total_inserted
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/sql.py:1468, in SQLAlchemyEngine.insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1466 if re.search(msg, err_text):
#    1467     raise ValueError("inf cannot be used with MySQL") from err
# -> 1468 raise err
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/sql.py:1459, in SQLAlchemyEngine.insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1456 from sqlalchemy import exc
#    1458 try:
# -> 1459     return table.insert(chunksize=chunksize, method=method)
#    1460 except exc.StatementError as err:
#    1461     # GH34431
#    1462     # https://stackoverflow.com/a/67358288/6067848
#    1463     msg = r"""(\(1054, "Unknown column 'inf(e0)?' in 'field list'"\))(?#
#    1464     )|inf can not be used with MySQL"""
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/sql.py:1021, in SQLTable.insert(self, chunksize, method)
#    1018     break
#    1020 chunk_iter = zip(*(arr[start_i:end_i] for arr in data_list))
# -> 1021 num_inserted = exec_insert(conn, keys, chunk_iter)
#    1022 # GH 46891
#    1023 if is_integer(num_inserted):
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/sql.py:927, in SQLTable._execute_insert(self, conn, keys, data_iter)
#     915 """
#     916 Execute SQL statement inserting data
#     917
#    (...)
#     924    Each item contains a list of values to be inserted
#     925 """
#     926 data = [dict(zip(keys, row)) for row in data_iter]
# --> 927 result = conn.execute(self.table.insert(), data)
#     928 return result.rowcount
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1422, in Connection.execute(self, statement, parameters, execution_options)
#    1420     raise exc.ObjectNotExecutableError(statement) from err
#    1421 else:
# -> 1422     return meth(
#    1423         self,
#    1424         distilled_parameters,
#    1425         execution_options or NO_OPTIONS,
#    1426     )
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sqlalchemy/sql/elements.py:514, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     512     if TYPE_CHECKING:
#     513         assert isinstance(self, Executable)
# --> 514     return connection._execute_clauseelement(
#     515         self, distilled_params, execution_options
#     516     )
#     517 else:
#     518     raise exc.ObjectNotExecutableError(self)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1644, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1632 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1633     "compiled_cache", self.engine._compiled_cache
#    1634 )
#    1636 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1637     dialect=dialect,
#    1638     compiled_cache=compiled_cache,
#    (...)
#    1642     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1643 )
# -> 1644 ret = self._execute_context(
#    1645     dialect,
#    1646     dialect.execution_ctx_cls._init_compiled,
#    1647     compiled_sql,
#    1648     distilled_parameters,
#    1649     execution_options,
#    1650     compiled_sql,
#    1651     distilled_parameters,
#    1652     elem,
#    1653     extracted_params,
#    1654     cache_hit=cache_hit,
#    1655 )
#    1656 if has_events:
#    1657     self.dispatch.after_execute(
#    1658         self,
#    1659         elem,
#    (...)
#    1663         ret,
#    1664     )
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1848, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1845 context.pre_exec()
#    1847 if context.execute_style is ExecuteStyle.INSERTMANYVALUES:
# -> 1848     return self._exec_insertmany_context(dialect, context)
#    1849 else:
#    1850     return self._exec_single_context(
#    1851         dialect, context, statement, parameters
#    1852     )
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sqlalchemy/engine/base.py:2128, in Connection._exec_insertmany_context(self, dialect, context)
#    2120         dialect.do_execute(
#    2121             cursor,
#    2122             sub_stmt,
#    2123             sub_params,
#    2124             context,
#    2125         )
#    2127 except BaseException as e:
# -> 2128     self._handle_dbapi_exception(
#    2129         e,
#    2130         sql_util._long_statement(sub_stmt),
#    2131         sub_params,
#    2132         cursor,
#    2133         context,
#    2134         is_sub_exec=True,
#    2135     )
#    2137 if engine_events:
#    2138     self.dispatch.after_cursor_execute(
#    2139         self,
#    2140         cursor,
#    (...)
#    2144         context.executemany,
#    2145     )
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sqlalchemy/engine/base.py:2357, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2355 elif should_wrap:
#    2356     assert sqlalchemy_exception is not None
# -> 2357     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2358 else:
#    2359     assert exc_info[1] is not None
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sqlalchemy/engine/base.py:2120, in Connection._exec_insertmany_context(self, dialect, context)
#    2118             break
#    2119     else:
# -> 2120         dialect.do_execute(
#    2121             cursor,
#    2122             sub_stmt,
#    2123             sub_params,
#    2124             context,
#    2125         )
#    2127 except BaseException as e:
#    2128     self._handle_dbapi_exception(
#    2129         e,
#    2130         sql_util._long_statement(sub_stmt),
#    (...)
#    2134         is_sub_exec=True,
#    2135     )
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sqlalchemy/engine/default.py:919, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     918 def do_execute(self, cursor, statement, parameters, context=None):
# --> 919     cursor.execute(statement, parameters)
#
# DataError: (psycopg2.errors.NumericValueOutOfRange) numeric field overflow
# DETAIL:  A field with precision 20, scale 8 must round to an absolute value less than 10^12.
#
# [SQL: INSERT INTO crypto_price_history (id, name, symbol, cmc_rank, price, volume_24h, market_cap, market_cap_dominance, circulating_supply, max_supply, percent_change_1h, percent_change_24h, percent_change_7d, last_updated, pulled_at) VALUES (%(id__0)s, % ... 31535 characters truncated ... 9)s, %(percent_change_24h__99)s, %(percent_change_7d__99)s, %(last_updated__99)s, %(pulled_at__99)s)]
# [parameters: {'circulating_supply__0': 19796600.0, 'cmc_rank__0': 1, 'market_cap__0': 2039472073967.48, 'percent_change_1h__0': -0.08974471, 'symbol__0': 'BTC', 'name__0': 'Bitcoin', 'id__0': 1, 'market_cap_dominance__0': 56.0653, 'max_supply__0': 21000000.0, 'percent_change_24h__0': 1.88223017, 'percent_change_7d__0': 2.97783358, 'last_updated__0': datetime.datetime(2024, 12, 15, 21, 46, tzinfo=datetime.timezone.utc), 'volume_24h__0': 43161311554.0694, 'pulled_at__0': datetime.datetime(2024, 12, 15, 15, 48, 8, 506557), 'price__0': 103021.33063089015, 'circulating_supply__1': 120448515.52700861, 'cmc_rank__1': 2, 'market_cap__1': 465578459222.66364, 'percent_change_1h__1': -0.88137894, 'symbol__1': 'ETH', 'name__1': 'Ethereum', 'id__1': 1027, 'market_cap_dominance__1': 12.8116, 'max_supply__1': None, 'percent_change_24h__1': 0.28337878, 'percent_change_7d__1': -3.1334057, 'last_updated__1': datetime.datetime(2024, 12, 15, 21, 46, tzinfo=datetime.timezone.utc), 'volume_24h__1': 22672213271.944176, 'pulled_at__1': datetime.datetime(2024, 12, 15, 15, 48, 8, 506557), 'price__1': 3865.3731611849153, 'circulating_supply__2': 140253672849.47852, 'cmc_rank__2': 3, 'market_cap__2': 140209201960.22348, 'percent_change_1h__2': 0.00633058, 'symbol__2': 'USDT', 'name__2': 'Tether USDt', 'id__2': 825, 'market_cap_dominance__2': 3.8612, 'max_supply__2': None, 'percent_change_24h__2': -0.00652116, 'percent_change_7d__2': -0.08764658, 'last_updated__2': datetime.datetime(2024, 12, 15, 21, 46, tzinfo=datetime.timezone.utc), 'volume_24h__2': 98686762432.57756, 'pulled_at__2': datetime.datetime(2024, 12, 15, 15, 48, 8, 506557), 'price__2': 0.9996829253141716, 'circulating_supply__3': 57187870382.0, 'cmc_rank__3': 4, 'market_cap__3': 136510984929.29765, 'percent_change_1h__3': -0.92342706, 'symbol__3': 'XRP' ... 1400 parameters truncated ... 'percent_change_7d__96': -10.95592464, 'last_updated__96': datetime.datetime(2024, 12, 15, 21, 46, tzinfo=datetime.timezone.utc), 'volume_24h__96': 35618915.84365905, 'pulled_at__96': datetime.datetime(2024, 12, 15, 15, 48, 8, 506557), 'price__96': 0.08228220050786571, 'circulating_supply__97': 88722559.87848262, 'cmc_rank__97': 98, 'market_cap__97': 1192479072.9478738, 'percent_change_1h__97': 0.04412918, 'symbol__97': 'GT', 'name__97': 'GateToken', 'id__97': 4269, 'market_cap_dominance__97': 0.0328, 'max_supply__97': None, 'percent_change_24h__97': 1.26147355, 'percent_change_7d__97': 4.12555602, 'last_updated__97': datetime.datetime(2024, 12, 15, 21, 46, tzinfo=datetime.timezone.utc), 'volume_24h__97': 6839520.72434557, 'pulled_at__97': datetime.datetime(2024, 12, 15, 15, 48, 8, 506557), 'price__97': 13.44053952659992, 'circulating_supply__98': 1942255184.1130493, 'cmc_rank__98': 99, 'market_cap__98': 1189411337.0921211, 'percent_change_1h__98': -1.99172805, 'symbol__98': 'MANA', 'name__98': 'Decentraland', 'id__98': 1966, 'market_cap_dominance__98': 0.0327, 'max_supply__98': None, 'percent_change_24h__98': 1.18318169, 'percent_change_7d__98': -16.57922377, 'last_updated__98': datetime.datetime(2024, 12, 15, 21, 47, tzinfo=datetime.timezone.utc), 'volume_24h__98': 126907796.6435536, 'pulled_at__98': datetime.datetime(2024, 12, 15, 15, 48, 8, 506557), 'price__98': 0.6123867485699507, 'circulating_supply__99': 155828417.79405698, 'cmc_rank__99': 100, 'market_cap__99': 1176434404.0949543, 'percent_change_1h__99': -1.52546984, 'symbol__99': 'AXS', 'name__99': 'Axie Infinity', 'id__99': 6783, 'market_cap_dominance__99': 0.0324, 'max_supply__99': None, 'percent_change_24h__99': 0.58941742, 'percent_change_7d__99': -19.05804116, 'last_updated__99': datetime.datetime(2024, 12, 15, 21, 46, tzinfo=datetime.timezone.utc), 'volume_24h__99': 90964437.03476776, 'pulled_at__99': datetime.datetime(2024, 12, 15, 15, 48, 8, 506557), 'price__99': 7.54954982376662}]
# (Background on this error at: https://sqlalche.me/e/20/9h9h)

# %%
df.describe()
# Out:
#                  id    cmc_rank          price    volume_24h    market_cap
# count    100.000000  100.000000     100.000000  1.000000e+02  1.000000e+02  \
# mean   10629.180000   50.500000    1122.799467  2.131439e+09  3.531672e+10
# min        1.000000    1.000000       0.000001  4.018472e+05  1.176434e+09
# 25%     3135.500000   25.750000       0.608336  9.089231e+07  1.614359e+09
# 50%     6537.000000   50.500000       2.041839  2.253861e+08  3.083407e+09
# 75%    20533.750000   75.250000      12.757684  4.468335e+08  6.389096e+09
# max    32880.000000  100.000000  103021.330631  9.868676e+10  2.039472e+12
# std    10040.048226   29.011492   10302.189058  1.091036e+10  2.089295e+11
#
#        market_cap_dominance  circulating_supply    max_supply
# count            100.000000        1.000000e+02  3.800000e+01  \
# mean               0.971318        2.064552e+13  1.352330e+13
# min                0.032400        8.909149e+05  1.005577e+06
# 25%                0.044400        4.050068e+08  2.026750e+08
# 50%                0.084800        1.369880e+09  2.050000e+09
# 75%                0.175975        6.500625e+09  1.000000e+10
# max               56.065300        9.682464e+14  4.206900e+14
# std                5.743827        1.199707e+14  6.948170e+13
#
#        percent_change_1h  percent_change_24h  percent_change_7d
# count         100.000000          100.000000         100.000000  \
# mean           -1.506728            1.081219          -8.529069
# min            -3.299938           -8.441818         -25.845567
# 25%            -2.006349           -0.038852         -15.478401
# 50%            -1.580610            0.681806         -11.652527
# 75%            -1.216013            1.935518          -4.556026
# max             0.366963           11.951290          52.490603
# std             0.787799            2.735452          11.314535
#
#                            pulled_at
# count                            100
# mean   2024-12-15 15:48:08.506556416
# min       2024-12-15 15:48:08.506557
# 25%    2024-12-15 15:48:08.506556928
# 50%    2024-12-15 15:48:08.506556928
# 75%    2024-12-15 15:48:08.506556928
# max       2024-12-15 15:48:08.506557
# std                              NaN

# %%
def validate_and_truncate(df):
    # Truncate string fields to match database limits
    df["symbol"] = df["symbol"].str[:10]
    df["name"] = df["name"].str[:50]

    # Clip numeric fields to match database constraints
    df["price"] = df["price"].clip(upper=10**12 - 1)
    df["volume_24h"] = df["volume_24h"].clip(upper=10**12 - 1)
    df["market_cap"] = df["market_cap"].clip(upper=10**12 - 1)
    df["market_cap_dominance"] = df["market_cap_dominance"].clip(upper=999.99)
    df["circulating_supply"] = df["circulating_supply"].clip(upper=10**12 - 1)
    df["max_supply"] = df["max_supply"].clip(upper=10**12 - 1)
    df["percent_change_1h"] = df["percent_change_1h"].clip(-9999.9999, 9999.9999)
    df["percent_change_24h"] = df["percent_change_24h"].clip(-9999.9999, 9999.9999)
    df["percent_change_7d"] = df["percent_change_7d"].clip(-9999.9999, 9999.9999)

    # Ensure no null values in required fields (if applicable)
    df = df.dropna(subset=["symbol", "last_updated"])

    return df

# %%
# Validate and truncate DataFrame
df_cleaned = validate_and_truncate(df)

# %%
# Call the function
upsert_crypto_data(df_cleaned, table_name, engine)
# Out:
# Inserted 100 new records into crypto_price_history.
